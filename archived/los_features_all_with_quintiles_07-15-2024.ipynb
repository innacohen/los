# %%
## This version excludes CONTINUOUS Variables and the RFD variables AND _wHICH VARIABLES 3/27/2024 and con_max_consultorder_time/day and drg name
## 4/4/2024 Added QUINTILE variables
## 4/8/2024 Added QUINTILE varables by service
## 4/9/2024 Added more consult and imaging variables (e.g. ad,it order to consult order, admit order to imaging read)
## 4/11/2024 Added QUINTILE variables by service for the additional variables
# 06/12/2024: Added gender, added imaging_order_before_consult_order and consult_order_before_imaging order variables, excluded 290 patients in 2022, dropped raw race/insurance categories
# 06/14/2024: Removed quintiles
# 06/20/2024: Set seed for reproducibility
# 06/22/2024: Added sample size for validation
# 07/05/2024: Collapsed Cardiology into Medicine
# 07/08/2024: Added label names

# %%
import pandas as pd
import numpy as np

#ML packages
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler
from feature_engine.discretisation import DecisionTreeDiscretiser
from sklearn.model_selection import GroupShuffleSplit
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score, roc_auc_score, classification_report, precision_recall_curve, roc_curve, auc
from sklearn.calibration import calibration_curve

#XGBo
#https://github.com/liannewriting/YouTube-videos-public/blob/main/xgboost-python-tutorial-example/xgboost_python.ipynb
import xgboost as xgb
from category_encoders.target_encoder import TargetEncoder
from xgboost import XGBClassifier
#hyperparameter values
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer

#Feature Selection
from feature_engine.selection import DropConstantFeatures, DropDuplicateFeatures, SmartCorrelatedSelection
from feature_engine.encoding import OneHotEncoder
from feature_engine.selection import DropFeatures, DropConstantFeatures, DropDuplicateFeatures, SmartCorrelatedSelection
from feature_engine.imputation import AddMissingIndicator
from feature_engine.outliers import Winsorizer
from feature_engine.wrappers import SklearnTransformerWrapper
from feature_engine.imputation import ArbitraryNumberImputer
from feature_engine.imputation import MeanMedianImputer
from feature_engine.imputation import CategoricalImputer
from feature_engine.encoding import RareLabelEncoder

#Plotting Packages
import shap
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
def map_med (value):
    if value in ["Cardiology", "Medicine"]:
        return "Medicine"
    else:
        return value

# %% [markdown]
# ### Filtering for specific patients

# %%
df_all = pd.read_csv('/gpfs/milgram/project/rtaylor/imc33/LOS/data/master_los.csv', index_col=[0])

# %%
pd.set_option('display.max_columns', None)

# %%
df_all.shape
# Out:
# (12931, 928)

# %%
df_all["viz_service_collapsed"].value_counts()
# Out:
# viz_service_collapsed
# Medicine             9973
# Cardiology           1667
# Neurology             877
# Surgical Services     414
# Name: count, dtype: int64

# %%
df_all["viz_service_collapsed"] = df_all["viz_service_collapsed"].apply(map_med)

# %%
df_all["viz_service_collapsed"].value_counts()
# Out:
# viz_service_collapsed
# Medicine             11640
# Neurology              877
# Surgical Services      414
# Name: count, dtype: int64

# %%
df_all["viz_disp_collapsed"].value_counts()
# Out:
# viz_disp_collapsed
# Other    8137
# Home     4794
# Name: count, dtype: int64

# %%
df_all["imaging_order_before_consult_order"].value_counts()
# Out:
# imaging_order_before_consult_order
# True     1351
# False     236
# Name: count, dtype: int64

# %%
#Filter for home patients
df_filt = df_all.copy()
#df_filt = df_all[df_all["viz_disp_collapsed"] == "Home"].copy()
#df_filt = df_all[df_all["thro_boarding_yn"] == 1].copy()

# %%
df_filt.shape
# Out:
# (12931, 928)

# %%
features_los = pd.read_excel('/gpfs/milgram/project/rtaylor/imc33/LOS/data/features_los.xlsx')

# Features that are divided into 5 types to conduct data preprocessing
# 1. drop: features that need to be dropped
drop_list = features_los[features_los['type'] == 'drop']['col_name'].tolist()

# 2. category: features that are already categorical and need to be OneHotEncoding (add missing value indicator, impute missing by adding 'missing' category)
category_list = features_los[features_los['type'] == 'category']['col_name'].tolist()

# 3. binary: features that are binary and need to be converted to categorical (add missing value indicator / prefer: fill missing with 0)
binary_list = features_los[features_los['type'] == 'binary']['col_name'].tolist()

# 4. continuous: features that are continous/numerical variables, need outlier handling and normalization (add missing value indicator, fill missing with median)
continuous_list = features_los[features_los['type'] == 'continuous']['col_name'].tolist()

# 5. discrete: features that are discrete/numerical variables, need to be discretized (fill missing with 0)
discrete_list = features_los[features_los['type'] == 'discrete']['col_name'].tolist()

# %%
# Split into X, y
X = df_filt.drop(['viz_outcome_prolonged_los_yn'], axis=1)
y = df_filt['viz_outcome_prolonged_los_yn']

# %%
# Convert variables to categorical
X[binary_list] = X[binary_list].astype('category')
X[category_list] = X[category_list].astype('category')

# %%
#missing_pct.reset_index().sort_values(0, ascending=False).head()

# %%
continuous_list.remove("viz_age")

# %%
#Check drop list
#drop_list

# %%
X = X.drop(columns=drop_list+continuous_list)
X = X.reset_index()
y = y.reset_index()

# %%
# Split the data by group shuffle split on 'PAT_MRN_ID' into train set and validation set
gss = GroupShuffleSplit(n_splits=2, test_size=0.2, random_state=42)

train_ix, val_ix = next(gss.split(X, y, groups=X['pat_mrn_id']))

X_train = X.loc[train_ix]
y_train = y.loc[train_ix]

X_val = X.loc[val_ix]
y_val = y.loc[val_ix]

# Drop 'PAT_MRN_ID' and set 'PAT_ENC_CSN_ID' as index
X_train = X_train.drop(['pat_mrn_id'], axis=1).set_index('pat_enc_csn_id')
X_val = X_val.drop(['pat_mrn_id'], axis=1).set_index('pat_enc_csn_id')

# %%
# Update feature preprocessing pipeline
feature_preprocess_pipeline = Pipeline(steps=[

    # Missing value imputation
    # Impute missing values with 0 for discrete variables
    ('arbitrary_number_imputer', ArbitraryNumberImputer(arbitrary_number=0, variables=discrete_list)),

  
    # Impute missing values with adding 'missing' category for categorical variables 
   ('categorical_imputer', CategoricalImputer(variables=category_list)),

    # Impute missing values with 0 for binary variables 
    ('binary_imputer', CategoricalImputer(fill_value='0', variables=binary_list)),

    
    # Rare encoding for categorical variables
    ('rare_label_encoder', RareLabelEncoder(tol=0.01, n_categories=5, max_n_categories=10, variables=category_list)),

    # OneHotEncoding for categoricals
    ('one_hot_category', OneHotEncoder(variables=category_list)),
    
])  # Apply the pipeline

# %%
# Apply the pipeline
X_train_preprocessed = feature_preprocess_pipeline.fit_transform(X_train, y_train)
X_val_preprocessed = feature_preprocess_pipeline.transform(X_val)

# %%
X_train_preprocessed.shape
# Out:
# (10380, 1515)

# %% [markdown]
# ### Feature Selection

# %%
# 1st Feature Selection pipeline
feature_selection_pipeline = Pipeline(steps=[

        ('drop_constant', DropConstantFeatures(tol=0.99)),

        ('drop_duplicates', DropDuplicateFeatures()),

        ('correlated_features', SmartCorrelatedSelection(
        method='pearson',
        threshold=0.9,
        selection_method='model_performance',
        estimator=xgb.XGBClassifier(random_state=0)
        ))
])

# %% [markdown]
# ### XGB Model

# %%
# Apply the pipeline
X_train_selected = feature_selection_pipeline.fit_transform(X_train_preprocessed, y_train['viz_outcome_prolonged_los_yn'])
X_val_selected = feature_selection_pipeline.transform(X_val_preprocessed)

# %%
X_train_selected.shape
# Out:
# (10380, 615)

# %%
y_train['viz_outcome_prolonged_los_yn'].sum()/y_train.shape[0]
# Out:
# 0.4430635838150289

# %%
estimators = [
    ('encoder', TargetEncoder()),
    ('clf', XGBClassifier(random_state=8, verbosity=1))
]

tuning_pipeline = Pipeline(steps=estimators)

# %%
search_space = {
    'clf__max_depth': Integer(2,8),
    'clf__learning_rate': Real(0.001, 1.0, prior='log-uniform'),
    'clf__subsample': Real(0.5, 1.0),
    'clf__colsample_bytree': Real(0.5, 1.0),
    'clf__colsample_bylevel': Real(0.5, 1.0),
    'clf__colsample_bynode' : Real(0.5, 1.0),
    'clf__reg_alpha': Real(0.0, 10.0),
    'clf__reg_lambda': Real(0.0, 10.0),
    'clf__gamma': Real(0.0, 10.0)
}

model_xgb = BayesSearchCV(tuning_pipeline, search_space, cv=3, n_iter=10, scoring='roc_auc', random_state=8)

# %%
y_train = y_train.set_index('pat_enc_csn_id')

# %%
model_xgb.fit(X_train_selected,  y_train)
# Out:
# BayesSearchCV(cv=3,
#               estimator=Pipeline(steps=[('encoder', TargetEncoder()),
#                                         ('clf',
#                                          XGBClassifier(base_score=None,
#                                                        booster=None,
#                                                        callbacks=None,
#                                                        colsample_bylevel=None,
#                                                        colsample_bynode=None,
#                                                        colsample_bytree=None,
#                                                        device=None,
#                                                        early_stopping_rounds=None,
#                                                        enable_categorical=False,
#                                                        eval_metric=None,
#                                                        feature_types=None,
#                                                        gamma=None,
#                                                        grow_policy=None,
#                                                        importance_type=N...
#                              'clf__learning_rate': Real(low=0.001, high=1.0, prior='log-uniform', transform='normalize'),
#                              'clf__max_depth': Integer(low=2, high=8, prior='uniform', transform='normalize'),
#                              'clf__reg_alpha': Real(low=0.0, high=10.0, prior='uniform', transform='normalize'),
#                              'clf__reg_lambda': Real(low=0.0, high=10.0, prior='uniform', transform='normalize'),
#                              'clf__subsample': Real(low=0.5, high=1.0, prior='uniform', transform='normalize')})

# %%
model_xgb.best_estimator_
# Out:
# Pipeline(steps=[('encoder',
#                  TargetEncoder(cols=['thro_boarding_yn',
#                                      'summary_pt_consult_order_yn',
#                                      'con_max_consult_order_to_sign_is_signer_ym_provider_yn',
#                                      'con_max_consult_order_to_sign_is_signer_nemg_provider_yn',
#                                      'con_max_consult_order_to_sign_is_signer_community_provider_yn',
#                                      'con_max_consult_note_to_sign_is_signer_ym_provider_yn',
#                                      'con_max_consult_n...
#                                grow_policy=None, importance_type=None,
#                                interaction_constraints=None,
#                                learning_rate=0.7929828265552742, max_bin=None,
#                                max_cat_threshold=None, max_cat_to_onehot=None,
#                                max_delta_step=None, max_depth=7,
#                                max_leaves=None, min_child_weight=None,
#                                missing=nan, monotone_constraints=None,
#                                multi_strategy=None, n_estimators=None,
#                                n_jobs=None, num_parallel_tree=None,
#                                random_state=8, ...))])

# %%
model_xgb.best_score_
# Out:
# 0.7844303600216332

# %%
y_val = y_val.set_index('pat_enc_csn_id')

# %%
#Column 1 and Column 2 are the probabilities that the label is 0 or 1 
y_probs = model_xgb.predict_proba(X_val_selected)
y_pred = model_xgb.predict(X_val_selected)
#Only select the positive class
y_probs_positive = y_probs[:,1]
y_test = y_val['viz_outcome_prolonged_los_yn']

# %%
def plot_metrics(y_test, y_probs_positive):
    fig, axes = plt.subplots(3, 1, figsize=(10, 18))  # 3 rows x 1 column

    # Plot ROC Curve
    fpr, tpr, _ = roc_curve(y_test, y_probs_positive)
    roc_auc = auc(fpr, tpr)
    axes[0].plot(fpr, tpr, label=f'AUC = {roc_auc:.2f}')
    axes[0].plot([0, 1], [0, 1], 'k--', lw=2)
    axes[0].set_xlabel('False Positive Rate')
    axes[0].set_ylabel('True Positive Rate')
    axes[0].set_title('ROC Curve')
    axes[0].legend()

    # Plot PR Curve
    precision, recall, _ = precision_recall_curve(y_test, y_probs_positive)
    pr_auc = auc(recall, precision)
    axes[1].plot(recall, precision, label=f'PR-AUC = {pr_auc:.2f}')
    axes[1].set_xlabel('Recall')
    axes[1].set_ylabel('Precision')
    axes[1].set_title('PR Curve')
    axes[1].legend()

    # Plot Calibration Curve
    prob_true, prob_pred = calibration_curve(y_test, y_probs_positive, n_bins=10)
    axes[2].plot(prob_pred, prob_true, label='Calibration')
    axes[2].plot([0, 1], [0, 1], 'k--', label='Perfectly Calibrated')
    axes[2].set_xlabel('Mean Predicted Probability')
    axes[2].set_ylabel('Fraction of Positives')
    axes[2].set_title('Calibration Curve')
    axes[2].legend()

    plt.tight_layout()
    plt.show()

# %%
plot_metrics(y_test, y_probs_positive)

# %%
def plot_cm(y_test, y_pred):
    # Generate confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.title('Confusion Matrix')
    plt.show()
    
    # Extract values for binary classification
    tn = cm[0, 0]
    fp = cm[0, 1]
    fn = cm[1, 0]
    tp = cm[1, 1]
    
    # Calculate metrics
    top_row = tn + fp
    bot_row = fn + tp
    
    specificity_value = recall_score(y_test, y_pred, pos_label=0)
    sensitivity_value = recall_score(y_test, y_pred, pos_label=1)
    accuracy_value = accuracy_score(y_test, y_pred)
    precision_value = precision_score(y_test, y_pred)
    f1_value = f1_score(y_test, y_pred)
    
    # Print results
    print(f'Specificity : {specificity_value:.4f}')
    print(f'Sensitivity : {sensitivity_value:.4f}')
    print(f'Accuracy : {accuracy_value:.4f}')
    print(f'Precision : {precision_value:.4f}')
    print(f'F1 score : {f1_value:.4f}')
    
    print(f'Of {top_row} people who did not have a prolonged LOS, {tn} ({specificity_value:.2%}) were correctly classified.')
    print(f'Of {bot_row} people who did have a prolonged LOS, {tp} ({sensitivity_value:.2%}) were correctly classified.')

# %%
plot_cm(y_test, y_pred)
# Out:
# Specificity : 0.7957
# Sensitivity : 0.6278
# Accuracy : 0.7229
# Precision : 0.7020
# F1 score : 0.6629
# Of 1444 people who did not have a prolonged LOS, 1149 (79.57%) were correctly classified.
# Of 1107 people who did have a prolonged LOS, 695 (62.78%) were correctly classified.

# %% [markdown]
# ### SHAP plots

# %%
model_xgb.best_estimator_.steps
# Out:
# [('encoder',
#   TargetEncoder(cols=['thro_boarding_yn', 'summary_pt_consult_order_yn',
#                       'con_max_consult_order_to_sign_is_signer_ym_provider_yn',
#                       'con_max_consult_order_to_sign_is_signer_nemg_provider_yn',
#                       'con_max_consult_order_to_sign_is_signer_community_provider_yn',
#                       'con_max_consult_note_to_sign_is_signer_ym_provider_yn',
#                       'con_max_consult_note_to_sign_is_signer_nemg_provider_yn',
#                       'con_max_consult_note_to_sign_is_signer_community_provider_yn',
#                       'icu_any_icu_yn'])),
#  ('clf',
#   XGBClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=0.9425384185492701,
#                 colsample_bynode=0.9095956806239844,
#                 colsample_bytree=0.706128679361455, device=None,
#                 early_stopping_rounds=None, enable_categorical=False,
#                 eval_metric=None, feature_types=None, gamma=1.6598135411398998,
#                 grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=0.7929828265552742,
#                 max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=7, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=8, ...))]

# %%
train_fp = '/gpfs/milgram/project/rtaylor/imc33/LOS/data/pipeline/los_train_initial_selected.csv'
val_fp = '/gpfs/milgram/project/rtaylor/imc33/LOS/data/pipeline/los_val_initial_selected.csv'

X_train_selected.to_csv(train_fp)
X_val_selected.to_csv(val_fp)

X_train_selected = pd.read_csv(train_fp, index_col=[0])
X_val_selected = pd.read_csv(val_fp, index_col=[0])

# %%
X_val_selected.shape
# Out:
# (2551, 615)

# %%
# Set seeds for reproducibility
np.random.seed(42)

# %%
clf_xgb = xgb.XGBClassifier(objective='binary:logistic', missing=None, seed=42)
clf_xgb.fit(X_train_selected, 
            y_train['viz_outcome_prolonged_los_yn'], 
            verbose=True,
            early_stopping_rounds=10,
            eval_metric='aucpr',
            eval_set=[(X_val_selected, y_val['viz_outcome_prolonged_los_yn'])])
# Out:
# [0]	validation_0-aucpr:0.70377
# [1]	validation_0-aucpr:0.72768
# [2]	validation_0-aucpr:0.74153
# [3]	validation_0-aucpr:0.74233
# [4]	validation_0-aucpr:0.74819
# [5]	validation_0-aucpr:0.75500
# [6]	validation_0-aucpr:0.75534
# [7]	validation_0-aucpr:0.75438
# [8]	validation_0-aucpr:0.74999
# [9]	validation_0-aucpr:0.75027
# [10]	validation_0-aucpr:0.75501
# [11]	validation_0-aucpr:0.75767
# [12]	validation_0-aucpr:0.75856
# [13]	validation_0-aucpr:0.76001
# [14]	validation_0-aucpr:0.76033
# [15]	validation_0-aucpr:0.76150
# [16]	validation_0-aucpr:0.76545
# [17]	validation_0-aucpr:0.76501
# [18]	validation_0-aucpr:0.76476
# [19]	validation_0-aucpr:0.76439
# [20]	validation_0-aucpr:0.76226
# [21]	validation_0-aucpr:0.76343
# [22]	validation_0-aucpr:0.76348
# [23]	validation_0-aucpr:0.76337
# [24]	validation_0-aucpr:0.76400
# [25]	validation_0-aucpr:0.76473
# [26]	validation_0-aucpr:0.76559
# [27]	validation_0-aucpr:0.76435
# [28]	validation_0-aucpr:0.76608
# [29]	validation_0-aucpr:0.76602
# [30]	validation_0-aucpr:0.76618
# [31]	validation_0-aucpr:0.76814
# [32]	validation_0-aucpr:0.76902
# [33]	validation_0-aucpr:0.76861
# [34]	validation_0-aucpr:0.76900
# [35]	validation_0-aucpr:0.76942
# [36]	validation_0-aucpr:0.76943
# [37]	validation_0-aucpr:0.77027
# [38]	validation_0-aucpr:0.77034
# [39]	validation_0-aucpr:0.77025
# [40]	validation_0-aucpr:0.77193
# [41]	validation_0-aucpr:0.77197
# [42]	validation_0-aucpr:0.77295
# [43]	validation_0-aucpr:0.77438
# [44]	validation_0-aucpr:0.77622
# [45]	validation_0-aucpr:0.77611
# [46]	validation_0-aucpr:0.77534
# [47]	validation_0-aucpr:0.77620
# [48]	validation_0-aucpr:0.77572
# [49]	validation_0-aucpr:0.77570
# [50]	validation_0-aucpr:0.77574
# [51]	validation_0-aucpr:0.77621
# [52]	validation_0-aucpr:0.77699
# [53]	validation_0-aucpr:0.77654
# [54]	validation_0-aucpr:0.77739
# [55]	validation_0-aucpr:0.77734
# [56]	validation_0-aucpr:0.77609
# [57]	validation_0-aucpr:0.77508
# [58]	validation_0-aucpr:0.77422
# [59]	validation_0-aucpr:0.77488
# [60]	validation_0-aucpr:0.77434
# [61]	validation_0-aucpr:0.77408
# [62]	validation_0-aucpr:0.77394
# [63]	validation_0-aucpr:0.77428
# [64]	validation_0-aucpr:0.77461
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=None, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
explainer = shap.Explainer(clf_xgb)
shap_values = explainer(X_val_selected)

# %%
shap.plots.beeswarm(shap_values, max_display=30)

# %%
shap_df = pd.DataFrame(shap_values.values, columns=shap_values.feature_names)

# %%
mean_abs_shap = np.abs(shap_df).mean(axis=0)

# %%
top_30_features = mean_abs_shap.sort_values(ascending=False).head(30)

# %%
for feature in top_30_features.index.tolist():
    print(feature)
# Out:
# img_max_admit_order_to_imaging_order_any_quintile_5.0
# summary_first_rfd_status_No
# summary_consult_count_all
# viz_drg_Septicemia or severe sepsis w/o mv >96 hours w mcc
# img_avg_admit_order_to_imaging_order_any_quintile_5.0
# viz_drg_Respiratory infections & inflammations w mcc
# con_avg_admit_order_to_consult_completion_any_quintile_5.0
# viz_service_collapsed_Surgical Services
# thro_ed_arrival_time_Afternoon
# con_max_admit_order_to_consult_order_any_quintile_5.0
# viz_age
# census_daily_inpt_count
# summary_last_rfd_status_No
# viz_disp_collapsed_Other
# con_avg_admit_order_to_consult_order_any_quintile_5.0
# summary_last_edd_doc_time_Morning
# con_avg_admit_order_to_consult_completion_any_quintile_4.0
# img_max_order_to_completion_any_quintile_5.0
# con_max_admit_order_to_consult_completion_any_quintile_4.0
# census_daily_ed_count
# viz_discharged_day_Fri
# viz_drg_Septicemia or severe sepsis w/o mv >96 hours w/o mcc
# viz_ynhhs_sg2_service_Digestive Health - Medical
# viz_service_collapsed_Medicine
# img_count_any
# summary_first_edd_doc_day_Thu
# viz_discharged_day_Sat
# con_avg_admit_order_to_consult_completion_any_quintile_1.0
# thro_ed_departure_day_Fri
# con_service_pharmacy_count

# %%
lab_df = pd.read_csv('/gpfs/milgram/project/rtaylor/imc33/LOS/data/new_label_names.csv')

# %%
new_feature_names_dict = pd.Series(lab_df.new_name.values, index=lab_df.old_name).to_dict()

# %%
new_feature_names
# Out:
# ['Age',
#  'ED Boarding',
#  'Consult Count',
#  'Consult Count Unique Services',
#  'summary_pt_consult_order_yn',
#  'YM Provider Count',
#  'con_signer_nemg_provider_count',
#  'Consult Sign Count by Community Provider Count',
#  'con_service_addiction_medicine_count',
#  'con_service_cardiology_count',
#  'con_service_diabetes_count',
#  'GI Consult Count',
#  'con_service_geriatrics_count',
#  'con_service_hematology_count',
#  'con_service_hepatology_count',
#  'Hospitalist Service Count',
#  'con_service_icu_sdu_count',
#  'con_service_infectious_disease_count',
#  'con_service_neurology_count',
#  'con_service_neurosurgery_count',
#  'Oncology Consult Count',
#  'con_service_orthopedics_count',
#  'con_service_other_count',
#  'Palliative Consult Count',
#  'Pharmacy Consult Count',
#  'con_service_picc_count',
#  'con_service_plastic_surgery_count',
#  'con_service_podiatry_count',
#  'con_service_psychiatry_count',
#  'con_service_pulmonology_count',
#  'Radiology Consult Count',
#  'con_service_surgery_count',
#  'con_service_urology_count',
#  'con_service_vascular_surgery_count',
#  'con_max_consult_order_to_sign_is_signer_ym_provider_yn',
#  'con_max_consult_order_to_sign_is_signer_nemg_provider_yn',
#  'con_max_consult_order_to_sign_is_signer_community_provider_yn',
#  'con_max_consult_note_to_sign_is_signer_ym_provider_yn',
#  'con_max_consult_note_to_sign_is_signer_nemg_provider_yn',
#  'con_max_consult_note_to_sign_is_signer_community_provider_yn',
#  'Imaging Count',
#  'CT Count',
#  'MRI Count',
#  'US Count',
#  'icu_any_icu_yn',
#  'Inpatient Volume',
#  'ED Volume',
#  'Discharged With Services',
#  'viz_ethnicity_Non Hispanic Origin',
#  'viz_ethnicity_Unknown',
#  'viz_race_collapsed_Non-White',
#  'viz_language_Other',
#  'viz_insurance_Other/Unknown',
#  'Medicare',
#  'viz_insurance_Managed Medicare',
#  'viz_insurance_Medicaid',
#  'viz_insurance_Commercial',
#  'Medicine Service',
#  'Surgical Services',
#  'viz_ynhhs_sg2_service_Infectious Disease - Medical',
#  'viz_ynhhs_sg2_service_General Medicine',
#  'viz_ynhhs_sg2_service_Nephrology',
#  'viz_ynhhs_sg2_service_Neurology',
#  'viz_ynhhs_sg2_service_Cardiology - Medical',
#  'viz_ynhhs_sg2_service_Pulmonology',
#  'Other Services',
#  'viz_ynhhs_sg2_service_Endocrine - Medical',
#  'GI service',
#  'viz_ynhhs_sg2_service_Cancer - Medical',
#  'DRG Severe Respiratory Infection',
#  'viz_drg_Simple pneumonia & pleurisy w mcc',
#  'DRG Other',
#  'DRG Severe Sepsis',
#  'viz_drg_heart failure & shock w mcc',
#  'viz_drg_Pulmonary edema & respiratory failure',
#  'viz_drg_Other kidney & urinary tract diagnoses w mcc',
#  'DRG Sepsis',
#  'viz_drg_Esophagitis, gastroent & misc digest disorders w/o mcc',
#  'viz_drg_Cellulitis w/o mcc',
#  'viz_admission_day_Sun',
#  'Admit Monday',
#  'viz_admission_day_Tue',
#  'viz_admission_day_Thu',
#  'Admit Friday',
#  'Discharged Tuesday',
#  'viz_discharged_day_Wed',
#  'viz_discharged_day_Thu',
#  'Discharged Friday',
#  'Discharged Saturday',
#  'Discharged Sunday',
#  'viz_discharged_day_Mon',
#  'ED Arrival Night',
#  'thro_ed_arrival_time_Morning',
#  'ED Arrival Afternoon',
#  'thro_ed_arrival_time_Missing',
#  'thro_ed_arrival_day_Wed',
#  'thro_ed_arrival_day_Sat',
#  'thro_admit_or_obs_order_time_Night',
#  'thro_admit_or_obs_order_time_Morning',
#  'thro_admit_or_obs_order_time_Afternoon',
#  'Admit or Obs Order Day Sunday',
#  'thro_admit_or_obs_order_day_Mon',
#  'thro_admit_or_obs_order_day_Tue',
#  'thro_admit_or_obs_order_day_Wed',
#  'thro_admit_or_obs_order_day_Thu',
#  'thro_admit_or_obs_order_day_Fri',
#  'thro_admit_or_obs_order_day_Sat',
#  'First Bed Assigned Night',
#  'thro_first_bed_assigned_time_Missing',
#  'thro_first_bed_assigned_day_Tue',
#  'thro_first_bed_assigned_day_Wed',
#  'thro_first_bed_assigned_day_Sat',
#  'thro_last_bed_assigned_time_Afternoon',
#  'Last Bed Assigned Morning',
#  'thro_last_bed_assigned_day_Sun',
#  'thro_last_bed_assigned_day_Mon',
#  'thro_last_bed_assigned_day_Thu',
#  'thro_last_bed_assigned_day_Fri',
#  'thro_ed_departure_time_Afternoon',
#  'thro_ed_departure_time_Morning',
#  'thro_ed_departure_time_Night',
#  'thro_ed_departure_day_Sun',
#  'thro_ed_departure_day_Mon',
#  'thro_ed_departure_day_Tue',
#  'thro_ed_departure_day_Wed',
#  'thro_ed_departure_day_Thu',
#  'ED Departure Friday',
#  'thro_ed_departure_day_Sat',
#  'summary_pt_consult_order_time_Missing',
#  'summary_first_edd_time_Night',
#  'summary_first_edd_day_Tue',
#  'First Estimated Discharge Wednesday',
#  'summary_first_edd_day_Fri',
#  'summary_first_edd_day_Thu',
#  'summary_first_edd_day_Sat',
#  'summary_first_edd_day_Mon',
#  'summary_first_edd_day_Sun',
#  'summary_first_edd_doc_time_Morning',
#  'summary_first_edd_doc_time_Afternoon',
#  'summary_first_edd_doc_day_Tue',
#  'First Estimated Discharge Monday',
#  'summary_first_edd_doc_day_Sun',
#  'summary_first_edd_doc_day_Wed',
#  'First Estimated Discharge Thursday',
#  'summary_first_edd_doc_day_Sat',
#  'summary_first_edd_doc_day_Fri',
#  'summary_last_edd_day_Tue',
#  'Last Estimated Discharge Wednesday',
#  'summary_last_edd_day_Thu',
#  'Last Estimated Discharge Friday',
#  'summary_last_edd_day_Sat',
#  'summary_last_edd_day_Mon',
#  'summary_last_edd_day_Sun',
#  'Last Estimated Discharge Morning',
#  'summary_last_edd_doc_time_Afternoon',
#  'summary_last_edd_doc_day_Tue',
#  'Last Estimated Discharge Monday',
#  'summary_last_edd_doc_day_Wed',
#  'Last Estimated Discharge Thursday',
#  'summary_last_edd_doc_day_Fri',
#  'summary_last_edd_doc_day_Sat',
#  'summary_last_edd_doc_day_Sun',
#  'First Ready for Discharge_No Barriers',
#  'Not Ready for Discharge_First',
#  'summary_first_rfd_status_Missing',
#  'summary_first_rfd_status_Yes, with barriers',
#  'summary_first_rfd_time_Morning',
#  'summary_first_rfd_time_Afternoon',
#  'First Discharge Readiness (Tuesday)',
#  'First Discharge Readiness (Monday)',
#  'summary_first_rfd_day_Wed',
#  'summary_first_rfd_day_Thu',
#  'First Discharge Readiness (Friday)',
#  'First Discharge Readiness (Sunday)',
#  'summary_first_rfd_day_Sat',
#  'Last Ready for Discharge_No Barriers',
#  'Not Ready for Discharge_Last',
#  'summary_last_rfd_status_Yes, with barriers',
#  'summary_last_rfd_time_Morning',
#  'summary_last_rfd_time_Afternoon',
#  'Last Discharge Readiness (Tuesday)',
#  'summary_last_rfd_day_Wed',
#  'summary_last_rfd_day_Thu',
#  'summary_last_rfd_day_Fri',
#  'summary_last_rfd_day_Sat',
#  'summary_last_rfd_day_Mon',
#  'summary_last_rfd_day_Sun',
#  'con_max_consult_note_creation_time_Missing',
#  'con_max_consult_note_creation_time_Morning',
#  'con_max_consult_note_creation_time_Night',
#  'Consult Afternoon',
#  'con_max_consult_note_creation_day_Wed',
#  'Consult Note Start_Mon',
#  'con_max_consult_note_creation_day_Sun',
#  'con_max_consult_note_creation_day_Fri',
#  'con_max_consult_note_creation_day_Tue',
#  'con_max_consult_note_creation_day_Thu',
#  'con_max_consult_note_creation_day_Sat',
#  'con_max_date_note_signed_time2_Morning',
#  'con_max_date_note_signed_time2_Afternoon',
#  'con_max_date_note_signed_time2_Night',
#  'con_max_date_note_signed_day2_Wed',
#  'con_max_date_note_signed_day2_Mon',
#  'con_max_date_note_signed_day2_Tue',
#  'con_max_date_note_signed_day2_Sat',
#  'con_max_date_note_signed_day2_Sun',
#  'con_max_date_note_signed_day2_Thu',
#  'con_max_date_note_signed_day2_Fri',
#  'con_max_consult_order_to_sign_any_quintile_1.0',
#  'con_max_consult_order_to_sign_any_quintile_2.0',
#  'con_max_consult_order_to_sign_any_quintile_3.0',
#  'con_max_consult_order_to_sign_any_quintile_5.0',
#  'con_max_consult_order_to_sign_any_quintile_4.0',
#  'con_avg_consult_order_to_sign_any_quintile_1.0',
#  'con_avg_consult_order_to_sign_any_quintile_2.0',
#  'con_avg_consult_order_to_sign_any_quintile_4.0',
#  'con_avg_consult_order_to_sign_any_quintile_3.0',
#  'con_avg_consult_order_to_sign_any_quintile_5.0',
#  'img_max_order_to_completion_any_quintile_1.0',
#  'img_max_order_to_completion_any_quintile_Missing',
#  'img_max_order_to_completion_any_quintile_3.0',
#  'img_max_order_to_completion_any_quintile_4.0',
#  'img_max_order_to_completion_any_quintile_2.0',
#  'Max Order to Consult Completion Quintile 5',
#  'img_max_order_to_read_any_quintile_1.0',
#  'img_max_order_to_read_any_quintile_3.0',
#  'img_max_order_to_read_any_quintile_4.0',
#  'img_max_order_to_read_any_quintile_2.0',
#  'img_max_order_to_read_any_quintile_5.0',
#  'img_avg_order_to_completion_any_quintile_2.0',
#  'img_avg_order_to_completion_any_quintile_3.0',
#  'img_avg_order_to_completion_any_quintile_5.0',
#  'img_avg_order_to_completion_any_quintile_1.0',
#  'img_avg_order_to_completion_any_quintile_4.0',
#  'img_avg_order_to_read_any_quintile_1.0',
#  'img_avg_order_to_read_any_quintile_3.0',
#  'img_avg_order_to_read_any_quintile_4.0',
#  'img_avg_order_to_read_any_quintile_2.0',
#  'img_avg_order_to_read_any_quintile_5.0',
#  'con_max_consult_order_to_sign_diabetes_quintile_Missing',
#  'con_max_consult_order_to_sign_diabetes_quintile_Rare',
#  'con_max_consult_order_to_sign_hematology_quintile_Missing',
#  'con_max_consult_order_to_sign_hematology_quintile_Rare',
#  'con_max_consult_order_to_sign_hematology_quintile_4.0',
#  'con_max_consult_order_to_sign_infectious_disease_quintile_3.0',
#  'con_max_consult_order_to_sign_infectious_disease_quintile_2.0',
#  'con_max_consult_order_to_sign_infectious_disease_quintile_Rare',
#  'con_max_consult_order_to_sign_nephrology_quintile_Missing',
#  'con_max_consult_order_to_sign_nephrology_quintile_2.0',
#  'con_max_consult_order_to_sign_nephrology_quintile_4.0',
#  'con_max_consult_order_to_sign_nephrology_quintile_3.0',
#  'con_max_consult_order_to_sign_oncology_quintile_Missing',
#  'con_max_consult_order_to_sign_oncology_quintile_1.0',
#  'con_max_consult_order_to_sign_oncology_quintile_Rare',
#  'con_max_consult_order_to_sign_palliative_quintile_Missing',
#  'con_max_consult_order_to_sign_palliative_quintile_Rare',
#  'con_max_consult_order_to_sign_pulmonology_quintile_Missing',
#  'con_max_consult_order_to_sign_pulmonology_quintile_Rare',
#  'con_max_consult_order_to_sign_pulmonology_quintile_2.0',
#  'con_max_consult_order_to_sign_pulmonology_quintile_3.0',
#  'con_max_consult_order_to_sign_radiology_quintile_Missing',
#  'con_max_consult_order_to_sign_radiology_quintile_2.0',
#  'con_max_consult_order_to_sign_radiology_quintile_Rare',
#  'con_max_consult_order_to_sign_radiology_quintile_5.0',
#  'con_max_consult_order_to_sign_urology_quintile_5.0',
#  'con_max_consult_order_to_sign_cardiology_quintile_Missing',
#  'con_max_consult_order_to_sign_cardiology_quintile_3.0',
#  'con_max_consult_order_to_sign_cardiology_quintile_4.0',
#  'Max Consult Order to Sign Cardiology Quintile 2',
#  'con_max_consult_order_to_sign_cardiology_quintile_5.0',
#  'con_max_consult_order_to_sign_gastroenterology_quintile_5.0',
#  'con_max_consult_order_to_sign_gastroenterology_quintile_2.0',
#  'con_max_consult_order_to_sign_gastroenterology_quintile_4.0',
#  'con_max_consult_order_to_sign_gastroenterology_quintile_3.0',
#  'con_max_consult_order_to_sign_other_quintile_Missing',
#  'con_max_consult_order_to_sign_other_quintile_5.0',
#  'con_max_consult_order_to_sign_surgery_quintile_3.0',
#  'con_max_consult_order_to_sign_surgery_quintile_Rare',
#  'con_max_consult_order_to_sign_neurology_quintile_Missing',
#  'con_max_consult_order_to_sign_neurology_quintile_3.0',
#  'con_max_consult_order_to_sign_neurology_quintile_4.0',
#  'con_max_consult_order_to_sign_neurology_quintile_2.0',
#  'con_max_consult_order_to_sign_neurology_quintile_5.0',
#  'con_max_consult_order_to_sign_hospitalist_service_quintile_Missing',
#  'con_max_consult_order_to_sign_hospitalist_service_quintile_Rare',
#  'con_max_consult_order_to_sign_hospitalist_service_quintile_1.0',
#  'con_max_consult_order_to_sign_psychiatry_quintile_Missing',
#  'con_max_consult_order_to_sign_psychiatry_quintile_Rare',
#  'con_max_consult_order_to_sign_psychiatry_quintile_1.0',
#  'con_max_consult_order_to_sign_neurosurgery_quintile_Missing',
#  'con_max_consult_order_to_sign_neurosurgery_quintile_5.0',
#  'con_max_consult_order_to_sign_orthopedics_quintile_Missing',
#  'con_max_consult_order_to_sign_orthopedics_quintile_4.0',
#  'con_max_consult_order_to_sign_dermatology_quintile_Missing',
#  'con_max_consult_order_to_sign_geriatrics_quintile_Rare',
#  'con_max_consult_order_to_sign_addiction_medicine_quintile_Missing',
#  'con_max_consult_order_to_sign_otolaryngology_ent_quintile_Missing',
#  'con_max_consult_order_to_sign_icu_sdu_quintile_Rare',
#  'con_max_consult_order_to_sign_cardiothoracic_surgery_quintile_Missing',
#  'con_avg_consult_order_to_sign_diabetes_quintile_1.0',
#  'con_avg_consult_order_to_sign_hematology_quintile_4.0',
#  'con_avg_consult_order_to_sign_infectious_disease_quintile_1.0',
#  'con_avg_consult_order_to_sign_infectious_disease_quintile_3.0',
#  'con_avg_consult_order_to_sign_infectious_disease_quintile_2.0',
#  'con_avg_consult_order_to_sign_nephrology_quintile_3.0',
#  'con_avg_consult_order_to_sign_nephrology_quintile_4.0',
#  'con_avg_consult_order_to_sign_nephrology_quintile_2.0',
#  'con_avg_consult_order_to_sign_nephrology_quintile_1.0',
#  'con_avg_consult_order_to_sign_palliative_quintile_1.0',
#  'con_avg_consult_order_to_sign_pulmonology_quintile_1.0',
#  'con_avg_consult_order_to_sign_pulmonology_quintile_2.0',
#  'con_avg_consult_order_to_sign_pulmonology_quintile_3.0',
#  'con_avg_consult_order_to_sign_radiology_quintile_2.0',
#  'con_avg_consult_order_to_sign_radiology_quintile_1.0',
#  'con_avg_consult_order_to_sign_radiology_quintile_Rare',
#  'con_avg_consult_order_to_sign_radiology_quintile_5.0',
#  'con_avg_consult_order_to_sign_urology_quintile_Rare',
#  'con_avg_consult_order_to_sign_cardiology_quintile_3.0',
#  'con_avg_consult_order_to_sign_cardiology_quintile_4.0',
#  'con_avg_consult_order_to_sign_cardiology_quintile_2.0',
#  'con_avg_consult_order_to_sign_cardiology_quintile_1.0',
#  'con_avg_consult_order_to_sign_gastroenterology_quintile_5.0',
#  'con_avg_consult_order_to_sign_gastroenterology_quintile_1.0',
#  'con_avg_consult_order_to_sign_gastroenterology_quintile_4.0',
#  'con_avg_consult_order_to_sign_gastroenterology_quintile_3.0',
#  'con_avg_consult_order_to_sign_other_quintile_Rare',
#  'con_avg_consult_order_to_sign_surgery_quintile_5.0',
#  'con_avg_consult_order_to_sign_surgery_quintile_2.0',
#  'con_avg_consult_order_to_sign_surgery_quintile_Rare',
#  'con_avg_consult_order_to_sign_vascular_surgery_quintile_5.0',
#  'con_avg_consult_order_to_sign_neurology_quintile_4.0',
#  'con_avg_consult_order_to_sign_neurology_quintile_2.0',
#  'con_avg_consult_order_to_sign_neurology_quintile_3.0',
#  'con_avg_consult_order_to_sign_neurology_quintile_5.0',
#  'con_avg_consult_order_to_sign_hospitalist_service_quintile_2.0',
#  'con_avg_consult_order_to_sign_psychiatry_quintile_Rare',
#  'con_avg_consult_order_to_sign_psychiatry_quintile_2.0',
#  'con_avg_consult_order_to_sign_psychiatry_quintile_1.0',
#  'con_avg_consult_order_to_sign_neurosurgery_quintile_4.0',
#  'con_avg_consult_order_to_sign_orthopedics_quintile_5.0',
#  'con_avg_consult_order_to_sign_orthopedics_quintile_Rare',
#  'con_avg_consult_order_to_sign_orthopedics_quintile_4.0',
#  'con_avg_consult_order_to_sign_geriatrics_quintile_1.0',
#  'con_avg_consult_order_to_sign_geriatrics_quintile_2.0',
#  'img_max_order_to_read_ct_quintile_1.0',
#  'img_max_order_to_read_ct_quintile_Missing',
#  'img_max_order_to_read_ct_quintile_3.0',
#  'img_max_order_to_read_ct_quintile_2.0',
#  'img_max_order_to_read_ct_quintile_4.0',
#  'img_max_order_to_read_ct_quintile_5.0',
#  'img_max_order_to_read_mr_quintile_Missing',
#  'img_max_order_to_read_mr_quintile_4.0',
#  'img_max_order_to_read_mr_quintile_5.0',
#  'img_max_order_to_read_mr_quintile_3.0',
#  'img_max_order_to_read_us_quintile_Missing',
#  'img_max_order_to_read_us_quintile_4.0',
#  'img_max_order_to_read_us_quintile_3.0',
#  'img_max_order_to_read_us_quintile_5.0',
#  'img_max_order_to_read_us_quintile_2.0',
#  'img_avg_order_to_completion_ct_quintile_2.0',
#  'img_avg_order_to_completion_ct_quintile_4.0',
#  'img_avg_order_to_completion_ct_quintile_3.0',
#  'img_avg_order_to_completion_ct_quintile_1.0',
#  'img_avg_order_to_completion_ct_quintile_5.0',
#  'img_avg_order_to_completion_mr_quintile_5.0',
#  'img_avg_order_to_completion_mr_quintile_3.0',
#  'img_avg_order_to_completion_mr_quintile_4.0',
#  'Avg Order to US Completion Quintile 5',
#  'img_avg_order_to_completion_us_quintile_2.0',
#  'img_avg_order_to_completion_us_quintile_4.0',
#  'img_avg_order_to_completion_us_quintile_3.0',
#  'img_avg_order_to_read_ct_quintile_1.0',
#  'img_avg_order_to_read_ct_quintile_3.0',
#  'img_avg_order_to_read_ct_quintile_2.0',
#  'img_avg_order_to_read_ct_quintile_4.0',
#  'img_avg_order_to_read_mr_quintile_4.0',
#  'img_avg_order_to_read_mr_quintile_5.0',
#  'img_avg_order_to_read_mr_quintile_3.0',
#  'img_avg_order_to_read_us_quintile_4.0',
#  'img_avg_order_to_read_us_quintile_3.0',
#  'img_avg_order_to_read_us_quintile_5.0',
#  'img_avg_order_to_read_us_quintile_1.0',
#  'img_avg_order_to_read_us_quintile_2.0',
#  'img_max_order_to_completion_ct_quintile3_Rare',
#  'img_max_order_to_completion_us_quintile5_Missing',
#  'img_max_order_to_completion_ct_quintile5_Missing',
#  'img_max_order_to_completion_ct_quintile2_Missing',
#  'img_max_order_to_completion_us_quintile2_Rare',
#  'img_max_order_to_completion_ct_quintile4_Rare',
#  'img_max_order_to_completion_us_quintile4_Missing',
#  'img_max_order_to_completion_ct_quintile1_Rare',
#  'img_max_order_to_completion_us_quintile3_Rare',
#  'img_max_order_to_completion_mr_quintile4_Missing',
#  'img_max_order_to_completion_us_quintile1_Missing',
#  'img_max_order_to_completion_mr_quintile3_Missing',
#  'con_max_admit_order_to_consult_order_any_quintile_Missing',
#  'con_max_admit_order_to_consult_order_any_quintile_2.0',
#  'con_max_admit_order_to_consult_order_any_quintile_3.0',
#  'con_max_admit_order_to_consult_order_any_quintile_4.0',
#  'Max Admit to Consult Order Quintile 5',
#  'con_max_admit_order_to_consult_order_any_quintile_1.0',
#  'con_avg_admit_order_to_consult_order_any_quintile_2.0',
#  'con_avg_admit_order_to_consult_order_any_quintile_3.0',
#  'Avg Admit to Consult Order Quintile 4',
#  'Avg Admit to Consult Order Quintile 5',
#  'img_max_admit_order_to_imaging_order_any_quintile_2.0',
#  'img_max_admit_order_to_imaging_order_any_quintile_Missing',
#  'img_max_admit_order_to_imaging_order_any_quintile_3.0',
#  'Max Admit to Imaging Order Quintile 4',
#  'Max Admit to Imaging Order Quintile 1',
#  'Max Admit to Imaging Order Quintile 5',
#  'img_max_admit_order_to_imaging_read_any_quintile_2.0',
#  'img_max_admit_order_to_imaging_read_any_quintile_3.0',
#  'Max Admit to Imaging Read Quintile 4',
#  'img_max_admit_order_to_imaging_read_any_quintile_5.0',
#  'img_avg_admit_order_to_imaging_order_any_quintile_3.0',
#  'img_avg_admit_order_to_imaging_order_any_quintile_2.0',
#  'img_avg_admit_order_to_imaging_order_any_quintile_4.0',
#  'img_avg_admit_order_to_imaging_order_any_quintile_1.0',
#  'Avg Admit to Imaging Order Quintile 5',
#  'img_avg_admit_order_to_imaging_read_any_quintile_2.0',
#  'img_avg_admit_order_to_imaging_read_any_quintile_3.0',
#  'img_avg_admit_order_to_imaging_read_any_quintile_4.0',
#  'img_avg_admit_order_to_imaging_read_any_quintile_5.0',
#  'img_avg_admit_order_to_imaging_read_any_quintile_1.0',
#  'con_max_admit_order_to_consult_completion_any_quintile_Missing',
#  'con_max_admit_order_to_consult_completion_any_quintile_3.0',
#  'con_max_admit_order_to_consult_completion_any_quintile_2.0',
#  'Max Admit to Consult Completion Quintile 4',
#  'con_max_admit_order_to_consult_completion_any_quintile_1.0',
#  'con_max_admit_order_to_consult_completion_any_quintile_5.0',
#  'con_avg_admit_order_to_consult_completion_any_quintile_3.0',
#  'con_avg_admit_order_to_consult_completion_any_quintile_2.0',
#  'Avg Admit to Consult Completion Quintile 4',
#  'Avg Admit to Consult Completion Quintile 1',
#  'Avg Admit to Consult Completion Quintile 5',
#  'con_max_admit_order_to_consult_order_diabetes_quintile_Rare',
#  'con_max_admit_order_to_consult_order_hematology_quintile_Missing',
#  'con_max_admit_order_to_consult_order_infectious_disease_quintile_2.0',
#  'con_max_admit_order_to_consult_order_infectious_disease_quintile_3.0',
#  'con_max_admit_order_to_consult_order_nephrology_quintile_Missing',
#  'con_max_admit_order_to_consult_order_nephrology_quintile_2.0',
#  'con_max_admit_order_to_consult_order_nephrology_quintile_1.0',
#  'con_max_admit_order_to_consult_order_nephrology_quintile_4.0',
#  'con_max_admit_order_to_consult_order_oncology_quintile_Missing',
#  'con_max_admit_order_to_consult_order_palliative_quintile_Rare',
#  'con_max_admit_order_to_consult_order_pulmonology_quintile_Missing',
#  'con_max_admit_order_to_consult_order_radiology_quintile_Missing',
#  'con_max_admit_order_to_consult_order_radiology_quintile_Rare',
#  'con_max_admit_order_to_consult_order_radiology_quintile_4.0',
#  'con_max_admit_order_to_consult_order_radiology_quintile_5.0',
#  'con_max_admit_order_to_consult_order_urology_quintile_Rare',
#  'con_max_admit_order_to_consult_order_cardiology_quintile_Missing',
#  'con_max_admit_order_to_consult_order_cardiology_quintile_2.0',
#  'con_max_admit_order_to_consult_order_cardiology_quintile_Rare',
#  'con_max_admit_order_to_consult_order_gastroenterology_quintile_Missing',
#  'con_max_admit_order_to_consult_order_gastroenterology_quintile_1.0',
#  'con_max_admit_order_to_consult_order_gastroenterology_quintile_3.0',
#  'con_max_admit_order_to_consult_order_vascular_surgery_quintile_Rare',
#  'con_max_admit_order_to_consult_order_neurology_quintile_Missing',
#  'con_max_admit_order_to_consult_order_psychiatry_quintile_Missing',
#  'con_max_admit_order_to_consult_order_orthopedics_quintile_Rare',
#  'con_max_admit_order_to_consult_order_podiatry_quintile_Rare',
#  'con_max_admit_order_to_consult_order_dermatology_quintile_Rare',
#  'con_max_admit_order_to_consult_completion_infectious_disease_quintile_Missing',
#  'con_max_admit_order_to_consult_completion_infectious_disease_quintile_4.0',
#  'con_max_admit_order_to_consult_completion_infectious_disease_quintile_2.0',
#  'con_max_admit_order_to_consult_completion_infectious_disease_quintile_5.0',
#  'con_max_admit_order_to_consult_completion_nephrology_quintile_Missing',
#  'con_max_admit_order_to_consult_completion_nephrology_quintile_4.0',
#  'con_max_admit_order_to_consult_completion_nephrology_quintile_3.0',
#  'con_max_admit_order_to_consult_completion_oncology_quintile_Rare',
#  'con_max_admit_order_to_consult_completion_oncology_quintile_5.0',
#  'con_max_admit_order_to_consult_completion_palliative_quintile_4.0',
#  'con_max_admit_order_to_consult_completion_palliative_quintile_5.0',
#  'con_max_admit_order_to_consult_completion_pulmonology_quintile_3.0',
#  'con_max_admit_order_to_consult_completion_pulmonology_quintile_Rare',
#  'con_max_admit_order_to_consult_completion_pulmonology_quintile_4.0',
#  'con_max_admit_order_to_consult_completion_radiology_quintile_4.0',
#  'con_max_admit_order_to_consult_completion_radiology_quintile_5.0',
#  'con_max_admit_order_to_consult_completion_radiology_quintile_3.0',
#  'con_max_admit_order_to_consult_completion_cardiology_quintile_2.0',
#  'con_max_admit_order_to_consult_completion_cardiology_quintile_1.0',
#  'con_max_admit_order_to_consult_completion_cardiology_quintile_3.0',
#  'con_max_admit_order_to_consult_completion_cardiology_quintile_4.0',
#  'con_max_admit_order_to_consult_completion_cardiology_quintile_5.0',
#  'con_max_admit_order_to_consult_completion_gastroenterology_quintile_3.0',
#  'con_max_admit_order_to_consult_completion_gastroenterology_quintile_4.0',
#  'con_max_admit_order_to_consult_completion_hepatology_quintile_Missing',
#  'con_max_admit_order_to_consult_completion_surgery_quintile_Missing',
#  'con_max_admit_order_to_consult_completion_surgery_quintile_Rare',
#  'con_max_admit_order_to_consult_completion_surgery_quintile_4.0',
#  'con_max_admit_order_to_consult_completion_surgery_quintile_1.0',
#  'con_max_admit_order_to_consult_completion_vascular_surgery_quintile_Rare',
#  'con_max_admit_order_to_consult_completion_neurology_quintile_3.0',
#  'con_max_admit_order_to_consult_completion_neurology_quintile_5.0',
#  'con_max_admit_order_to_consult_completion_neurology_quintile_2.0',
#  'con_max_admit_order_to_consult_completion_neurology_quintile_4.0',
#  'con_max_admit_order_to_consult_completion_hospitalist_service_quintile_1.0',
#  'con_max_admit_order_to_consult_completion_hospitalist_service_quintile_Rare',
#  'con_max_admit_order_to_consult_completion_psychiatry_quintile_Rare',
#  'con_max_admit_order_to_consult_completion_psychiatry_quintile_5.0',
#  'con_max_admit_order_to_consult_completion_psychiatry_quintile_4.0',
#  'con_max_admit_order_to_consult_completion_neurosurgery_quintile_1.0',
#  'con_max_admit_order_to_consult_completion_neurosurgery_quintile_Rare',
#  'con_max_admit_order_to_consult_completion_physical_medicine_and_rehabilitation_quintile_Missing',
#  'con_max_admit_order_to_consult_completion_geriatrics_quintile_Rare',
#  'con_avg_admit_order_to_consult_order_infectious_disease_quintile_4.0',
#  'con_avg_admit_order_to_consult_order_infectious_disease_quintile_5.0',
#  'con_avg_admit_order_to_consult_order_nephrology_quintile_Rare',
#  'con_avg_admit_order_to_consult_order_nephrology_quintile_3.0',
#  'con_avg_admit_order_to_consult_order_radiology_quintile_4.0',
#  'con_avg_admit_order_to_consult_order_cardiology_quintile_3.0',
#  'con_avg_admit_order_to_consult_order_cardiology_quintile_1.0',
#  'con_avg_admit_order_to_consult_order_gastroenterology_quintile_4.0',
#  'con_avg_admit_order_to_consult_order_gastroenterology_quintile_2.0',
#  'con_avg_admit_order_to_consult_completion_infectious_disease_quintile_4.0',
#  'con_avg_admit_order_to_consult_completion_infectious_disease_quintile_3.0',
#  'con_avg_admit_order_to_consult_completion_infectious_disease_quintile_5.0',
#  'con_avg_admit_order_to_consult_completion_nephrology_quintile_2.0',
#  'con_avg_admit_order_to_consult_completion_nephrology_quintile_4.0',
#  'con_avg_admit_order_to_consult_completion_nephrology_quintile_1.0',
#  'con_avg_admit_order_to_consult_completion_oncology_quintile_3.0',
#  'con_avg_admit_order_to_consult_completion_oncology_quintile_Rare',
#  'con_avg_admit_order_to_consult_completion_palliative_quintile_4.0',
#  'con_avg_admit_order_to_consult_completion_palliative_quintile_5.0',
#  'con_avg_admit_order_to_consult_completion_pulmonology_quintile_3.0',
#  'con_avg_admit_order_to_consult_completion_pulmonology_quintile_4.0',
#  'con_avg_admit_order_to_consult_completion_radiology_quintile_1.0',
#  'con_avg_admit_order_to_consult_completion_radiology_quintile_4.0',
#  'con_avg_admit_order_to_consult_completion_radiology_quintile_3.0',
#  'con_avg_admit_order_to_consult_completion_cardiology_quintile_3.0',
#  'con_avg_admit_order_to_consult_completion_cardiology_quintile_4.0',
#  'con_avg_admit_order_to_consult_completion_cardiology_quintile_5.0',
#  'con_avg_admit_order_to_consult_completion_gastroenterology_quintile_3.0',
#  'con_avg_admit_order_to_consult_completion_gastroenterology_quintile_1.0',
#  'con_avg_admit_order_to_consult_completion_gastroenterology_quintile_5.0',
#  'con_avg_admit_order_to_consult_completion_gastroenterology_quintile_2.0',
#  'con_avg_admit_order_to_consult_completion_gastroenterology_quintile_4.0',
#  'con_avg_admit_order_to_consult_completion_surgery_quintile_Rare',
#  'con_avg_admit_order_to_consult_completion_surgery_quintile_5.0',
#  'con_avg_admit_order_to_consult_completion_neurology_quintile_1.0',
#  'con_avg_admit_order_to_consult_completion_neurology_quintile_3.0',
#  'con_avg_admit_order_to_consult_completion_neurology_quintile_5.0',
#  'con_avg_admit_order_to_consult_completion_neurology_quintile_2.0',
#  'con_avg_admit_order_to_consult_completion_neurology_quintile_4.0',
#  'con_avg_admit_order_to_consult_completion_psychiatry_quintile_Rare',
#  'con_avg_admit_order_to_consult_completion_psychiatry_quintile_4.0',
#  'con_avg_admit_order_to_consult_completion_icu_sdu_quintile_1.0',
#  'con_avg_admit_order_to_consult_completion_icu_sdu_quintile_Rare',
#  'img_max_admit_order_to_imaging_order_ct_quintile4_Missing',
#  'img_max_admit_order_to_imaging_order_mr_quintile5_Rare',
#  'img_max_admit_order_to_imaging_order_us_quintile5_Rare',
#  'img_max_admit_order_to_imaging_order_ct_quintile5_Rare',
#  'img_max_admit_order_to_imaging_order_mr_quintile3_Missing',
#  'img_max_admit_order_to_imaging_order_ct_quintile2_Missing',
#  'img_max_admit_order_to_imaging_order_us_quintile3_Rare',
#  'img_max_admit_order_to_imaging_order_us_quintile4_Missing',
#  'img_max_admit_order_to_imaging_order_mr_quintile4_Missing',
#  'img_max_admit_order_to_imaging_order_mr_quintile1_Missing',
#  'img_max_admit_order_to_imaging_order_us_quintile2_Rare',
#  'img_max_admit_order_to_imaging_order_ct_quintile3_Missing',
#  'img_max_admit_order_to_imaging_order_mr_quintile2_Missing',
#  'img_max_admit_order_to_imaging_read_ct_quintile_2.0',
#  'img_max_admit_order_to_imaging_read_ct_quintile_3.0',
#  'img_max_admit_order_to_imaging_read_ct_quintile_4.0',
#  'img_max_admit_order_to_imaging_read_ct_quintile_5.0',
#  'img_max_admit_order_to_imaging_read_mr_quintile_3.0',
#  'img_max_admit_order_to_imaging_read_mr_quintile_4.0',
#  'img_max_admit_order_to_imaging_read_mr_quintile_5.0',
#  'img_max_admit_order_to_imaging_read_mr_quintile_2.0',
#  'Max Admit to Imaging Read US Quintile 3',
#  'img_max_admit_order_to_imaging_read_us_quintile_4.0',
#  'img_max_admit_order_to_imaging_read_us_quintile_5.0',
#  'img_max_admit_order_to_imaging_read_us_quintile_2.0',
#  'img_avg_admit_order_to_imaging_order_ct_quintile_3.0',
#  'img_avg_admit_order_to_imaging_order_ct_quintile_2.0',
#  'img_avg_admit_order_to_imaging_order_ct_quintile_4.0',
#  'img_avg_admit_order_to_imaging_order_ct_quintile_1.0',
#  'img_avg_admit_order_to_imaging_order_ct_quintile_5.0',
#  'img_avg_admit_order_to_imaging_order_mr_quintile_3.0',
#  'img_avg_admit_order_to_imaging_order_mr_quintile_5.0',
#  'img_avg_admit_order_to_imaging_order_mr_quintile_4.0',
#  'img_avg_admit_order_to_imaging_order_mr_quintile_2.0',
#  'img_avg_admit_order_to_imaging_order_us_quintile_4.0',
#  'img_avg_admit_order_to_imaging_order_us_quintile_3.0',
#  'img_avg_admit_order_to_imaging_order_us_quintile_5.0',
#  'img_avg_admit_order_to_imaging_order_us_quintile_1.0',
#  'img_avg_admit_order_to_imaging_order_us_quintile_2.0',
#  'img_avg_admit_order_to_imaging_read_ct_quintile_2.0',
#  'img_avg_admit_order_to_imaging_read_ct_quintile_3.0',
#  'Avg Admit to Imaging Read CT Quintile 1',
#  'img_avg_admit_order_to_imaging_read_ct_quintile_4.0',
#  'img_avg_admit_order_to_imaging_read_ct_quintile_5.0',
#  'img_avg_admit_order_to_imaging_read_mr_quintile_3.0',
#  'img_avg_admit_order_to_imaging_read_mr_quintile_4.0',
#  'img_avg_admit_order_to_imaging_read_mr_quintile_5.0',
#  'img_avg_admit_order_to_imaging_read_mr_quintile_2.0',
#  'img_avg_admit_order_to_imaging_read_us_quintile_4.0',
#  'img_avg_admit_order_to_imaging_read_us_quintile_3.0',
#  'img_avg_admit_order_to_imaging_read_us_quintile_5.0',
#  'img_avg_admit_order_to_imaging_read_us_quintile_1.0',
#  'img_avg_admit_order_to_imaging_read_us_quintile_2.0',
#  'con_unique_services_which2_Missing',
#  'con_unique_services_which2_Rare',
#  'con_unique_services_which2_Nephrology',
#  'con_unique_services_which2_Multiple',
#  'con_unique_services_which2_Neurology',
#  'con_unique_services_which2_Cardiology',
#  'con_unique_services_which2_Pharmacy',
#  'con_unique_services_which2_Diabetes',
#  'con_unique_services_which2_Gastroenterology',
#  'con_unique_services_which2_Palliative',
#  'con_unique_services_which2_Addiction Medicine',
#  'Male']

# %%
lab_df = pd.read_csv('/gpfs/milgram/project/rtaylor/imc33/LOS/data/new_label_names.csv')

new_feature_names_dict = pd.Series(lab_df.new_name.values, index=lab_df.old_name).to_dict()

current_feature_names = shap_values.feature_names  # Current feature names

# Update feature names in the SHAP values object
#new_feature_names = [new_feature_names_dict.get(name, name) for name in current_feature_names]
#shap_values.feature_names = new_feature_names

# Generate the beeswarm plot with the updated feature names
#shap.plots.beeswarm(shap_values, max_display=30)

# Find the index of the feature to drop
drop_index = new_feature_names.index('Imaging Count')

# Filter out the SHAP values for the feature to drop
shap_values.values = np.delete(shap_values.values, drop_index, axis=1)
shap_values.feature_names = [name for i, name in enumerate(new_feature_names) if i != drop_index]

# Generate the beeswarm plot with the updated SHAP values
shap.plots.beeswarm(shap_values, max_display=30)
# Out:
# ---------------------------------------------------------------------------
# DimensionError                            Traceback (most recent call last)
# Cell In[103], line 22
#      19 shap_values.feature_names = [name for i, name in enumerate(new_feature_names) if i != drop_index]
#      21 # Generate the beeswarm plot with the updated SHAP values
# ---> 22 shap.plots.beeswarm(shap_values, max_display=30)
#
# File /gpfs/milgram/project/hwang/imc33/conda_envs/aitc/lib/python3.8/site-packages/shap/plots/_beeswarm.py:153, in beeswarm(shap_values, max_display, order, clustering, cluster_threshold, color, axis_color, alpha, show, log_scale, color_bar, plot_size, color_bar_label)
#     151         raise DimensionError(shape_msg)
#     152     if num_features != features.shape[1]:
# --> 153         raise DimensionError(shape_msg)
#     155 if feature_names is None:
#     156     feature_names = np.array([labels['FEATURE'] % str(i) for i in range(num_features)])
#
# DimensionError: The shape of the shap_values matrix does not match the shape of the provided data matrix.

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from feature_engine.selection import DropConstantFeatures, DropDuplicateFeatures, SmartCorrelatedSelection
from feature_engine.encoding import OneHotEncoder
from feature_engine.selection import DropFeatures, DropConstantFeatures, DropDuplicateFeatures, SmartCorrelatedSelection
from feature_engine.imputation import AddMissingIndicator
from feature_engine.outliers import Winsorizer
from sklearn.preprocessing import MinMaxScaler
from feature_engine.discretisation import DecisionTreeDiscretiser
from sklearn.model_selection import GroupShuffleSplit

from feature_engine.wrappers import SklearnTransformerWrapper
from feature_engine.imputation import ArbitraryNumberImputer
from feature_engine.imputation import MeanMedianImputer
from feature_engine.imputation import CategoricalImputer
from feature_engine.encoding import RareLabelEncoder
from sklearn.impute import SimpleImputer

#pip install xgboost==0.90
import xgboost as xgb
import plotly.express as px
import shap

#https://github.com/liannewriting/YouTube-videos-public/blob/main/xgboost-python-tutorial-example/xgboost_python.ipynb
from category_encoders.target_encoder import TargetEncoder
from xgboost import XGBClassifier
#hyperparameter values
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer

from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, f1_score, roc_auc_score, classification_report, precision_recall_curve
from sklearn.calibration import calibration_curve

import warnings
warnings.filterwarnings('ignore')
# Out:
# /tmp/ipykernel_3016009/1918152630.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df_all = pd.read_csv('/gpfs/milgram/project/rtaylor/imc33/data/clean/master_los.csv', index_col=[0])

# %%
pd.set_option('display.max_columns', None)

# %%
df_all.head()
# Out:
#                admissiondate dischargedate pat_mrn_id  \
# pat_enc_csn_id
# 304251454         2022-11-11    2023-01-05  MR3040756
# 305958762         2022-11-30    2023-02-07  MR2150031
# 306272157         2022-12-05    2023-01-05  MR2546424
# 306432396         2022-12-05    2023-01-05  MR7137397
# 306430893         2022-12-05    2023-01-07  MR1461853
#
#                                            viz_primary_payer_name  \
# pat_enc_csn_id
# 304251454       Commercial/Private Health Maintenance Organiza...
# 305958762                                   Medicare/Managed Care
# 306272157                          Medicaid Traditional/Indemnity
# 306432396                                   Medicare/Managed Care
# 306430893                          Medicaid Traditional/Indemnity
#
#                viz_disp_collapsed  viz_age        viz_ethnicity viz_race  \
# pat_enc_csn_id
# 304251454                   Other       64  Non Hispanic Origin    White
# 305958762                   Other       83  Non Hispanic Origin    White
# 306272157                   Other       66  Non Hispanic Origin    Black
# 306432396                   Other       79      Hispanic Origin    Other
# 306430893                   Other       46  Non Hispanic Origin    Black
#
#                viz_race_collapsed viz_language     viz_insurance  \
# pat_enc_csn_id
# 304251454                   White      English        Commercial
# 305958762                   White      English  Managed Medicare
# 306272157               Non-White      English          Medicaid
# 306432396               Non-White        Other  Managed Medicare
# 306430893               Non-White      English          Medicaid
#
#                viz_service_collapsed          viz_ynhhs_sg2_service  \
# pat_enc_csn_id
# 304251454          Surgical Services  Infectious Disease - Surgical
# 305958762          Surgical Services  Infectious Disease - Surgical
# 306272157                   Medicine   Infectious Disease - Medical
# 306432396                   Medicine   Infectious Disease - Medical
# 306430893                   Medicine   Infectious Disease - Medical
#
#                 viz_observed_mortality_yn  viz_drg viz_admission_day  \
# pat_enc_csn_id
# 304251454                               0      853               Fri
# 305958762                               0      853               Wed
# 306272157                               0      871               Mon
# 306432396                               0      177               Mon
# 306430893                               0      871               Mon
#
#                viz_discharged_day  viz_outcome_prolonged_los_yn  \
# pat_enc_csn_id
# 304251454                     Thu                             0
# 305958762                     Tue                             1
# 306272157                     Thu                             1
# 306432396                     Thu                             1
# 306430893                     Sat                             1
#
#                 thro_door_to_admit_order_hrs  \
# pat_enc_csn_id
# 304251454                           6.000000
# 305958762                           6.650000
# 306272157                           7.233333
# 306432396                           5.150000
# 306430893                           6.600000
#
#                 thro_admit_order_to_first_bed_hrs  \
# pat_enc_csn_id
# 304251454                                6.783333
# 305958762                               19.250000
# 306272157                                     NaN
# 306432396                               19.633333
# 306430893                               42.350000
#
#                 thro_last_bed_to_ed_dept_hrs  thro_admit_order_to_ed_dept_hrs  \
# pat_enc_csn_id
# 304251454                           1.500000                         8.283333
# 305958762                           2.316667                        21.566667
# 306272157                                NaN                         8.433333
# 306432396                           1.450000                        21.083333
# 306430893                           2.916667                        45.266667
#
#                 thro_boarding_yn thro_ed_arrival_time thro_ed_arrival_day  \
# pat_enc_csn_id
# 304251454                    1.0              Morning                 Fri
# 305958762                    1.0            Afternoon                 Wed
# 306272157                    1.0                Night                 Mon
# 306432396                    1.0            Afternoon                 Mon
# 306430893                    1.0            Afternoon                 Mon
#
#                thro_admit_or_obs_order_time thro_admit_or_obs_order_day  \
# pat_enc_csn_id
# 304251454                         Afternoon                         Fri
# 305958762                             Night                         Thu
# 306272157                           Morning                         Mon
# 306432396                             Night                         Mon
# 306430893                             Night                         Tue
#
#                thro_first_bed_assigned_time thro_first_bed_assigned_day  \
# pat_enc_csn_id
# 304251454                             Night                         Sat
# 305958762                         Afternoon                         Thu
# 306272157                               NaN                         NaN
# 306432396                         Afternoon                         Tue
# 306430893                         Afternoon                         Wed
#
#                thro_last_bed_assigned_time thro_last_bed_assigned_day  \
# pat_enc_csn_id
# 304251454                            Night                        Sat
# 305958762                        Afternoon                        Thu
# 306272157                              NaN                        NaN
# 306432396                        Afternoon                        Tue
# 306430893                        Afternoon                        Wed
#
#                thro_ed_departure_time thro_ed_departure_day  \
# pat_enc_csn_id
# 304251454                       Night                   Sat
# 305958762                   Afternoon                   Thu
# 306272157                   Afternoon                   Mon
# 306432396                   Afternoon                   Tue
# 306430893                   Afternoon                   Wed
#
#                 summary_consult_count_all  \
# pat_enc_csn_id
# 304251454                              26
# 305958762                              31
# 306272157                              13
# 306432396                               2
# 306430893                              25
#
#                 summary_consult_count_unique_services  \
# pat_enc_csn_id
# 304251454                                          13
# 305958762                                          13
# 306272157                                           9
# 306432396                                           2
# 306430893                                          15
#
#                 summary_pt_consult_order_yn summary_pt_consult_order_time  \
# pat_enc_csn_id
# 304251454                                 0                           NaN
# 305958762                                 0                           NaN
# 306272157                                 0                           NaN
# 306432396                                 0                           NaN
# 306430893                                 1                       Morning
#
#                summary_pt_consult_order_day  summary_sw_consult_order_yn  \
# pat_enc_csn_id
# 304251454                               NaN                            0
# 305958762                               NaN                            0
# 306272157                               NaN                            0
# 306432396                               NaN                            0
# 306430893                               Wed                            0
#
#                 summary_sw_consult_order_time  summary_sw_consult_order_day  \
# pat_enc_csn_id
# 304251454                                 NaN                           NaN
# 305958762                                 NaN                           NaN
# 306272157                                 NaN                           NaN
# 306432396                                 NaN                           NaN
# 306430893                                 NaN                           NaN
#
#                summary_first_edd_time summary_first_edd_day  \
# pat_enc_csn_id
# 304251454                       Night                   Mon
# 305958762                       Night                   Wed
# 306272157                       Night                   Sat
# 306432396                       Night                   Fri
# 306430893                       Night                   Tue
#
#                summary_first_edd_doc_time summary_first_edd_doc_day  \
# pat_enc_csn_id
# 304251454                         Morning                       Fri
# 305958762                         Morning                       Mon
# 306272157                       Afternoon                       Fri
# 306432396                         Morning                       Tue
# 306430893                         Morning                       Fri
#
#                 summary_first_edd_to_discharge_hrs  \
# pat_enc_csn_id
# 304251454                               592.933333
# 305958762                              1498.933333
# 306272157                               467.183333
# 306432396                               500.000000
# 306430893                               616.500000
#
#                 summary_first_edd_doc_to_discharge_hrs summary_last_edd_time  \
# pat_enc_csn_id
# 304251454                                   650.516667                 Night
# 305958762                                  1538.783333                 Night
# 306272157                                   475.600000                 Night
# 306432396                                   562.433333                 Night
# 306430893                                   698.466667                 Night
#
#                summary_last_edd_day summary_last_edd_doc_time  \
# pat_enc_csn_id
# 304251454                       Thu                   Morning
# 305958762                       Tue                   Morning
# 306272157                       Thu                   Morning
# 306432396                       Thu                   Morning
# 306430893                       Sat                   Morning
#
#                summary_last_edd_doc_day  summary_last_edd_to_discharge_hrs  \
# pat_enc_csn_id
# 304251454                           Thu                          16.933333
# 305958762                           Tue                          10.933333
# 306272157                           Thu                          11.183333
# 306432396                           Thu                          20.000000
# 306430893                           Sat                          16.500000
#
#                 summary_last_edd_doc_to_discharge_hrs  \
# pat_enc_csn_id
# 304251454                                    2.333333
# 305958762                                    2.183333
# 306272157                                    0.666667
# 306432396                                    8.466667
# 306430893                                    7.016667
#
#                summary_first_rfd_status summary_first_rfd_time  \
# pat_enc_csn_id
# 304251454                            No                Morning
# 305958762                            No                Morning
# 306272157                            No                Morning
# 306432396                            No                Morning
# 306430893                            No              Afternoon
#
#                summary_first_rfd_day  summary_first_rfd_to_discharge_hrs  \
# pat_enc_csn_id
# 304251454                        Sun                         1280.400000
# 305958762                        Fri                         1607.716667
# 306272157                        Tue                          717.133333
# 306432396                        Wed                          703.083333
# 306430893                        Thu                          720.966667
#
#                summary_last_rfd_status summary_last_rfd_time  \
# pat_enc_csn_id
# 304251454             Yes, no barriers               Morning
# 305958762             Yes, no barriers               Morning
# 306272157                           No               Morning
# 306432396             Yes, no barriers               Morning
# 306430893             Yes, no barriers               Morning
#
#                summary_last_rfd_day  summary_last_rfd_to_discharge_hrs  \
# pat_enc_csn_id
# 304251454                       Thu                           2.900000
# 305958762                       Tue                           2.200000
# 306272157                       Tue                          49.250000
# 306432396                       Thu                           8.266667
# 306430893                       Sat                           7.050000
#
#                 summary_total_hrs_nmr  summary_total_hrs_mrwb  \
# pat_enc_csn_id
# 304251454                 1061.033333              216.466667
# 305958762                 1585.766667               19.750000
# 306272157                  624.416667               44.616667
# 306432396                  169.083333              457.516667
# 306430893                  695.233333               18.683333
#
#                 summary_total_hrs_mrnb rfd_first_nmr_start_day  \
# pat_enc_csn_id
# 304251454                     2.900000                     Sun
# 305958762                     8.733333                     Fri
# 306272157                    48.100000                     Tue
# 306432396                    76.483333                     Wed
# 306430893                     7.050000                     Thu
#
#                rfd_first_nmr_start_time rfd_first_mrnb_start_day  \
# pat_enc_csn_id
# 304251454                       Morning                      Thu
# 305958762                       Morning                      Tue
# 306272157                       Morning                      Sun
# 306432396                       Morning                      Sat
# 306430893                     Afternoon                      Sat
#
#                rfd_first_mrnb_start_time rfd_first_mrwb_start_day  \
# pat_enc_csn_id
# 304251454                        Morning                      Fri
# 305958762                        Morning                      Mon
# 306272157                        Morning                      Tue
# 306432396                        Morning                      Wed
# 306430893                        Morning                      Fri
#
#                rfd_first_mrwb_start_time  rfd_first_nmr_to_discharge_hrs  \
# pat_enc_csn_id
# 304251454                      Afternoon                     1280.400000
# 305958762                        Morning                     1607.716667
# 306272157                      Afternoon                      717.133333
# 306432396                        Morning                      703.083333
# 306430893                        Morning                      720.966667
#
#                 rfd_first_mrnb_to_discharge_hrs  \
# pat_enc_csn_id
# 304251454                              2.900000
# 305958762                              2.200000
# 306272157                             97.350000
# 306432396                            127.966667
# 306430893                              7.050000
#
#                 rfd_first_mrwb_to_discharge_hrs  \
# pat_enc_csn_id
# 304251454                            985.933333
# 305958762                             21.950000
# 306272157                            211.383333
# 306432396                            534.000000
# 306430893                             25.733333
#
#                rfd_last_nmr_effective_end_day rfd_last_nmr_effective_end_time  \
# pat_enc_csn_id
# 304251454                                 Fri                         Morning
# 305958762                                 Mon                         Morning
# 306272157                                 Thu                         Morning
# 306432396                                 Wed                         Morning
# 306430893                                 Fri                         Morning
#
#                rfd_last_mrnb_effective_end_day  \
# pat_enc_csn_id
# 304251454                                  Thu
# 305958762                                  Tue
# 306272157                                  Tue
# 306432396                                  Thu
# 306430893                                  Sat
#
#                rfd_last_mrnb_effective_end_time  \
# pat_enc_csn_id
# 304251454                             Afternoon
# 305958762                                 Night
# 306272157                               Morning
# 306432396                             Afternoon
# 306430893                             Afternoon
#
#                rfd_last_mrwb_effective_end_day  \
# pat_enc_csn_id
# 304251454                                  Thu
# 305958762                                  Tue
# 306272157                                  Thu
# 306432396                                  Thu
# 306430893                                  Sat
#
#                rfd_last_mrwb_effective_end_time  \
# pat_enc_csn_id
# 304251454                               Morning
# 305958762                               Morning
# 306272157                               Morning
# 306432396                               Morning
# 306430893                               Morning
#
#                 rfd_last_nmr_to_discharge_hrs  rfd_last_mrnb_to_discharge_hrs  \
# pat_enc_csn_id
# 304251454                          147.266667                        0.000000
# 305958762                           21.950000                       10.933333
# 306272157                            0.000000                       49.250000
# 306432396                          534.000000                        0.000000
# 306430893                           25.733333                        0.000000
#
#                 rfd_last_mrwb_to_discharge_hrs  \
# pat_enc_csn_id
# 304251454                             2.900000
# 305958762                             2.200000
# 306272157                           166.766667
# 306432396                             8.266667
# 306430893                             7.050000
#
#                 con_max_consult_order_to_sign_any_hrs  \
# pat_enc_csn_id
# 304251454                                  123.716667
# 305958762                                  251.433333
# 306272157                                   27.833333
# 306432396                                   24.133333
# 306430893                                  547.516667
#
#                 con_avg_consult_order_to_sign_any_hrs  \
# pat_enc_csn_id
# 304251454                                   21.381667
# 305958762                                   36.573611
# 306272157                                    8.846667
# 306432396                                   24.133333
# 306430893                                  121.790278
#
#                 con_max_consult_note_to_sign_any_hrs  \
# pat_enc_csn_id
# 304251454                                 123.483333
# 305958762                                  37.866667
# 306272157                                 115.900000
# 306432396                                  47.916667
# 306430893                                 546.716667
#
#                 con_avg_consult_note_to_sign_any_hrs  \
# pat_enc_csn_id
# 304251454                                  16.163768
# 305958762                                  10.926667
# 306272157                                  23.435417
# 306432396                                  35.666667
# 306430893                                  69.138636
#
#                 con_signer_ym_provider_count  con_signer_nemg_provider_count  \
# pat_enc_csn_id
# 304251454                               23.0                             1.0
# 305958762                               20.0                             1.0
# 306272157                                7.0                             0.0
# 306432396                                2.0                             0.0
# 306430893                               21.0                             1.0
#
#                 con_signer_community_provider_count  \
# pat_enc_csn_id
# 304251454                                       3.0
# 305958762                                      11.0
# 306272157                                       6.0
# 306432396                                       0.0
# 306430893                                       4.0
#
#                 con_max_consult_order_to_sign_colon_and_rectal_hrs  \
# pat_enc_csn_id
# 304251454                                                     NaN
# 305958762                                                     NaN
# 306272157                                                     NaN
# 306432396                                                     NaN
# 306430893                                                     NaN
#
#                 con_max_consult_order_to_sign_diabetes_hrs  \
# pat_enc_csn_id
# 304251454                                        25.033333
# 305958762                                              NaN
# 306272157                                              NaN
# 306432396                                              NaN
# 306430893                                              NaN
#
#                 con_max_consult_order_to_sign_hematology_hrs  \
# pat_enc_csn_id
# 304251454                                                NaN
# 305958762                                                NaN
# 306272157                                                NaN
# 306432396                                                NaN
# 306430893                                           9.383333
#
#                 con_max_consult_order_to_sign_infectious_disease_hrs  \
# pat_enc_csn_id
# 304251454                                               21.466667
# 305958762                                                     NaN
# 306272157                                               12.950000
# 306432396                                                     NaN
# 306430893                                               27.366667
#
#                 con_max_consult_order_to_sign_lab_medicine_hrs  \
# pat_enc_csn_id
# 304251454                                                  NaN
# 305958762                                                  NaN
# 306272157                                                  NaN
# 306432396                                                  NaN
# 306430893                                                  NaN
#
#                 con_max_consult_order_to_sign_nephrology_hrs  \
# pat_enc_csn_id
# 304251454                                           6.533333
# 305958762                                                NaN
# 306272157                                                NaN
# 306432396                                                NaN
# 306430893                                           4.200000
#
#                 con_max_consult_order_to_sign_oncology_hrs  \
# pat_enc_csn_id
# 304251454                                              NaN
# 305958762                                              NaN
# 306272157                                              NaN
# 306432396                                              NaN
# 306430893                                              NaN
#
#                 con_max_consult_order_to_sign_picc_hrs  \
# pat_enc_csn_id
# 304251454                                          NaN
# 305958762                                          NaN
# 306272157                                          NaN
# 306432396                                          NaN
# 306430893                                          NaN
#
#                 con_max_consult_order_to_sign_palliative_hrs  \
# pat_enc_csn_id
# 304251454                                                NaN
# 305958762                                                NaN
# 306272157                                                NaN
# 306432396                                                NaN
# 306430893                                                NaN
#
#                 con_max_consult_order_to_sign_pulmonology_hrs  \
# pat_enc_csn_id
# 304251454                                                 4.3
# 305958762                                                 NaN
# 306272157                                                 NaN
# 306432396                                                 NaN
# 306430893                                                 NaN
#
#                 con_max_consult_order_to_sign_radiation_oncology_hrs  \
# pat_enc_csn_id
# 304251454                                                    2.35
# 305958762                                                     NaN
# 306272157                                                     NaN
# 306432396                                                     NaN
# 306430893                                                  319.00
#
#                 con_max_consult_order_to_sign_radiology_hrs  \
# pat_enc_csn_id
# 304251454                                          3.533333
# 305958762                                         39.566667
# 306272157                                          0.533333
# 306432396                                               NaN
# 306430893                                         20.866667
#
#                 con_max_consult_order_to_sign_urology_hrs  \
# pat_enc_csn_id
# 304251454                                      123.716667
# 305958762                                             NaN
# 306272157                                             NaN
# 306432396                                             NaN
# 306430893                                             NaN
#
#                 con_max_consult_order_to_sign_cardiology_hrs  \
# pat_enc_csn_id
# 304251454                                                NaN
# 305958762                                           3.066667
# 306272157                                                NaN
# 306432396                                                NaN
# 306430893                                                NaN
#
#                 con_max_consult_order_to_sign_gastroenterology_hrs  \
# pat_enc_csn_id
# 304251454                                                     NaN
# 305958762                                               23.466667
# 306272157                                                     NaN
# 306432396                                                     NaN
# 306430893                                                     NaN
#
#                 con_max_consult_order_to_sign_hepatology_hrs  \
# pat_enc_csn_id
# 304251454                                                NaN
# 305958762                                          28.866667
# 306272157                                                NaN
# 306432396                                                NaN
# 306430893                                                NaN
#
#                 con_max_consult_order_to_sign_other_hrs  \
# pat_enc_csn_id
# 304251454                                           NaN
# 305958762                                           NaN
# 306272157                                           NaN
# 306432396                                           NaN
# 306430893                                           NaN
#
#                 con_max_consult_order_to_sign_pharmacy_hrs  \
# pat_enc_csn_id
# 304251454                                              NaN
# 305958762                                              NaN
# 306272157                                              NaN
# 306432396                                              NaN
# 306430893                                              NaN
#
#                 con_max_consult_order_to_sign_plastic_surgery_hrs  \
# pat_enc_csn_id
# 304251454                                                     NaN
# 305958762                                               38.766667
# 306272157                                               27.833333
# 306432396                                                     NaN
# 306430893                                                     NaN
#
#                 con_max_consult_order_to_sign_surgery_hrs  \
# pat_enc_csn_id
# 304251454                                             NaN
# 305958762                                             NaN
# 306272157                                             NaN
# 306432396                                             NaN
# 306430893                                             NaN
#
#                 con_max_consult_order_to_sign_vascular_surgery_hrs  \
# pat_enc_csn_id
# 304251454                                                     NaN
# 305958762                                               23.016667
# 306272157                                                     NaN
# 306432396                                                     NaN
# 306430893                                                     NaN
#
#                 con_max_consult_order_to_sign_neurology_hrs  \
# pat_enc_csn_id
# 304251454                                               NaN
# 305958762                                               NaN
# 306272157                                               NaN
# 306432396                                         24.133333
# 306430893                                         10.516667
#
#                 con_max_consult_order_to_sign_hospitalist_service_hrs  \
# pat_enc_csn_id
# 304251454                                                     NaN
# 305958762                                                     NaN
# 306272157                                                     NaN
# 306432396                                                     NaN
# 306430893                                                     NaN
#
#                 con_max_consult_order_to_sign_psychiatry_hrs  \
# pat_enc_csn_id
# 304251454                                                NaN
# 305958762                                                NaN
# 306272157                                                NaN
# 306432396                                                NaN
# 306430893                                                NaN
#
#                 con_max_consult_order_to_sign_internal_medicine_hrs  \
# pat_enc_csn_id
# 304251454                                                     NaN
# 305958762                                                     NaN
# 306272157                                                     NaN
# 306432396                                                     NaN
# 306430893                                                     NaN
#
#                 con_max_consult_order_to_sign_neuro_oncology_hrs  \
# pat_enc_csn_id
# 304251454                                                    NaN
# 305958762                                                    NaN
# 306272157                                                    NaN
# 306432396                                                    NaN
# 306430893                                              23.116667
#
#                 con_max_consult_order_to_sign_neurosurgery_hrs  \
# pat_enc_csn_id
# 304251454                                                  NaN
# 305958762                                                  NaN
# 306272157                                                  NaN
# 306432396                                                  NaN
# 306430893                                                  NaN
#
#                 con_max_consult_order_to_sign_ophthalmology_hrs  \
# pat_enc_csn_id
# 304251454                                                   NaN
# 305958762                                                   NaN
# 306272157                                                   NaN
# 306432396                                                   NaN
# 306430893                                            454.116667
#
#                 con_max_consult_order_to_sign_orthopedics_hrs  \
# pat_enc_csn_id
# 304251454                                                 NaN
# 305958762                                                 NaN
# 306272157                                                 NaN
# 306432396                                                 NaN
# 306430893                                                18.4
#
#                 con_max_consult_order_to_sign_physical_medicine_and_rehabilitation_hrs  \
# pat_enc_csn_id
# 304251454                                                     NaN
# 305958762                                                     NaN
# 306272157                                                     NaN
# 306432396                                                     NaN
# 306430893                                               22.366667
#
#                 con_max_consult_order_to_sign_podiatry_hrs  \
# pat_enc_csn_id
# 304251454                                              NaN
# 305958762                                              NaN
# 306272157                                              NaN
# 306432396                                              NaN
# 306430893                                              NaN
#
#                 con_max_consult_order_to_sign_dermatology_hrs  \
# pat_enc_csn_id
# 304251454                                                 NaN
# 305958762                                                 NaN
# 306272157                                                 NaN
# 306432396                                                 NaN
# 306430893                                                 NaN
#
#                 con_max_consult_order_to_sign_geriatrics_hrs  \
# pat_enc_csn_id
# 304251454                                                NaN
# 305958762                                                NaN
# 306272157                                                NaN
# 306432396                                                NaN
# 306430893                                                NaN
#
#                 con_max_consult_order_to_sign_addiction_medicine_hrs  \
# pat_enc_csn_id
# 304251454                                                     NaN
# 305958762                                                     NaN
# 306272157                                                     NaN
# 306432396                                                     NaN
# 306430893                                                     NaN
#
#                 con_max_consult_order_to_sign_otolaryngology_ent_hrs  \
# pat_enc_csn_id
# 304251454                                                     NaN
# 305958762                                                     NaN
# 306272157                                                     NaN
# 306432396                                                     NaN
# 306430893                                                     NaN
#
#                 con_max_consult_order_to_sign_icu_sdu_hrs  \
# pat_enc_csn_id
# 304251454                                             NaN
# 305958762                                             NaN
# 306272157                                             NaN
# 306432396                                             NaN
# 306430893                                             NaN
#
#                 con_max_consult_order_to_sign_trauma_hrs  \
# pat_enc_csn_id
# 304251454                                            NaN
# 305958762                                            NaN
# 306272157                                            NaN
# 306432396                                            NaN
# 306430893                                            NaN
#
#                 con_max_consult_order_to_sign_cardiothoracic_surgery_hrs  \
# pat_enc_csn_id
# 304251454                                                     NaN
# 305958762                                                     NaN
# 306272157                                                     NaN
# 306432396                                                     NaN
# 306430893                                                     NaN
#
#                 con_max_consult_order_to_sign_rheumatology_hrs  \
# pat_enc_csn_id
# 304251454                                                  NaN
# 305958762                                                  NaN
# 306272157                                                  NaN
# 306432396                                                  NaN
# 306430893                                                  NaN
#
#                 con_max_consult_order_to_sign_sw_hrs  \
# pat_enc_csn_id
# 304251454                                        NaN
# 305958762                                        NaN
# 306272157                                        NaN
# 306432396                                        NaN
# 306430893                                        NaN
#
#                 con_max_consult_note_to_sign_colon_and_rectal_hrs  \
# pat_enc_csn_id
# 304251454                                               52.283333
# 305958762                                                     NaN
# 306272157                                                     NaN
# 306432396                                                     NaN
# 306430893                                                     NaN
#
#                 con_max_consult_note_to_sign_diabetes_hrs  \
# pat_enc_csn_id
# 304251454                                        6.116667
# 305958762                                             NaN
# 306272157                                             NaN
# 306432396                                             NaN
# 306430893                                             NaN
#
#                 con_max_consult_note_to_sign_hematology_hrs  \
# pat_enc_csn_id
# 304251454                                         17.166667
# 305958762                                               NaN
# 306272157                                               NaN
# 306432396                                               NaN
# 306430893                                          6.450000
#
#                 con_max_consult_note_to_sign_infectious_disease_hrs  \
# pat_enc_csn_id
# 304251454                                               21.083333
# 305958762                                               24.583333
# 306272157                                                9.000000
# 306432396                                                     NaN
# 306430893                                                1.700000
#
#                 con_max_consult_note_to_sign_lab_medicine_hrs  \
# pat_enc_csn_id
# 304251454                                                 7.7
# 305958762                                                 NaN
# 306272157                                                 NaN
# 306432396                                                 NaN
# 306430893                                                 NaN
#
#                 con_max_consult_note_to_sign_nephrology_hrs  \
# pat_enc_csn_id
# 304251454                                          3.600000
# 305958762                                               NaN
# 306272157                                               NaN
# 306432396                                               NaN
# 306430893                                          3.816667
#
#                 con_max_consult_note_to_sign_oncology_hrs  \
# pat_enc_csn_id
# 304251454                                             NaN
# 305958762                                             NaN
# 306272157                                             NaN
# 306432396                                             NaN
# 306430893                                       33.133333
#
#                 con_max_consult_note_to_sign_picc_hrs  \
# pat_enc_csn_id
# 304251454                                         NaN
# 305958762                                         NaN
# 306272157                                         NaN
# 306432396                                         NaN
# 306430893                                         NaN
#
#                 con_max_consult_note_to_sign_palliative_hrs  \
# pat_enc_csn_id
# 304251454                                         76.366667
# 305958762                                         25.150000
# 306272157                                               NaN
# 306432396                                               NaN
# 306430893                                          4.066667
#
#                 con_max_consult_note_to_sign_pulmonology_hrs  \
# pat_enc_csn_id
# 304251454                                               2.85
# 305958762                                                NaN
# 306272157                                                NaN
# 306432396                                                NaN
# 306430893                                                NaN
#
#                 con_max_consult_note_to_sign_radiation_oncology_hrs  \
# pat_enc_csn_id
# 304251454                                                0.000000
# 305958762                                                     NaN
# 306272157                                                     NaN
# 306432396                                                     NaN
# 306430893                                              318.116667
#
#                 con_max_consult_note_to_sign_radiology_hrs  \
# pat_enc_csn_id
# 304251454                                         0.000000
# 305958762                                        37.866667
# 306272157                                         0.000000
# 306432396                                              NaN
# 306430893                                        18.583333
#
#                 con_max_consult_note_to_sign_urology_hrs  \
# pat_enc_csn_id
# 304251454                                     123.483333
# 305958762                                            NaN
# 306272157                                      26.300000
# 306432396                                            NaN
# 306430893                                            NaN
#
#                 con_max_consult_note_to_sign_cardiology_hrs  \
# pat_enc_csn_id
# 304251454                                               NaN
# 305958762                                          2.883333
# ...
# 304251454                             0.0                   0.0
# 305958762                             1.0                   0.0
# 306272157                             1.0                   0.0
# 306432396                             1.0                   0.0
# 306430893                             0.0                   0.0
#
#                 con_service_trauma_count  con_service_urology_count  \
# pat_enc_csn_id
# 304251454                            0.0                        1.0
# 305958762                            0.0                        0.0
# 306272157                            0.0                        1.0
# 306432396                            0.0                        0.0
# 306430893                            0.0                        0.0
#
#                 con_service_vascular_surgery_count  \
# pat_enc_csn_id
# 304251454                                      0.0
# 305958762                                      1.0
# 306272157                                      0.0
# 306432396                                      0.0
# 306430893                                      0.0
#
#                con_max_consult_order_to_sign_which  \
# pat_enc_csn_id
# 304251454                                  Urology
# 305958762                               Palliative
# 306272157                          Plastic Surgery
# 306432396                                Neurology
# 306430893                             Neurosurgery
#
#                 con_max_consult_order_to_sign_is_signer_ym_provider_yn  \
# pat_enc_csn_id
# 304251454                                                     1.0
# 305958762                                                     1.0
# 306272157                                                     1.0
# 306432396                                                     1.0
# 306430893                                                     1.0
#
#                 con_max_consult_order_to_sign_is_signer_nemg_provider_yn  \
# pat_enc_csn_id
# 304251454                                                     0.0
# 305958762                                                     0.0
# 306272157                                                     0.0
# 306432396                                                     0.0
# 306430893                                                     0.0
#
#                 con_max_consult_order_to_sign_is_signer_community_provider_yn  \
# pat_enc_csn_id
# 304251454                                                     0.0
# 305958762                                                     0.0
# 306272157                                                     0.0
# 306432396                                                     0.0
# 306430893                                                     0.0
#
#                con_max_consult_order_time con_max_consult_order_day  \
# pat_enc_csn_id
# 304251454                         Morning                       Thu
# 305958762                         Morning                       Tue
# 306272157                         Morning                       Mon
# 306432396                         Morning                       Thu
# 306430893                         Morning                       Tue
#
#                con_max_date_note_signed_time1 con_max_date_note_signed_day1  \
# pat_enc_csn_id
# 304251454                           Afternoon                           Tue
# 305958762                           Afternoon                           Fri
# 306272157                             Morning                           Tue
# 306432396                             Morning                           Fri
# 306430893                             Morning                           Thu
#
#                con_max_consult_note_to_sign_which  \
# pat_enc_csn_id
# 304251454                                 Urology
# 305958762                               Radiology
# 306272157                                 Surgery
# 306432396                                 Surgery
# 306430893                            Neurosurgery
#
#                 con_max_consult_note_to_sign_is_signer_ym_provider_yn  \
# pat_enc_csn_id
# 304251454                                                     1.0
# 305958762                                                     1.0
# 306272157                                                     1.0
# 306432396                                                     1.0
# 306430893                                                     1.0
#
#                 con_max_consult_note_to_sign_is_signer_nemg_provider_yn  \
# pat_enc_csn_id
# 304251454                                                     0.0
# 305958762                                                     0.0
# 306272157                                                     0.0
# 306432396                                                     0.0
# 306430893                                                     0.0
#
#                 con_max_consult_note_to_sign_is_signer_community_provider_yn  \
# pat_enc_csn_id
# 304251454                                                     0.0
# 305958762                                                     0.0
# 306272157                                                     0.0
# 306432396                                                     0.0
# 306430893                                                     0.0
#
#                con_max_consult_note_creation_time  \
# pat_enc_csn_id
# 304251454                                 Morning
# 305958762                               Afternoon
# 306272157                                 Morning
# 306432396                               Afternoon
# 306430893                                 Morning
#
#                con_max_consult_note_creation_day  \
# pat_enc_csn_id
# 304251454                                    Thu
# 305958762                                    Wed
# 306272157                                    Sun
# 306432396                                    Sat
# 306430893                                    Tue
#
#                con_max_date_note_signed_time2 con_max_date_note_signed_day2  \
# pat_enc_csn_id
# 304251454                           Afternoon                           Tue
# 305958762                             Morning                           Fri
# 306272157                             Morning                           Fri
# 306432396                           Afternoon                           Mon
# 306430893                             Morning                           Thu
#
#                 img_max_order_to_completion_any_hrs  \
# pat_enc_csn_id
# 304251454                                106.532778
# 305958762                                 78.250833
# 306272157                                 32.246389
# 306432396                                 59.360556
# 306430893                                102.773333
#
#                 img_max_order_to_read_any_hrs  \
# pat_enc_csn_id
# 304251454                          207.412500
# 305958762                           88.250833
# 306272157                           32.446389
# 306432396                           59.610556
# 306430893                          104.806667
#
#                 img_avg_order_to_completion_any_hrs  \
# pat_enc_csn_id
# 304251454                                 22.369330
# 305958762                                 11.106780
# 306272157                                  4.561995
# 306432396                                 19.326167
# 306430893                                 18.089232
#
#                 img_avg_order_to_read_any_hrs  img_count_any  \
# pat_enc_csn_id
# 304251454                           35.497010           17.0
# 305958762                           12.223116           32.0
# 306272157                            5.257778           11.0
# 306432396                           20.016167            5.0
# 306430893                           18.977141           17.0
#
#                 img_max_order_to_completion_ct_hrs  \
# pat_enc_csn_id
# 304251454                                 6.087222
# 305958762                                28.352778
# 306272157                                 2.546111
# 306432396                                 3.000833
# 306430893                                25.277222
#
#                 img_max_order_to_completion_mr_hrs  \
# pat_enc_csn_id
# 304251454                               106.532778
# 305958762                                78.250833
# 306272157                                32.246389
# 306432396                                32.325000
# 306430893                               102.773333
#
#                 img_max_order_to_completion_us_hrs  \
# pat_enc_csn_id
# 304251454                                51.283333
# 305958762                                51.787500
# 306272157                                 2.995556
# 306432396                                59.360556
# 306430893                                50.235000
#
#                 img_max_order_to_completion_echo_hrs  \
# pat_enc_csn_id
# 304251454                                        NaN
# 305958762                                        NaN
# 306272157                                        NaN
# 306432396                                        NaN
# 306430893                                        NaN
#
#                 img_max_order_to_read_ct_hrs  img_max_order_to_read_mr_hrs  \
# pat_enc_csn_id
# 304251454                           6.903889                    106.766111
# 305958762                          30.036111                     88.250833
# 306272157                           3.696111                     32.446389
# 306432396                           3.767500                     32.858333
# 306430893                          26.693889                    104.806667
#
#                 img_max_order_to_read_us_hrs  img_max_order_to_read_echo_hrs  \
# pat_enc_csn_id
# 304251454                         207.412500                             NaN
# 305958762                          51.870833                             NaN
# 306272157                           3.895556                             NaN
# 306432396                          59.610556                             NaN
# 306430893                          51.635000                             NaN
#
#                 img_avg_order_to_completion_ct_hrs  \
# pat_enc_csn_id
# 304251454                                 4.439028
# 305958762                                 6.838524
# 306272157                                 1.162731
# 306432396                                 1.648426
# 306430893                                 6.915586
#
#                 img_avg_order_to_completion_mr_hrs  \
# pat_enc_csn_id
# 304251454                                63.027870
# 305958762                                78.250833
# 306272157                                20.098472
# 306432396                                32.325000
# 306430893                                69.138333
#
#                 img_avg_order_to_completion_us_hrs  \
# pat_enc_csn_id
# 304251454                                15.193079
# 305958762                                11.183315
# 306272157                                 1.002870
# 306432396                                59.360556
# 306430893                                17.833333
#
#                 img_avg_order_to_completion_echo_hrs  \
# pat_enc_csn_id
# 304251454                                        NaN
# 305958762                                        NaN
# 306272157                                        NaN
# 306432396                                        NaN
# 306430893                                        NaN
#
#                 img_avg_order_to_read_ct_hrs  img_avg_order_to_read_mr_hrs  \
# pat_enc_csn_id
# 304251454                           6.903889                    106.766111
# 305958762                          30.036111                     88.250833
# 306272157                           3.696111                     32.446389
# 306432396                           3.767500                     32.858333
# 306430893                          26.693889                    104.806667
#
#                 img_avg_order_to_read_us_hrs  img_avg_order_to_read_echo_hrs  \
# pat_enc_csn_id
# 304251454                         207.412500                             NaN
# 305958762                          51.870833                             NaN
# 306272157                           3.895556                             NaN
# 306432396                          59.610556                             NaN
# 306430893                          51.635000                             NaN
#
#                 img_count_ct  img_count_mr  img_count_us  img_count_echo  \
# pat_enc_csn_id
# 304251454                2.0           3.0          12.0             0.0
# 305958762               16.0           1.0          15.0             0.0
# 306272157                6.0           2.0           3.0             0.0
# 306432396                3.0           1.0           1.0             0.0
# 306430893                9.0           2.0           6.0             0.0
#
#                 icu_any_icu_yn  census_daily_inpt_count      ed_arrival_time  \
# pat_enc_csn_id
# 304251454                    1                      NaN  2022-11-11 14:53:00
# 305958762                    1                      NaN  2022-11-30 17:37:00
# 306272157                    1                      NaN  2022-12-05 05:24:00
# 306432396                    0                      NaN  2022-12-05 18:30:00
# 306430893                    0                      NaN  2022-12-05 17:52:00
#
#                 ed_arrival_hour ed_arrival_date  census_daily_ed_count
# pat_enc_csn_id
# 304251454                  14.0      2022-11-11                    NaN
# 305958762                  17.0      2022-11-30                    NaN
# 306272157                   5.0      2022-12-05                    NaN
# 306432396                  18.0      2022-12-05                    NaN
# 306430893                  17.0      2022-12-05                    NaN

# %%
df_all.shape
# Out:
# (13205, 336)

# %%
df_all["viz_disp_collapsed"].value_counts()
# Out:
# viz_disp_collapsed
# Other    8346
# Home     4859
# Name: count, dtype: int64

# %%
df_all["thro_boarding_yn"].value_counts()
# Out:
# thro_boarding_yn
# 1.0    6895
# 0.0    5585
# Name: count, dtype: int64

# %%
#Filter for home patients
#df_filt = df_all.copy()
#df_filt = df_all[df_all["viz_disp_collapsed"] == "Home"].copy()
df_filt = df_all[df_all["thro_boarding_yn"] == 0].copy()

# %%
#df_filt.shape

# %%
# aitc_features.xlsx includes all the feature names and corresponding types
features_los = pd.read_excel('/gpfs/milgram/project/rtaylor/imc33/data/clean/features_los.xlsx')

# Features that are divided into 5 types to conduct data preprocessing
# 1. drop: features that need to be dropped
drop_list = features_los[features_los['type'] == 'drop']['col_name'].tolist()

# 2. category: features that are already categorical and need to be OneHotEncoding (add missing value indicator, impute missing by adding 'missing' category)
category_list = features_los[features_los['type'] == 'category']['col_name'].tolist()

# 3. binary: features that are binary and need to be converted to categorical (add missing value indicator / prefer: fill missing with 0)
binary_list = features_los[features_los['type'] == 'binary']['col_name'].tolist()

# 4. continuous: features that are continous/numerical variables, need outlier handling and normalization (add missing value indicator, fill missing with median)
continuous_list = features_los[features_los['type'] == 'continuous']['col_name'].tolist()

# 5. discrete: features that are discrete/numerical variables, need to be discretized (fill missing with 0)
discrete_list = features_los[features_los['type'] == 'discrete']['col_name'].tolist()

# %%
# Identify variables with infinite values
variables_with_inf = df_filt.columns[df_filt.isin([np.inf, -np.inf]).any()]

# Handle infinite values (e.g., replace with NaN)
df_filt[variables_with_inf] = df_filt[variables_with_inf].replace([np.inf, -np.inf], np.nan)

# %%
# Split into X, y
X = df_filt.drop(['viz_outcome_prolonged_los_yn'], axis=1)
y = df_filt['viz_outcome_prolonged_los_yn']

# %%
# Convert variables to categorical
X[binary_list] = X[binary_list].astype('category')
X[category_list] = X[category_list].astype('category')

# %%
# Drop features that have >= 99% missing values And features in drop list
missing_pct = X.isnull().mean() * 100
cols_to_drop = missing_pct[missing_pct >= 99].index.tolist()
#final_drop_list = list(set(drop_list + cols_to_drop))
#X_1b = X_1b.drop(columns=final_drop_list)
#X_1b = X_1b.reset_index(drop=True)
#y_1b = y_1b.reset_index(drop=True)

# %%
pd.set_option('display.max_rows', 400)

# %%
missing_pct.reset_index().sort_values(0, ascending=False).head()
# Out:
#                                                  index      0
# 145          con_max_consult_note_to_sign_pharmacy_hrs  100.0
# 225          con_avg_consult_note_to_sign_pharmacy_hrs  100.0
# 105         con_max_consult_order_to_sign_pharmacy_hrs  100.0
# 168  con_avg_consult_order_to_sign_colon_and_rectal...  100.0
# 39                        summary_sw_consult_order_day  100.0

# %%
continuous_list.remove("viz_age")

# %%
# We do NOT want to drop these
#cols_to_drop
#only these
drop_list
# Out:
# ['admissiondate',
#  'ed_arrival_time',
#  'ed_arrival_hour',
#  'ed_arrival_date',
#  'dischargedate']

# %%
X = X.drop(columns=drop_list+continuous_list)
X = X.reset_index()
y = y.reset_index()

# %%
# Split the data by group shuffle split on 'PAT_MRN_ID' into train set and validation set
gss = GroupShuffleSplit(n_splits=2, test_size=0.2, random_state=42)

train_ix, val_ix = next(gss.split(X, y, groups=X['pat_mrn_id']))

X_train = X.loc[train_ix]
y_train = y.loc[train_ix]

X_val = X.loc[val_ix]
y_val = y.loc[val_ix]

# Drop 'PAT_MRN_ID' and set 'PAT_ENC_CSN_ID' as index
X_train = X_train.drop(['pat_mrn_id'], axis=1).set_index('pat_enc_csn_id')
X_val = X_val.drop(['pat_mrn_id'], axis=1).set_index('pat_enc_csn_id')

# %% [markdown]
# ### Feature Processing

# %%
# Update feature preprocessing pipeline
feature_preprocess_pipeline = Pipeline(steps=[

    # Missing value indicator for categoricals and continuous variables
    #('missing_indicator', AddMissingIndicator(variables=category_list + continuous_list)),

    # Missing value imputation
    # Impute missing values with 0 for discrete variables
    ('arbitrary_number_imputer', ArbitraryNumberImputer(arbitrary_number=0, variables=discrete_list)),

  
    # Impute missing values with adding 'missing' category for categorical variables 
   ('categorical_imputer', CategoricalImputer(variables=category_list)),

    # Impute missing values with 0 for binary variables 
    ('binary_imputer', CategoricalImputer(fill_value='0', variables=binary_list)),

    
    # Rare encoding for categorical variables
    ('rare_label_encoder', RareLabelEncoder(tol=0.01, n_categories=5, max_n_categories=10, variables=category_list)),

    # OneHotEncoding for categoricals
    ('one_hot_category', OneHotEncoder(variables=category_list)),

    # Outlier handling & normalization for continous variables
   #('outlier_handling', Winsorizer(capping_method='gaussian', tail='right', fold=3, variables=continuous_list)),
    #todo: 

  # ('normalize', SklearnTransformerWrapper(MinMaxScaler(feature_range=(0, 1)), variables=continuous_list)),

    # discretize for discrete variables
   #('discretize', DecisionTreeDiscretiser(cv=3, scoring='roc_auc', regression=False, random_state=42, variables=discrete_list))
    #todo:
    
])  # Apply the pipeline

# %%
# Apply the pipeline
X_train_preprocessed = feature_preprocess_pipeline.fit_transform(X_train, y_train)
X_val_preprocessed = feature_preprocess_pipeline.transform(X_val)

# %%
X_train_preprocessed.shape
# Out:
# (4489, 409)

# %%
X_train_preprocessed.to_csv('/gpfs/milgram/project/rtaylor/imc33/data/pipeline/los_train_preprocessed_nonboarded_patients_cat_only.csv')
X_val_preprocessed.to_csv('/gpfs/milgram/project/rtaylor/imc33/data/pipeline/los_val_preprocessed_nonboarded_patients_cat_only.csv')

# %% [markdown]
# ### Feature Selection

# %%
# 1st Feature Selection pipeline
feature_selection_pipeline = Pipeline(steps=[

        ('drop_constant', DropConstantFeatures(tol=0.99)),

        ('drop_duplicates', DropDuplicateFeatures()),

        ('correlated_features', SmartCorrelatedSelection(
        method='pearson',
        threshold=0.9,
        selection_method='model_performance',
        estimator=xgb.XGBClassifier(random_state=0)
        ))
])

# %%
# Apply the pipeline
X_train_selected = feature_selection_pipeline.fit_transform(X_train_preprocessed, y_train['viz_outcome_prolonged_los_yn'])
X_val_selected = feature_selection_pipeline.transform(X_val_preprocessed)

# %%
X_train_selected.to_csv('/gpfs/milgram/project/rtaylor/imc33/data/pipeline/los_train_initial_selected_nonboarded_patients_cat_only.csv')
X_val_selected.to_csv('/gpfs/milgram/project/rtaylor/imc33/data/pipeline/los_val_initial_selected_nonboarded_patients_cat_only.csv')

# %%
X_train_preprocessed.shape
# Out:
# (4489, 409)

# %%
X_train_selected.shape
# Out:
# (4489, 291)

# %%
# Read files
#X_train_selected = pd.read_csv('/gpfs/milgram/project/rtaylor/imc33/data/pipeline/los_train_initial_selected_nonboarded_patients_cat_only.csv')
#X_val_selected = pd.read_csv('/gpfs/milgram/project/rtaylor/imc33/data/pipeline/los_val_initial_selected_nonboarded_patients_cat_only.csv')

# %%
#train_selected = X_train_selected.merge(y_train, on='pat_enc_csn_id', how='left')
#val_selected = X_val_selected.merge(y_val, on='pat_enc_csn_id', how='left')

# %%
#train_selected = train_selected.set_index('pat_enc_csn_id')
#val_selected = val_selected.set_index('pat_enc_csn_id')

# %%
# Top 20 features - training set
#get_best_features(num_feats = 20, df = train_selected, df_name = 'train', target = 'viz_outcome_prolonged_los_yn')

# %%
y_train['viz_outcome_prolonged_los_yn'].sum()/y_train.shape[0]
# Out:
# 0.4357317888171085

# %%
estimators = [
    ('encoder', TargetEncoder()),
    ('clf', XGBClassifier(random_state=8, verbosity=1))
]

tuning_pipeline = Pipeline(steps=estimators)

# %%
search_space = {
    'clf__max_depth': Integer(2,8),
    'clf__learning_rate': Real(0.001, 1.0, prior='log-uniform'),
    'clf__subsample': Real(0.5, 1.0),
    'clf__colsample_bytree': Real(0.5, 1.0),
    'clf__colsample_bylevel': Real(0.5, 1.0),
    'clf__colsample_bynode' : Real(0.5, 1.0),
    'clf__reg_alpha': Real(0.0, 10.0),
    'clf__reg_lambda': Real(0.0, 10.0),
    'clf__gamma': Real(0.0, 10.0)
}

model_xgb = BayesSearchCV(tuning_pipeline, search_space, cv=3, n_iter=10, scoring='roc_auc', random_state=8)

# %%
#y_train = y_train.set_index('pat_enc_csn_id')

# %%
y_train = y_train.set_index('pat_enc_csn_id')

# %%
#X_train_selected = X_train_selected.set_index('pat_enc_csn_id')

# %%
model_xgb.fit(X_train_selected,  y_train)
# Out:
# BayesSearchCV(cv=3,
#               estimator=Pipeline(steps=[('encoder', TargetEncoder()),
#                                         ('clf',
#                                          XGBClassifier(base_score=None,
#                                                        booster=None,
#                                                        callbacks=None,
#                                                        colsample_bylevel=None,
#                                                        colsample_bynode=None,
#                                                        colsample_bytree=None,
#                                                        device=None,
#                                                        early_stopping_rounds=None,
#                                                        enable_categorical=False,
#                                                        eval_metric=None,
#                                                        feature_types=None,
#                                                        gamma=None,
#                                                        grow_policy=None,
#                                                        importance_type=N...
#                              'clf__learning_rate': Real(low=0.001, high=1.0, prior='log-uniform', transform='normalize'),
#                              'clf__max_depth': Integer(low=2, high=8, prior='uniform', transform='normalize'),
#                              'clf__reg_alpha': Real(low=0.0, high=10.0, prior='uniform', transform='normalize'),
#                              'clf__reg_lambda': Real(low=0.0, high=10.0, prior='uniform', transform='normalize'),
#                              'clf__subsample': Real(low=0.5, high=1.0, prior='uniform', transform='normalize')})

# %%
model_xgb.best_estimator_
# Out:
# Pipeline(steps=[('encoder',
#                  TargetEncoder(cols=['summary_pt_consult_order_yn',
#                                      'con_max_consult_order_to_sign_is_signer_ym_provider_yn',
#                                      'con_max_consult_order_to_sign_is_signer_nemg_provider_yn',
#                                      'con_max_consult_order_to_sign_is_signer_community_provider_yn',
#                                      'con_max_consult_note_to_sign_is_signer_ym_provider_yn',
#                                      'con_max_consult_note_to_sign_is_sign...
#                                grow_policy=None, importance_type=None,
#                                interaction_constraints=None,
#                                learning_rate=0.7929828265552742, max_bin=None,
#                                max_cat_threshold=None, max_cat_to_onehot=None,
#                                max_delta_step=None, max_depth=7,
#                                max_leaves=None, min_child_weight=None,
#                                missing=nan, monotone_constraints=None,
#                                multi_strategy=None, n_estimators=None,
#                                n_jobs=None, num_parallel_tree=None,
#                                random_state=8, ...))])

# %%
model_xgb.best_score_
# Out:
# 0.725827144786182

# %%
y_val = y_val.set_index('pat_enc_csn_id')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Confusion Matrix

# %% [markdown]
# -- Of 5831 people who did not have a prolonged LOS, 5831 (86%) were correctly classified.
# -- Of 4724 people who did have prolonged LOS, 3918 (83%) were correctly classified

# %%
# Generate confusion matrix
cm = confusion_matrix(y_train, model_xgb.predict(X_train_selected))

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %%
from sklearn import metrics

def buildROC(target_test,test_preds):
    fpr, tpr, threshold = metrics.roc_curve(target_test, test_preds)
    roc_auc = metrics.auc(fpr, tpr)
    plt.title('ROC Curve')
    plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1], [0, 1],'r--')
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.gcf().savefig('roc.png')

# %%
test_preds = model_xgb.predict(X_val_selected)
target_test = y_val['viz_outcome_prolonged_los_yn']

# %%
buildROC(target_test, test_preds)

# %%
def buildPR(target_test,test_preds):
    precision, recall, _ = metrics.precision_recall_curve(target_test, test_preds)
    pr_auc = metrics.auc(recall, precision)
    plt.title('PR Curve')
    plt.plot(recall, precision, label=f'PR-AUC = {pr_auc:.2f})')
    plt.legend(loc = 'lower right')
    plt.xlabel('Recall')
    plt.ylabel('Precision')

# %%
buildPR(target_test, test_preds)

# %%
def buildCC(target_test,test_preds):
      prob_true, prob_pred = calibration_curve(target_test, test_preds, n_bins=10)
      plt.plot(prob_pred, prob_true)
      plt.xlabel('Mean Predicted Probability')
      plt.ylabel('Fraction of Positives')

# %%
buildCC(target_test, test_preds)

# %%
#model_xgb.predict_proba(X_val)

# %%
model_xgb.best_estimator_.steps
# Out:
# [('encoder',
#   TargetEncoder(cols=['summary_pt_consult_order_yn',
#                       'con_max_consult_order_to_sign_is_signer_ym_provider_yn',
#                       'con_max_consult_order_to_sign_is_signer_nemg_provider_yn',
#                       'con_max_consult_order_to_sign_is_signer_community_provider_yn',
#                       'con_max_consult_note_to_sign_is_signer_ym_provider_yn',
#                       'con_max_consult_note_to_sign_is_signer_nemg_provider_yn',
#                       'con_max_consult_note_to_sign_is_signer_community_provider_yn',
#                       'icu_any_icu_yn'])),
#  ('clf',
#   XGBClassifier(base_score=None, booster=None, callbacks=None,
#                 colsample_bylevel=0.9425384185492701,
#                 colsample_bynode=0.9095956806239844,
#                 colsample_bytree=0.706128679361455, device=None,
#                 early_stopping_rounds=None, enable_categorical=False,
#                 eval_metric=None, feature_types=None, gamma=1.6598135411398998,
#                 grow_policy=None, importance_type=None,
#                 interaction_constraints=None, learning_rate=0.7929828265552742,
#                 max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#                 max_delta_step=None, max_depth=7, max_leaves=None,
#                 min_child_weight=None, missing=nan, monotone_constraints=None,
#                 multi_strategy=None, n_estimators=None, n_jobs=None,
#                 num_parallel_tree=None, random_state=8, ...))]

# %%
#https://www.youtube.com/watch?v=aLOQD66Sj0g&ab_channel=LianneandJustin
from xgboost import plot_importance

xgboost_step = model_xgb.best_estimator_.steps[1]
xgboost_model = xgboost_step[1]
plot_importance(xgboost_model, max_num_features=30)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
xgboost_model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=0.9425384185492701,
#               colsample_bynode=0.9095956806239844,
#               colsample_bytree=0.706128679361455, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=1.6598135411398998,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.7929828265552742,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=7, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=8, ...)

# %%
X_train_selected = pd.read_csv('/gpfs/milgram/project/rtaylor/imc33/data/pipeline/los_train_initial_selected_nonboarded_patients_cat_only.csv', index_col=[0])

# %%
X_val_selected = pd.read_csv('/gpfs/milgram/project/rtaylor/imc33/data/pipeline/los_val_initial_selected_nonboarded_patients_cat_only.csv', index_col=[0])

# %%
clf_xgb = xgb.XGBClassifier(objective='binary:logistic', missing=None, seed=42)
clf_xgb.fit(X_train_selected, 
            y_train['viz_outcome_prolonged_los_yn'], 
            verbose=True,
            early_stopping_rounds=10,
            eval_metric='aucpr',
            eval_set=[(X_val_selected, y_val['viz_outcome_prolonged_los_yn'])])
# Out:
# [0]	validation_0-aucpr:0.57411
# [1]	validation_0-aucpr:0.59032
# [2]	validation_0-aucpr:0.60142
# [3]	validation_0-aucpr:0.61148
# [4]	validation_0-aucpr:0.60678
# [5]	validation_0-aucpr:0.60998
# [6]	validation_0-aucpr:0.61144
# [7]	validation_0-aucpr:0.61529
# [8]	validation_0-aucpr:0.61752
# [9]	validation_0-aucpr:0.61428
# [10]	validation_0-aucpr:0.61573
# [11]	validation_0-aucpr:0.61856
# [12]	validation_0-aucpr:0.62158
# [13]	validation_0-aucpr:0.62443
# [14]	validation_0-aucpr:0.62600
# [15]	validation_0-aucpr:0.62521
# [16]	validation_0-aucpr:0.62440
# [17]	validation_0-aucpr:0.62349
# [18]	validation_0-aucpr:0.62805
# [19]	validation_0-aucpr:0.62874
# [20]	validation_0-aucpr:0.63470
# [21]	validation_0-aucpr:0.63795
# [22]	validation_0-aucpr:0.63663
# [23]	validation_0-aucpr:0.63716
# [24]	validation_0-aucpr:0.63813
# [25]	validation_0-aucpr:0.64001
# [26]	validation_0-aucpr:0.64116
# [27]	validation_0-aucpr:0.63788
# [28]	validation_0-aucpr:0.63866
# [29]	validation_0-aucpr:0.64026
# [30]	validation_0-aucpr:0.64532
# [31]	validation_0-aucpr:0.65009
# [32]	validation_0-aucpr:0.64866
# [33]	validation_0-aucpr:0.65070
# [34]	validation_0-aucpr:0.65037
# [35]	validation_0-aucpr:0.65084
# [36]	validation_0-aucpr:0.65162
# [37]	validation_0-aucpr:0.64963
# [38]	validation_0-aucpr:0.64847
# [39]	validation_0-aucpr:0.65173
# [40]	validation_0-aucpr:0.64979
# [41]	validation_0-aucpr:0.64990
# [42]	validation_0-aucpr:0.65068
# [43]	validation_0-aucpr:0.64866
# [44]	validation_0-aucpr:0.65135
# [45]	validation_0-aucpr:0.65220
# [46]	validation_0-aucpr:0.64974
# [47]	validation_0-aucpr:0.64899
# [48]	validation_0-aucpr:0.64710
# [49]	validation_0-aucpr:0.64759
# [50]	validation_0-aucpr:0.64754
# [51]	validation_0-aucpr:0.64715
# [52]	validation_0-aucpr:0.64630
# [53]	validation_0-aucpr:0.64694
# [54]	validation_0-aucpr:0.64869
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=None, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
explainer = shap.Explainer(clf_xgb)
shap_values = explainer(X_val_selected)

# %%
#1 shap value for each feature
np.shape(shap_values.values)
# Out:
# (1096, 291)

# %%
#This is for a single prediction
shap.plots.waterfall(shap_values[0])

# %%
shap.initjs(),
shap.plots.force(shap_values[0])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='i6G630N3YJTV775G0DYWI'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -0.2814614474773407, "outValue": 2.305809259414673, "link": "identity", "featureNames": ["viz_age", "summary_consult_count_all", "summary_consult_count_unique_services", "summary_pt_consult_order_yn", "con_signer_ym_provider_count", "con_signer_nemg_provider_count", "con_signer_community_provider_count", "con_service_addiction_medicine_count", "con_service_cardiology_count", "con_service_dermatology_count", "con_service_diabetes_count", "con_service_gastroenterology_count", "con_service_geriatrics_count", "con_service_hematology_count", "con_service_hospitalist_service_count", "con_service_icu_sdu_count", "con_service_infectious_disease_count", "con_service_nephrology_count", "con_service_neurology_count", "con_service_neurosurgery_count", "con_service_oncology_count", "con_service_orthopedics_count", "con_service_other_count", "con_service_otolaryngology_ent_count", "con_service_palliative_count", "con_service_pharmacy_count", "con_service_picc_count", "con_service_plastic_surgery_count", "con_service_podiatry_count", "con_service_psychiatry_count", "con_service_pulmonology_count", "con_service_radiology_count", "con_service_surgery_count", "con_service_urology_count", "con_service_vascular_surgery_count", "con_max_consult_order_to_sign_is_signer_ym_provider_yn", "con_max_consult_order_to_sign_is_signer_nemg_provider_yn", "con_max_consult_order_to_sign_is_signer_community_provider_yn", "con_max_consult_note_to_sign_is_signer_ym_provider_yn", "con_max_consult_note_to_sign_is_signer_nemg_provider_yn", "con_max_consult_note_to_sign_is_signer_community_provider_yn", "img_count_any", "img_count_ct", "img_count_mr", "img_count_us", "icu_any_icu_yn", "census_daily_inpt_count", "census_daily_ed_count", "viz_primary_payer_name_Medicare Traditional/Indemnity", "viz_primary_payer_name_Medicare/Managed Care", "viz_primary_payer_name_Commercial/Private Health Maintenance Organization (HMO)", "viz_primary_payer_name_Commercial/Private Traditional/Indemnity", "viz_primary_payer_name_Rare", "viz_primary_payer_name_Missing", "viz_disp_collapsed_Other", "viz_ethnicity_Hispanic Origin", "viz_ethnicity_Unknown", "viz_race_Black", "viz_race_Other", "viz_race_Asian", "viz_race_Unknown", "viz_race_collapsed_Non-White", "viz_language_Other", "viz_insurance_Medicaid", "viz_insurance_Commercial", "viz_service_collapsed_Medicine", "viz_service_collapsed_Surgical Services", "viz_service_collapsed_Cardiology", "viz_service_collapsed_Neurology", "viz_ynhhs_sg2_service_Infectious Disease - Medical", "viz_ynhhs_sg2_service_Rare", "viz_ynhhs_sg2_service_Digestive Health - Medical", "viz_ynhhs_sg2_service_General Medicine", "viz_ynhhs_sg2_service_Pulmonology", "viz_ynhhs_sg2_service_Nephrology", "viz_ynhhs_sg2_service_Orthopedics - Surgical", "viz_ynhhs_sg2_service_Cancer - Medical", "viz_drg_871", "viz_drg_Rare", "viz_drg_291", "viz_drg_193", "viz_drg_177", "viz_drg_189", "viz_drg_603", "viz_drg_392", "viz_drg_872", "viz_admission_day_Sat", "viz_admission_day_Thu", "viz_admission_day_Fri", "viz_admission_day_Tue", "viz_admission_day_Wed", "viz_discharged_day_Fri", "viz_discharged_day_Sat", "viz_discharged_day_Sun", "viz_discharged_day_Wed", "viz_discharged_day_Tue", "viz_discharged_day_Mon", "thro_ed_arrival_time_Afternoon", "thro_ed_arrival_time_Morning", "thro_ed_arrival_time_Night", "thro_ed_arrival_day_Sun", "thro_ed_arrival_day_Mon", "thro_admit_or_obs_order_time_Night", "thro_admit_or_obs_order_time_Afternoon", "thro_admit_or_obs_order_time_Morning", "thro_admit_or_obs_order_day_Mon", "thro_admit_or_obs_order_day_Tue", "thro_first_bed_assigned_time_Afternoon", "thro_first_bed_assigned_time_Morning", "thro_first_bed_assigned_time_Missing", "thro_first_bed_assigned_day_Wed", "thro_last_bed_assigned_time_Night", "thro_last_bed_assigned_day_Sun", "thro_last_bed_assigned_day_Thu", "thro_last_bed_assigned_day_Fri", "thro_last_bed_assigned_day_Sat", "thro_ed_departu ...

# %%
shap.plots.force(shap_values[0:100])
# Out:
# <div id='iIEUQH2V8AFRYHXIJ1OF9'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceArrayVisualizer, {"outNames": ["f(x)"], "baseValue": -0.2814614474773407, "link": "identity", "featureNames": ["viz_age", "summary_consult_count_all", "summary_consult_count_unique_services", "summary_pt_consult_order_yn", "con_signer_ym_provider_count", "con_signer_nemg_provider_count", "con_signer_community_provider_count", "con_service_addiction_medicine_count", "con_service_cardiology_count", "con_service_dermatology_count", "con_service_diabetes_count", "con_service_gastroenterology_count", "con_service_geriatrics_count", "con_service_hematology_count", "con_service_hospitalist_service_count", "con_service_icu_sdu_count", "con_service_infectious_disease_count", "con_service_nephrology_count", "con_service_neurology_count", "con_service_neurosurgery_count", "con_service_oncology_count", "con_service_orthopedics_count", "con_service_other_count", "con_service_otolaryngology_ent_count", "con_service_palliative_count", "con_service_pharmacy_count", "con_service_picc_count", "con_service_plastic_surgery_count", "con_service_podiatry_count", "con_service_psychiatry_count", "con_service_pulmonology_count", "con_service_radiology_count", "con_service_surgery_count", "con_service_urology_count", "con_service_vascular_surgery_count", "con_max_consult_order_to_sign_is_signer_ym_provider_yn", "con_max_consult_order_to_sign_is_signer_nemg_provider_yn", "con_max_consult_order_to_sign_is_signer_community_provider_yn", "con_max_consult_note_to_sign_is_signer_ym_provider_yn", "con_max_consult_note_to_sign_is_signer_nemg_provider_yn", "con_max_consult_note_to_sign_is_signer_community_provider_yn", "img_count_any", "img_count_ct", "img_count_mr", "img_count_us", "icu_any_icu_yn", "census_daily_inpt_count", "census_daily_ed_count", "viz_primary_payer_name_Medicare Traditional/Indemnity", "viz_primary_payer_name_Medicare/Managed Care", "viz_primary_payer_name_Commercial/Private Health Maintenance Organization (HMO)", "viz_primary_payer_name_Commercial/Private Traditional/Indemnity", "viz_primary_payer_name_Rare", "viz_primary_payer_name_Missing", "viz_disp_collapsed_Other", "viz_ethnicity_Hispanic Origin", "viz_ethnicity_Unknown", "viz_race_Black", "viz_race_Other", "viz_race_Asian", "viz_race_Unknown", "viz_race_collapsed_Non-White", "viz_language_Other", "viz_insurance_Medicaid", "viz_insurance_Commercial", "viz_service_collapsed_Medicine", "viz_service_collapsed_Surgical Services", "viz_service_collapsed_Cardiology", "viz_service_collapsed_Neurology", "viz_ynhhs_sg2_service_Infectious Disease - Medical", "viz_ynhhs_sg2_service_Rare", "viz_ynhhs_sg2_service_Digestive Health - Medical", "viz_ynhhs_sg2_service_General Medicine", "viz_ynhhs_sg2_service_Pulmonology", "viz_ynhhs_sg2_service_Nephrology", "viz_ynhhs_sg2_service_Orthopedics - Surgical", "viz_ynhhs_sg2_service_Cancer - Medical", "viz_drg_871", "viz_drg_Rare", "viz_drg_291", "viz_drg_193", "viz_drg_177", "viz_drg_189", "viz_drg_603", "viz_drg_392", "viz_drg_872", "viz_admission_day_Sat", "viz_admission_day_Thu", "viz_admission_day_Fri", "viz_admission_day_Tue", "viz_admission_day_Wed", "viz_discharged_day_Fri", "viz_discharged_day_Sat", "viz_discharged_day_Sun", "viz_discharged_day_Wed", "viz_discharged_day_Tue", "viz_discharged_day_Mon", "thro_ed_arrival_time_Afternoon", "thro_ed_arrival_time_Morning", "thro_ed_arrival_time_Night", "thro_ed_arrival_day_Sun", "thro_ed_arrival_day_Mon", "thro_admit_or_obs_order_time_Night", "thro_admit_or_obs_order_time_Afternoon", "thro_admit_or_obs_order_time_Morning", "thro_admit_or_obs_order_day_Mon", "thro_admit_or_obs_order_day_Tue", "thro_first_bed_assigned_time_Afternoon", "thro_first_bed_assigned_time_Morning", "thro_first_bed_assigned_time_Missing", "thro_first_bed_assigned_day_Wed", "thro_last_bed_assigned_time_Night", "thro_last_bed_assigned_day_Sun", "thro_last_bed_assigned_day_Thu", "thro_last_bed_assigned_day_Fri", "thro_last_bed_assigned_day_Sat", "thro_ed_departure_time_Night", "thro_ed_d ...

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values, max_display=30)

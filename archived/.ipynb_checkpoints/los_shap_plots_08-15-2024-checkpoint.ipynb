# %%
## This version excludes CONTINUOUS Variables and the RFD variables AND _wHICH VARIABLES 3/27/2024 and con_max_consultorder_time/day and drg name
## 4/4/2024 Added QUINTILE variables
## 4/8/2024 Added QUINTILE varables by service
## 4/9/2024 Added more consult and imaging variables (e.g. ad,it order to consult order, admit order to imaging read)
## 4/11/2024 Added QUINTILE variables by service for the additional variables
# 06/12/2024: Added gender, added imaging_order_before_consult_order and consult_order_before_imaging order variables, excluded 290 patients in 2022, dropped raw race/insurance categories
# 06/14/2024: Removed quintiles
# 06/20/2024: Set seed for reproducibility
# 06/22/2024: Added sample size for validation
# 07/05/2024: Collapsed Cardiology into Medicine
# 07/08/2024: Added labels
# 07/25/2024: Removed duplicated patients from master file
# 08/01/2024: Changed XGBoost hyperparmeter tuning to Haipeng's code and using only one model, streamlined so all shap plots in one jupyter notebook
# 08/07/2024: Added continuous features, add discretizer and removed variables >=99% missing 
# 08/15/2024: Added viz_right_service_hf_yn variable

# %%
import pandas as pd
import numpy as np
import os
import warnings
from los_functions_v2 import *
warnings.filterwarnings('ignore')

# %%
#all hospitalized patients 
df_all = pd.read_csv('/gpfs/milgram/project/rtaylor/imc33/LOS/data/master_los.csv', index_col=[0])
df_all["viz_service_collapsed"] = df_all["viz_service_collapsed"].apply(map_med)

#discharged home
df_home = df_all[df_all["viz_disp_collapsed"] == "Home"].copy()

#hf patients
df_all = pd.read_csv('/gpfs/milgram/project/rtaylor/imc33/LOS/data/master_los.csv', index_col=[0])
df_hf = df_all[df_all["viz_drg"]=="heart failure & shock w mcc"].copy()

# %%
# Dictionary of data frames with their names
dfs = {
    "df_all": df_all,
    "df_home": df_home,
    "df_hf":df_hf
}

fp_simple = '/gpfs/milgram/project/rtaylor/imc33/LOS/data/features_los_simple.xlsx'
fp_complex = '/gpfs/milgram/project/rtaylor/imc33/LOS/data/features_los.xlsx'
fp_continuous = '/gpfs/milgram/project/rtaylor/imc33/LOS/data/features_los_continuous.xlsx'
output_folder = '/gpfs/milgram/project/rtaylor/imc33/LOS/output'

# %% [markdown]
# ### Simple (without quintiles)

# %%
# Run the function for each data frame and save the plots
for df_name, df_filt in dfs.items():
    print(f"Running on {df_name}")
    run_xgb_and_plot(df_filt, fp_simple, output_folder, df_name, suffix="simple")
# Out:
# Running on df_all
# df_filt shape: (12771, 911)
# X train_preprocessed shape: (10246, 318)
# X val preprocessed shape: (2525, 318)
# y train prolonged LOS proportion: 0.4388053874682803
# y val prolonged LOS proportion: 0.4304950495049505
# X_train_selected shape: (10246, 213)
# X_val_selected shape: (2525, 213)
# 100%|██████████| 20/20 [00:15<00:00,  1.32trial/s, best loss: -0.7592425475434327]
# XGB Best parameters for 213 features: {'colsample_by_tree': 0.6425936901635491, 'learning_rate': 0.13914887471932533, 'max_depth': 14, 'n_estimators': 29, 'num_leaves': 35, 'reg_lambda': 0.8474645439246081}
# Specificity : 0.7719
# Sensitivity : 0.6053
# Accuracy : 0.7002
# Precision : 0.6673
# F1 score : 0.6348
# Of 1438 people who did not have a prolonged LOS, 1110 (77.19%) were correctly classified.
# Of 1087 people who did have a prolonged LOS, 658 (60.53%) were correctly classified.
# summary_consult_count_all
# summary_first_rfd_status_No
# img_count_any
# viz_right_service_collapsed_yn
# viz_disp_collapsed_Other
# viz_drg_Respiratory infections & inflammations w mcc
# viz_drg_Septicemia or severe sepsis w/o mv >96 hours w mcc
# thro_ed_arrival_time_Afternoon
# viz_age
# summary_consult_count_unique_services
# summary_last_rfd_status_No
# con_service_gastroenterology_count
# img_count_us
# census_daily_ed_count
# viz_drg_Septicemia or severe sepsis w/o mv >96 hours w/o mcc
# summary_last_edd_doc_time_Morning
# viz_admission_day_Fri
# thro_last_bed_assigned_time_Morning
# census_daily_inpt_count
# summary_first_rfd_day_Mon
# viz_insurance_Medicare
# viz_ynhhs_sg2_service_Digestive Health - Medical
# viz_service_collapsed_Surgical Services
# thro_boarding_yn
# img_count_ct
# viz_discharged_day_Mon
# viz_discharged_day_Sat
# viz_gender_Female
# con_signer_ym_provider_count
# thro_ed_arrival_time_Night
# Plots for df_all_simple_2024-08-07 saved to /gpfs/milgram/project/rtaylor/imc33/LOS/output
# Running on df_home
# df_filt shape: (4749, 911)
# X train_preprocessed shape: (3814, 306)
# X val preprocessed shape: (935, 306)
# y train prolonged LOS proportion: 0.3618248557944415
# y val prolonged LOS proportion: 0.32192513368983955
# X_train_selected shape: (3814, 203)
# X_val_selected shape: (935, 203)
# 100%|██████████| 20/20 [00:09<00:00,  2.12trial/s, best loss: -0.7913259569588205]
# XGB Best parameters for 203 features: {'colsample_by_tree': 0.6425936901635491, 'learning_rate': 0.13914887471932533, 'max_depth': 14, 'n_estimators': 29, 'num_leaves': 35, 'reg_lambda': 0.8474645439246081}
# Specificity : 0.8707
# Sensitivity : 0.5017
# Accuracy : 0.7519
# Precision : 0.6481
# F1 score : 0.5655
# Of 634 people who did not have a prolonged LOS, 552 (87.07%) were correctly classified.
# Of 301 people who did have a prolonged LOS, 151 (50.17%) were correctly classified.
# summary_first_rfd_status_No
# summary_consult_count_all
# thro_ed_arrival_time_Afternoon
# viz_age
# viz_drg_Septicemia or severe sepsis w/o mv >96 hours w mcc
# img_count_any
# census_daily_ed_count
# viz_drg_Septicemia or severe sepsis w/o mv >96 hours w/o mcc
# img_count_us
# census_daily_inpt_count
# viz_drg_Respiratory infections & inflammations w mcc
# summary_first_edd_doc_day_Mon
# con_service_radiology_count
# summary_last_edd_doc_time_Morning
# summary_last_rfd_status_No
# summary_last_edd_doc_day_Mon
# viz_ynhhs_sg2_service_Digestive Health - Medical
# summary_first_rfd_day_Mon
# thro_ed_arrival_time_Night
# summary_last_rfd_day_Tue
# viz_discharged_day_Fri
# viz_admission_day_Thu
# viz_admission_day_Fri
# con_service_gastroenterology_count
# summary_first_edd_doc_day_Thu
# img_count_ct
# viz_ynhhs_sg2_service_Infectious Disease - Medical
# viz_ynhhs_sg2_service_Rare
# con_max_consult_note_creation_time_Morning
# viz_insurance_Managed Medicare
# Plots for df_home_simple_2024-08-07 saved to /gpfs/milgram/project/rtaylor/imc33/LOS/output
# Running on df_hf
# df_filt shape: (1351, 911)
# X train_preprocessed shape: (1091, 287)
# X val preprocessed shape: (260, 287)
# y train prolonged LOS proportion: 0.44912923923006415
# y val prolonged LOS proportion: 0.4576923076923077
# X_train_selected shape: (1091, 174)
# X_val_selected shape: (260, 174)
# 100%|██████████| 20/20 [00:06<00:00,  3.14trial/s, best loss: -0.7148035081801314]
# XGB Best parameters for 174 features: {'colsample_by_tree': 0.6565004189886763, 'learning_rate': 0.29938202228220967, 'max_depth': 7, 'n_estimators': 33, 'num_leaves': 47, 'reg_lambda': 0.5464002904734102}
# Specificity : 0.7163
# Sensitivity : 0.6471
# Accuracy : 0.6846
# Precision : 0.6581
# F1 score : 0.6525
# Of 141 people who did not have a prolonged LOS, 101 (71.63%) were correctly classified.
# Of 119 people who did have a prolonged LOS, 77 (64.71%) were correctly classified.
# census_daily_ed_count
# viz_gender_Female
# summary_first_rfd_status_No
# img_count_any
# img_count_us
# viz_age
# summary_consult_count_all
# summary_consult_count_unique_services
# thro_ed_arrival_time_Afternoon
# thro_first_bed_assigned_time_Afternoon
# thro_first_bed_assigned_time_Night
# viz_disp_collapsed_Home
# summary_last_rfd_day_Wed
# con_signer_ym_provider_count
# summary_first_edd_day_Wed
# summary_first_edd_day_Mon
# summary_first_rfd_status_Yes, no barriers
# summary_first_rfd_day_Mon
# summary_last_edd_day_Fri
# con_max_consult_note_creation_day_Mon
# thro_admit_or_obs_order_day_Sun
# con_service_cardiology_count
# viz_admission_day_Mon
# viz_discharged_day_Tue
# census_daily_inpt_count
# summary_last_edd_day_Mon
# summary_last_rfd_status_Yes, no barriers
# con_service_palliative_count
# summary_last_rfd_day_Tue
# thro_boarding_yn
# Plots for df_hf_simple_2024-08-07 saved to /gpfs/milgram/project/rtaylor/imc33/LOS/output

# %% [markdown]
# ### With Quintiles

# %%
# Run the function for each data frame and save the plots
for df_name, df_filt in dfs.items():
    print(f"Running on {df_name}")
    run_xgb_and_plot(df_filt, fp_complex, output_folder, df_name, suffix="with_quintiles")
# Out:
# Running on df_all
# df_filt shape: (12771, 911)
# X train_preprocessed shape: (10246, 1560)
# X val preprocessed shape: (2525, 1560)
# y train prolonged LOS proportion: 0.4388053874682803
# y val prolonged LOS proportion: 0.4304950495049505
# X_train_selected shape: (10246, 615)
# X_val_selected shape: (2525, 615)
# 100%|██████████| 20/20 [00:34<00:00,  1.70s/trial, best loss: -0.8012540650105056]
# XGB Best parameters for 615 features: {'colsample_by_tree': 0.6425936901635491, 'learning_rate': 0.13914887471932533, 'max_depth': 14, 'n_estimators': 29, 'num_leaves': 35, 'reg_lambda': 0.8474645439246081}
# Specificity : 0.8345
# Sensitivity : 0.6127
# Accuracy : 0.7390
# Precision : 0.7367
# F1 score : 0.6690
# Of 1438 people who did not have a prolonged LOS, 1200 (83.45%) were correctly classified.
# Of 1087 people who did have a prolonged LOS, 666 (61.27%) were correctly classified.
# img_max_admit_order_to_imaging_order_any_quintile_5.0
# summary_first_rfd_status_No
# summary_consult_count_all
# con_max_admit_order_to_consult_order_any_quintile_5.0
# viz_drg_Respiratory infections & inflammations w mcc
# viz_right_service_collapsed_yn
# viz_drg_Septicemia or severe sepsis w/o mv >96 hours w mcc
# img_avg_admit_order_to_imaging_order_any_quintile_5.0
# con_avg_admit_order_to_consult_order_any_quintile_5.0
# con_avg_admit_order_to_consult_completion_any_quintile_5.0
# viz_age
# thro_ed_arrival_time_Afternoon
# viz_disp_collapsed_Other
# summary_last_rfd_status_No
# img_max_admit_order_to_imaging_order_any_quintile_4.0
# summary_last_edd_doc_time_Morning
# con_max_admit_order_to_consult_completion_any_quintile_4.0
# viz_service_collapsed_Surgical Services
# viz_service_collapsed_Medicine
# con_max_admit_order_to_consult_order_any_quintile_4.0
# img_max_order_to_completion_any_quintile_5.0
# con_avg_admit_order_to_consult_order_any_quintile_4.0
# viz_drg_Septicemia or severe sepsis w/o mv >96 hours w/o mcc
# viz_ynhhs_sg2_service_Digestive Health - Medical
# con_avg_admit_order_to_consult_completion_any_quintile_4.0
# con_avg_consult_order_to_sign_any_quintile_5.0
# thro_ed_arrival_time_Night
# summary_first_rfd_day_Mon
# viz_insurance_Medicare
# summary_last_edd_doc_day_Mon
# Plots for df_all_with_quintiles_2024-08-07 saved to /gpfs/milgram/project/rtaylor/imc33/LOS/output
# Running on df_home
# df_filt shape: (4749, 911)
# X train_preprocessed shape: (3814, 1356)
# X val preprocessed shape: (935, 1356)
# y train prolonged LOS proportion: 0.3618248557944415
# y val prolonged LOS proportion: 0.32192513368983955
# X_train_selected shape: (3814, 522)
# X_val_selected shape: (935, 522)
# 100%|██████████| 20/20 [00:19<00:00,  1.01trial/s, best loss: -0.8117679577159056]
# XGB Best parameters for 522 features: {'colsample_by_tree': 0.6425936901635491, 'learning_rate': 0.13914887471932533, 'max_depth': 14, 'n_estimators': 29, 'num_leaves': 35, 'reg_lambda': 0.8474645439246081}
# Specificity : 0.8991
# Sensitivity : 0.5415
# Accuracy : 0.7840
# Precision : 0.7181
# F1 score : 0.6174
# Of 634 people who did not have a prolonged LOS, 570 (89.91%) were correctly classified.
# Of 301 people who did have a prolonged LOS, 163 (54.15%) were correctly classified.
# summary_first_rfd_status_No
# img_max_admit_order_to_imaging_order_any_quintile_5.0
# summary_consult_count_all
# img_max_admit_order_to_imaging_order_any_quintile_4.0
# viz_drg_Septicemia or severe sepsis w/o mv >96 hours w mcc
# viz_age
# thro_ed_arrival_time_Afternoon
# census_daily_ed_count
# viz_drg_Septicemia or severe sepsis w/o mv >96 hours w/o mcc
# viz_drg_Respiratory infections & inflammations w mcc
# viz_ynhhs_sg2_service_Digestive Health - Medical
# summary_first_rfd_day_Mon
# summary_first_edd_doc_day_Mon
# thro_ed_arrival_time_Night
# con_max_admit_order_to_consult_completion_any_quintile_4.0
# summary_last_edd_doc_day_Mon
# viz_ynhhs_sg2_service_Infectious Disease - Medical
# census_daily_inpt_count
# summary_last_rfd_status_No
# viz_drg_Rare
# con_max_admit_order_to_consult_order_any_quintile_4.0
# summary_last_rfd_day_Tue
# img_max_order_to_completion_any_quintile_5.0
# viz_drg_Cellulitis w/o mcc
# viz_discharged_day_Sun
# summary_first_edd_time_Night
# viz_ynhhs_sg2_service_Rare
# viz_admission_day_Thu
# con_avg_admit_order_to_consult_order_any_quintile_5.0
# con_avg_admit_order_to_consult_completion_any_quintile_4.0
# Plots for df_home_with_quintiles_2024-08-07 saved to /gpfs/milgram/project/rtaylor/imc33/LOS/output
# Running on df_hf
# df_filt shape: (1351, 911)
# X train_preprocessed shape: (1091, 1320)
# X val preprocessed shape: (260, 1320)
# y train prolonged LOS proportion: 0.44912923923006415
# y val prolonged LOS proportion: 0.4576923076923077
# X_train_selected shape: (1091, 448)
# X_val_selected shape: (260, 448)
# 100%|██████████| 20/20 [00:12<00:00,  1.59trial/s, best loss: -0.7526811716422105]
# XGB Best parameters for 448 features: {'colsample_by_tree': 0.997027695705137, 'learning_rate': 0.2686350001914848, 'max_depth': 9, 'n_estimators': 8, 'num_leaves': 47, 'reg_lambda': 0.501868580702795}
# Specificity : 0.7872
# Sensitivity : 0.5714
# Accuracy : 0.6885
# Precision : 0.6939
# F1 score : 0.6267
# Of 141 people who did not have a prolonged LOS, 111 (78.72%) were correctly classified.
# Of 119 people who did have a prolonged LOS, 68 (57.14%) were correctly classified.
# img_max_admit_order_to_imaging_order_any_quintile_5.0
# con_avg_admit_order_to_consult_order_any_quintile_5.0
# census_daily_ed_count
# summary_first_rfd_status_No
# con_avg_admit_order_to_consult_completion_cardiology_quintile_1.0
# viz_discharged_day_Tue
# con_avg_admit_order_to_consult_order_any_quintile_4.0
# thro_first_bed_assigned_time_Night
# viz_gender_Female
# viz_age
# summary_first_rfd_status_Yes, no barriers
# img_max_order_to_completion_any_quintile_5.0
# thro_ed_arrival_time_Night
# summary_last_rfd_status_No
# con_max_consult_order_to_sign_cardiology_quintile_2.0
# thro_ed_arrival_time_Afternoon
# thro_admit_or_obs_order_day_Sun
# img_count_any
# summary_consult_count_all
# con_max_admit_order_to_consult_order_any_quintile_5.0
# thro_ed_arrival_time_Morning
# img_max_admit_order_to_imaging_read_any_quintile_4.0
# con_service_palliative_count
# img_avg_admit_order_to_imaging_order_any_quintile_5.0
# con_avg_admit_order_to_consult_completion_any_quintile_4.0
# img_max_admit_order_to_imaging_order_any_quintile_4.0
# con_signer_ym_provider_count
# summary_last_edd_doc_day_Mon
# con_signer_nemg_provider_count
# viz_admission_day_Mon
# Plots for df_hf_with_quintiles_2024-08-07 saved to /gpfs/milgram/project/rtaylor/imc33/LOS/output

# %% [markdown]
# ### With Continuous Features

# %%
# Run the function for each data frame and save the plots
for df_name, df_filt in dfs.items():
    print(f"Running on {df_name}")
    run_xgb_continuous_and_plot(df_filt, fp_continuous, output_folder, df_name, suffix="continuous")
# Out:
# Running on df_all
# df_filt shape: (12771, 911)
# X train_preprocessed shape: (10246, 853)
# X val preprocessed shape: (2525, 853)
# y train prolonged LOS proportion: 0.4388053874682803
# y val prolonged LOS proportion: 0.4304950495049505
# X_train_selected shape: (10246, 371)
# X_val_selected shape: (2525, 371)
# 100%|██████████| 20/20 [00:56<00:00,  2.83s/trial, best loss: -0.8894363633237145]
# XGB Best parameters for 371 features: {'colsample_by_tree': 0.6565004189886763, 'learning_rate': 0.29938202228220967, 'max_depth': 7, 'n_estimators': 33, 'num_leaves': 47, 'reg_lambda': 0.5464002904734102}
# Specificity : 0.8268
# Sensitivity : 0.7930
# Accuracy : 0.8123
# Precision : 0.7759
# F1 score : 0.7843
# Of 1438 people who did not have a prolonged LOS, 1189 (82.68%) were correctly classified.
# Of 1087 people who did have a prolonged LOS, 862 (79.30%) were correctly classified.
# summary_first_rfd_to_discharge_hrs
# summary_total_hrs_nmr
# summary_first_edd_to_discharge_hrs
# viz_drg_Septicemia or severe sepsis w/o mv >96 hours w mcc
# viz_drg_Respiratory infections & inflammations w mcc
# viz_age
# viz_right_service_collapsed_yn
# viz_service_collapsed_Medicine
# thro_ed_arrival_time_Afternoon
# thro_door_to_admit_order_hrs
# thro_admit_order_to_ed_dept_hrs
# viz_disp_collapsed_Other
# viz_drg_Rare
# summary_first_rfd_day_Mon
# icu_any_icu_yn
# viz_service_collapsed_Surgical Services
# viz_drg_Esophagitis, gastroent & misc digest disorders w/o mcc
# con_max_admit_order_to_consult_order_any_hrs
# viz_admission_day_Fri
# img_avg_admit_order_to_imaging_read_any_hrs
# summary_last_edd_to_discharge_hrs
# img_avg_admit_order_to_imaging_order_any_hrs
# viz_ynhhs_sg2_service_Digestive Health - Medical
# thro_admit_order_to_first_bed_hrs
# summary_first_rfd_status_na
# thro_ed_departure_day_Fri
# summary_first_edd_doc_day_Mon
# viz_drg_Cellulitis w/o mcc
# rfd_last_nmr_to_discharge_hrs
# con_avg_admit_order_to_consult_completion_any_hrs
# Plots for df_all_continuous_2024-08-07 saved to /gpfs/milgram/project/rtaylor/imc33/LOS/output
# Running on df_home
# df_filt shape: (4749, 911)
# X train_preprocessed shape: (3814, 773)
# X val preprocessed shape: (935, 773)
# y train prolonged LOS proportion: 0.3618248557944415
# y val prolonged LOS proportion: 0.32192513368983955
# X_train_selected shape: (3814, 338)
# X_val_selected shape: (935, 338)
# 100%|██████████| 20/20 [00:26<00:00,  1.33s/trial, best loss: -0.8997619413267653]
# XGB Best parameters for 338 features: {'colsample_by_tree': 0.6565004189886763, 'learning_rate': 0.29938202228220967, 'max_depth': 7, 'n_estimators': 33, 'num_leaves': 47, 'reg_lambda': 0.5464002904734102}
# Specificity : 0.8912
# Sensitivity : 0.7841
# Accuracy : 0.8567
# Precision : 0.7738
# F1 score : 0.7789
# Of 634 people who did not have a prolonged LOS, 565 (89.12%) were correctly classified.
# Of 301 people who did have a prolonged LOS, 236 (78.41%) were correctly classified.
# summary_first_rfd_to_discharge_hrs
# summary_first_rfd_day_Mon
# summary_first_edd_to_discharge_hrs
# thro_admit_order_to_ed_dept_hrs
# viz_age
# viz_drg_Septicemia or severe sepsis w/o mv >96 hours w mcc
# thro_door_to_admit_order_hrs
# summary_last_edd_doc_to_discharge_hrs
# summary_first_edd_doc_to_discharge_hrs
# img_avg_admit_order_to_imaging_order_any_hrs
# thro_ed_arrival_time_Afternoon
# viz_drg_Esophagitis, gastroent & misc digest disorders w/o mcc
# viz_drg_Respiratory infections & inflammations w mcc
# viz_drg_Septicemia or severe sepsis w/o mv >96 hours w/o mcc
# viz_drg_Cellulitis w/o mcc
# census_daily_ed_count
# summary_last_edd_to_discharge_hrs
# viz_drg_Rare
# thro_admit_or_obs_order_day_Fri
# viz_ynhhs_sg2_service_Digestive Health - Medical
# con_max_admit_order_to_consult_order_any_hrs
# thro_ed_arrival_time_Night
# img_max_admit_order_to_imaging_order_ct_hrs
# img_max_order_to_read_any_hrs
# census_daily_inpt_count
# summary_first_rfd_status_na
# thro_admit_order_to_first_bed_hrs
# viz_admission_day_Sun
# viz_ynhhs_sg2_service_Rare
# summary_first_rfd_day_Wed
# Plots for df_home_continuous_2024-08-07 saved to /gpfs/milgram/project/rtaylor/imc33/LOS/output
# Running on df_hf
# df_filt shape: (1351, 911)
# X train_preprocessed shape: (1091, 730)
# X val preprocessed shape: (260, 730)
# y train prolonged LOS proportion: 0.44912923923006415
# y val prolonged LOS proportion: 0.4576923076923077
# X_train_selected shape: (1091, 292)
# X_val_selected shape: (260, 292)
# 100%|██████████| 20/20 [00:13<00:00,  1.51trial/s, best loss: -0.8779791420700512]
# XGB Best parameters for 292 features: {'colsample_by_tree': 0.6098851658750725, 'learning_rate': 0.12756984422442919, 'max_depth': 8, 'n_estimators': 20, 'num_leaves': 19, 'reg_lambda': 0.4078503245770707}
# Specificity : 0.8652
# Sensitivity : 0.7479
# Accuracy : 0.8115
# Precision : 0.8241
# F1 score : 0.7841
# Of 141 people who did not have a prolonged LOS, 122 (86.52%) were correctly classified.
# Of 119 people who did have a prolonged LOS, 89 (74.79%) were correctly classified.
# rfd_first_nmr_to_discharge_hrs
# summary_total_hrs_nmr
# thro_door_to_admit_order_hrs
# img_max_admit_order_to_imaging_read_any_hrs
# summary_first_edd_to_discharge_hrs
# viz_age
# census_daily_ed_count
# con_avg_admit_order_to_consult_order_any_hrs
# thro_last_bed_to_ed_dept_hrs
# thro_admit_order_to_ed_dept_hrs
# img_max_order_to_completion_ct_hrs
# summary_last_rfd_to_discharge_hrs
# summary_last_edd_doc_to_discharge_hrs
# img_avg_admit_order_to_imaging_read_us_hrs
# img_max_admit_order_to_imaging_order_us_hrs
# img_avg_admit_order_to_imaging_order_any_hrs
# con_avg_admit_order_to_consult_completion_any_hrs
# summary_consult_count_unique_services
# viz_disp_collapsed_Home
# rfd_first_mrnb_to_discharge_hrs
# thro_admit_order_to_first_bed_hrs
# summary_last_edd_to_discharge_hrs
# summary_total_hrs_mrwb
# img_avg_admit_order_to_imaging_read_ct_hrs
# img_avg_order_to_read_ct_hrs
# con_max_date_note_signed_day2_Thu
# con_max_consult_order_to_sign_any_hrs
# summary_consult_count_all
# rfd_last_nmr_to_discharge_hrs
# thro_first_bed_assigned_day_Fri
# Plots for df_hf_continuous_2024-08-07 saved to /gpfs/milgram/project/rtaylor/imc33/LOS/output

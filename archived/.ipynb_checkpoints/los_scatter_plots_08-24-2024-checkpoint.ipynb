# %%
import pandas as pd
import numpy as np
import os
import warnings
from los_functions_v2 import *
warnings.filterwarnings('ignore')

# %%
#all hospitalized patients 
df_all = pd.read_csv('/gpfs/milgram/project/rtaylor/imc33/LOS/data/master_los.csv', index_col=[0])
df_all["viz_service_collapsed"] = df_all["viz_service_collapsed"].apply(map_med)

#discharged home
df_home = df_all[df_all["viz_disp_collapsed"] == "Home"].copy()

#hf patients
df_all = pd.read_csv('/gpfs/milgram/project/rtaylor/imc33/LOS/data/master_los.csv', index_col=[0])
df_hf = df_all[df_all["viz_drg"]=="heart failure & shock w mcc"].copy()

# %%
# Dictionary of data frames with their names
dfs = {
    "df_all": df_all,
    "df_home": df_home,
    "df_hf":df_hf
}

fp_simple = '/gpfs/milgram/project/rtaylor/imc33/LOS/data/features_los_simple.xlsx'
fp_complex = '/gpfs/milgram/project/rtaylor/imc33/LOS/data/features_los.xlsx'
fp_continuous = '/gpfs/milgram/project/rtaylor/imc33/LOS/data/features_los_continuous.xlsx'
output_folder = '/gpfs/milgram/project/rtaylor/imc33/LOS/output'

# %%
X_train_preprocessed, X_val_preprocessed, y_train, y_val = preprocess_continuous_features(fp_continuous, df_all)
X_train_selected, X_val_selected = select_features(X_train_preprocessed, X_val_preprocessed, y_train)
model_xgb = run_xgb_tune_fit_1b(X_train_selected, y_train, num_eval=20)
# Out:
# df_filt shape: (12771, 911)
# X train_preprocessed shape: (10246, 853)
# X val preprocessed shape: (2525, 853)
# y train prolonged LOS proportion: 0.4388053874682803
# y val prolonged LOS proportion: 0.4304950495049505
# X_train_selected shape: (10246, 371)
# X_val_selected shape: (2525, 371)
# 100%|██████████| 20/20 [00:56<00:00,  2.82s/trial, best loss: -0.8880499857598083]
# XGB Best parameters for 371 features: {'colsample_by_tree': 0.6565004189886763, 'learning_rate': 0.29938202228220967, 'max_depth': 7, 'n_estimators': 33, 'num_leaves': 47, 'reg_lambda': 0.5464002904734102}

# %%
np.random.seed(42)
explainer = shap.Explainer(model_xgb)
shap_values = explainer(X_val_selected)

# %%
#for col in X_val_selected.columns:
#    print(col)

# %%
shap.plots.scatter(shap_values[:, "viz_age"])

# %%
shap.plots.scatter(shap_values[:, "viz_age"], color=shap_values)

# %%
variables = [
    'con_max_admit_order_to_consult_order_any_hrs',
    'con_max_consult_order_to_sign_any_hrs',
  #  'con_max_admit_order_to_consult_completion_any_hrs',
    'img_max_admit_order_to_imaging_order_any_hrs',
    'img_max_order_to_completion_any_hrs',
    'img_max_order_to_read_any_hrs',
    'img_max_admit_order_to_imaging_read_any_hrs'
]

# %%
for var in variables:
    shap.plots.scatter(shap_values[:, var], color=shap_values)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 for var in variables:
# ----> 2     shap.plots.scatter(shap_values[:, var], color=shap_values)
#
# File /gpfs/milgram/project/hwang/imc33/conda_envs/aitc/lib/python3.8/site-packages/shap/_explanation.py:418, in Explanation.__getitem__(self, item)
#     416 if new_self is None:
#     417     new_self = copy.copy(self)
# --> 418 new_self._s = new_self._s.__getitem__(item)
#     419 new_self.op_history.append({
#     420     "name": "__getitem__",
#     421     "args": (item,),
#     422     "prev_shape": self.shape
#     423 })
#     425 return new_self
#
# File /gpfs/milgram/project/hwang/imc33/conda_envs/aitc/lib/python3.8/site-packages/slicer/slicer.py:112, in Slicer.__getitem__(self, item)
#     110 index_slicer = AtomicSlicer(index_tup, max_dim=1)
#     111 slicer_index = index_slicer[tracked.dim]
# --> 112 sliced_o = tracked[slicer_index]
#     113 sliced_dim = resolve_dim(index_tup, tracked.dim)
#     115 new_tracked = tracked.__class__(sliced_o, sliced_dim)
#
# File /gpfs/milgram/project/hwang/imc33/conda_envs/aitc/lib/python3.8/site-packages/slicer/slicer_internal.py:69, in AtomicSlicer.__getitem__(self, item)
#      66 index_tup = unify_slice(item, self.max_dim)
#      68 # Slice according to object type.
# ---> 69 return UnifiedDataHandler.slice(self.o, index_tup, self.max_dim)
#
# File /gpfs/milgram/project/hwang/imc33/conda_envs/aitc/lib/python3.8/site-packages/slicer/slicer_internal.py:583, in UnifiedDataHandler.slice(cls, o, index_tup, max_dim)
#     580 tail_slice = cls.type_map[o_type].tail_slice
#     582 is_element, sliced_o, cut = head_slice(o, index_tup, max_dim)
# --> 583 out = tail_slice(sliced_o, index_tup[cut:], max_dim - cut, is_element)
#     584 return out
#
# File /gpfs/milgram/project/hwang/imc33/conda_envs/aitc/lib/python3.8/site-packages/slicer/slicer_internal.py:439, in ArrayHandler.tail_slice(cls, o, tail_index, max_dim, flatten)
#     437         return AtomicSlicer(o, max_dim=max_dim)[tail_index]
#     438 else:
# --> 439     inner = [AtomicSlicer(e, max_dim=max_dim)[tail_index] for e in o]
#     440     if _safe_isinstance(o, "numpy", "ndarray"):
#     441         import numpy
#
# File /gpfs/milgram/project/hwang/imc33/conda_envs/aitc/lib/python3.8/site-packages/slicer/slicer_internal.py:439, in <listcomp>(.0)
#     437         return AtomicSlicer(o, max_dim=max_dim)[tail_index]
#     438 else:
# --> 439     inner = [AtomicSlicer(e, max_dim=max_dim)[tail_index] for e in o]
#     440     if _safe_isinstance(o, "numpy", "ndarray"):
#     441         import numpy
#
# File /gpfs/milgram/project/hwang/imc33/conda_envs/aitc/lib/python3.8/site-packages/slicer/slicer_internal.py:69, in AtomicSlicer.__getitem__(self, item)
#      66 index_tup = unify_slice(item, self.max_dim)
#      68 # Slice according to object type.
# ---> 69 return UnifiedDataHandler.slice(self.o, index_tup, self.max_dim)
#
# File /gpfs/milgram/project/hwang/imc33/conda_envs/aitc/lib/python3.8/site-packages/slicer/slicer_internal.py:582, in UnifiedDataHandler.slice(cls, o, index_tup, max_dim)
#     579 head_slice = cls.type_map[o_type].head_slice
#     580 tail_slice = cls.type_map[o_type].tail_slice
# --> 582 is_element, sliced_o, cut = head_slice(o, index_tup, max_dim)
#     583 out = tail_slice(sliced_o, index_tup[cut:], max_dim - cut, is_element)
#     584 return out
#
# File /gpfs/milgram/project/hwang/imc33/conda_envs/aitc/lib/python3.8/site-packages/slicer/slicer_internal.py:418, in ArrayHandler.head_slice(cls, o, index_tup, max_dim)
#     416 cut_index = index_tup[:cut]
#     417 is_element = any([True if isinstance(x, int) else False for x in cut_index])
# --> 418 sliced_o = o[cut_index]
#     420 return is_element, sliced_o, cut
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

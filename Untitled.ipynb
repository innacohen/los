# %%
import pandas as pd
import numpy as np
import os
import warnings
from los_functions_v3 import *
warnings.filterwarnings('ignore')

# %%
def View(df, rows=None, cols=None, width=None):
    """Displays the first `rows` of the DataFrame like R's View() by adjusting Pandas settings."""
    
    # Show only the first `rows` of the DataFrame
    with pd.option_context(
        "display.max_rows", rows,  # Limit number of rows shown
        "display.max_columns", cols,  # Show all columns
        "display.max_colwidth", width,  # Show full column width
        "display.expand_frame_repr", False  # Prevent column wrapping
    ):
        display(df.head(rows))  # Show only the first `rows`

# %%
#all hospitalized patients 
df_filt = pd.read_csv('/gpfs/milgram/project/rtaylor/imc33/LOS/data/master_los.csv', index_col=[0])
df_filt["viz_service_collapsed"] = df_filt["viz_service_collapsed"].apply(map_med)

# %%
fp_simple = '/gpfs/milgram/project/rtaylor/imc33/LOS/data/features_los_simple.xlsx'

features_los = pd.read_excel(fp_simple)

# Features that are divided into 5 types to conduct data preprocessing
# 1. drop: features that need to be dropped
drop_list = features_los[features_los['type'] == 'drop']['col_name'].tolist()

# 2. category: features that are already categorical and need to be OneHotEncoding (add missing value indicator, impute missing by adding 'missing' category)
category_list = features_los[features_los['type'] == 'category']['col_name'].tolist()

# 3. binary: features that are binary and need to be converted to categorical (add missing value indicator / prefer: fill missing with 0)
binary_list = features_los[features_los['type'] == 'binary']['col_name'].tolist()

# 4. continuous: features that are continous/numerical variables, need outlier handling and normalization (add missing value indicator, fill missing with median)
continuous_list = features_los[features_los['type'] == 'continuous']['col_name'].tolist()

# 5. discrete: features that are discrete/numerical variables, need to be discretized (fill missing with 0)
discrete_list = features_los[features_los['type'] == 'discrete']['col_name'].tolist()

# Split into X, y
X = df_filt.drop(['viz_outcome_prolonged_los_yn'], axis=1)
y = df_filt['viz_outcome_prolonged_los_yn']

#inna-updated
# Drop features that have >= 99% missing values And features in drop list
missing_pct = X.isnull().mean() * 100
cols_to_drop = missing_pct[missing_pct >= 99].index.tolist()
# print("Columns with >99% missing values", cols_to_drop)
final_drop_list = list(set(drop_list + cols_to_drop+continuous_list))
final_drop_list.remove("viz_age")

X = X.drop(columns=final_drop_list)
# print("Final drop list", final_drop_list)

X = X.reset_index()
y = y.reset_index()

# Update lists
category_list = [col for col in category_list if col not in final_drop_list]
continuous_list = [col for col in continuous_list if col not in final_drop_list]
discrete_list = [col for col in discrete_list if col not in final_drop_list]
binary_list = [col for col in binary_list if col not in final_drop_list]
#update 8/23: do not discretize hospitalist counts
#discrete_list.remove("con_service_hospitalist_service_count")

# Convert variables to categorical
X[category_list] = X[category_list].astype('category')

# Split the data by group shuffle split on 'PAT_MRN_ID' into train set and validation set
gss = GroupShuffleSplit(n_splits=2, test_size=0.2, random_state=SEED)

train_ix, val_ix = next(gss.split(X, y, groups=X['pat_mrn_id']))

X_train = X.loc[train_ix]
y_train = y.loc[train_ix]

X_val = X.loc[val_ix]
y_val = y.loc[val_ix]

# Drop 'PAT_MRN_ID' and set 'PAT_ENC_CSN_ID' as index
X_train = X_train.drop(['pat_mrn_id'], axis=1).set_index('pat_enc_csn_id')
X_val = X_val.drop(['pat_mrn_id'], axis=1).set_index('pat_enc_csn_id')
y_train = y_train.set_index('pat_enc_csn_id')
y_val = y_val.set_index('pat_enc_csn_id')

# %% [markdown]
# # 99% Missing

# %%
cols_to_drop
# Out:
# ['summary_sw_consult_order_time',
#  'summary_sw_consult_order_day',
#  'con_max_consult_order_to_sign_colon_and_rectal_hrs',
#  'con_max_consult_order_to_sign_lab_medicine_hrs',
#  'con_max_consult_order_to_sign_picc_hrs',
#  'con_max_consult_order_to_sign_radiation_oncology_hrs',
#  'con_max_consult_order_to_sign_pharmacy_hrs',
#  'con_max_consult_order_to_sign_internal_medicine_hrs',
#  'con_max_consult_order_to_sign_neuro_oncology_hrs',
#  'con_max_consult_order_to_sign_ophthalmology_hrs',
#  'con_max_consult_order_to_sign_trauma_hrs',
#  'con_max_consult_order_to_sign_rheumatology_hrs',
#  'con_max_consult_order_to_sign_sw_hrs',
#  'con_max_consult_note_to_sign_colon_and_rectal_hrs',
#  'con_max_consult_note_to_sign_lab_medicine_hrs',
#  'con_max_consult_note_to_sign_picc_hrs',
#  'con_max_consult_note_to_sign_radiation_oncology_hrs',
#  'con_max_consult_note_to_sign_pharmacy_hrs',
#  'con_max_consult_note_to_sign_internal_medicine_hrs',
#  'con_max_consult_note_to_sign_neuro_oncology_hrs',
#  'con_max_consult_note_to_sign_ophthalmology_hrs',
#  'con_max_consult_note_to_sign_trauma_hrs',
#  'con_max_consult_note_to_sign_rheumatology_hrs',
#  'con_max_consult_note_to_sign_sw_hrs',
#  'con_avg_consult_order_to_sign_colon_and_rectal_hrs',
#  'con_avg_consult_order_to_sign_lab_medicine_hrs',
#  'con_avg_consult_order_to_sign_picc_hrs',
#  'con_avg_consult_order_to_sign_radiation_oncology_hrs',
#  'con_avg_consult_order_to_sign_pharmacy_hrs',
#  'con_avg_consult_order_to_sign_internal_medicine_hrs',
#  'con_avg_consult_order_to_sign_neuro_oncology_hrs',
#  'con_avg_consult_order_to_sign_ophthalmology_hrs',
#  'con_avg_consult_order_to_sign_trauma_hrs',
#  'con_avg_consult_order_to_sign_rheumatology_hrs',
#  'con_avg_consult_order_to_sign_sw_hrs',
#  'con_avg_consult_note_to_sign_colon_and_rectal_hrs',
#  'con_avg_consult_note_to_sign_lab_medicine_hrs',
#  'con_avg_consult_note_to_sign_picc_hrs',
#  'con_avg_consult_note_to_sign_radiation_oncology_hrs',
#  'con_avg_consult_note_to_sign_pharmacy_hrs',
#  'con_avg_consult_note_to_sign_internal_medicine_hrs',
#  'con_avg_consult_note_to_sign_neuro_oncology_hrs',
#  'con_avg_consult_note_to_sign_ophthalmology_hrs',
#  'con_avg_consult_note_to_sign_trauma_hrs',
#  'con_avg_consult_note_to_sign_rheumatology_hrs',
#  'con_avg_consult_note_to_sign_sw_hrs',
#  'con_max_consult_order_to_sign_colon_and_rectal_quintile',
#  'con_max_consult_order_to_sign_lab_medicine_quintile',
#  'con_max_consult_order_to_sign_picc_quintile',
#  'con_max_consult_order_to_sign_radiation_oncology_quintile',
#  'con_max_consult_order_to_sign_pharmacy_quintile',
#  'con_max_consult_order_to_sign_internal_medicine_quintile',
#  'con_max_consult_order_to_sign_neuro_oncology_quintile',
#  'con_max_consult_order_to_sign_ophthalmology_quintile',
#  'con_max_consult_order_to_sign_trauma_quintile',
#  'con_max_consult_order_to_sign_rheumatology_quintile',
#  'con_max_consult_order_to_sign_sw_quintile',
#  'con_max_consult_note_to_sign_colon_and_rectal_quintile',
#  'con_max_consult_note_to_sign_lab_medicine_quintile',
#  'con_max_consult_note_to_sign_picc_quintile',
#  'con_max_consult_note_to_sign_radiation_oncology_quintile',
#  'con_max_consult_note_to_sign_pharmacy_quintile',
#  'con_max_consult_note_to_sign_internal_medicine_quintile',
#  'con_max_consult_note_to_sign_neuro_oncology_quintile',
#  'con_max_consult_note_to_sign_ophthalmology_quintile',
#  'con_max_consult_note_to_sign_trauma_quintile',
#  'con_max_consult_note_to_sign_rheumatology_quintile',
#  'con_max_consult_note_to_sign_sw_quintile',
#  'con_avg_consult_order_to_sign_colon_and_rectal_quintile',
#  'con_avg_consult_order_to_sign_lab_medicine_quintile',
#  'con_avg_consult_order_to_sign_picc_quintile',
#  'con_avg_consult_order_to_sign_radiation_oncology_quintile',
#  'con_avg_consult_order_to_sign_pharmacy_quintile',
#  'con_avg_consult_order_to_sign_internal_medicine_quintile',
#  'con_avg_consult_order_to_sign_neuro_oncology_quintile',
#  'con_avg_consult_order_to_sign_ophthalmology_quintile',
#  'con_avg_consult_order_to_sign_trauma_quintile',
#  'con_avg_consult_order_to_sign_rheumatology_quintile',
#  'con_avg_consult_order_to_sign_sw_quintile',
#  'con_avg_consult_note_to_sign_colon_and_rectal_quintile',
#  'con_avg_consult_note_to_sign_lab_medicine_quintile',
#  'con_avg_consult_note_to_sign_picc_quintile',
#  'con_avg_consult_note_to_sign_radiation_oncology_quintile',
#  'con_avg_consult_note_to_sign_pharmacy_quintile',
#  'con_avg_consult_note_to_sign_internal_medicine_quintile',
#  'con_avg_consult_note_to_sign_neuro_oncology_quintile',
#  'con_avg_consult_note_to_sign_ophthalmology_quintile',
#  'con_avg_consult_note_to_sign_trauma_quintile',
#  'con_avg_consult_note_to_sign_rheumatology_quintile',
#  'con_avg_consult_note_to_sign_sw_quintile',
#  'con_max_admit_order_to_consult_order_colon_and_rectal_hrs',
#  'con_max_admit_order_to_consult_order_lab_medicine_hrs',
#  'con_max_admit_order_to_consult_order_picc_hrs',
#  'con_max_admit_order_to_consult_order_radiation_oncology_hrs',
#  'con_max_admit_order_to_consult_order_hepatology_hrs',
#  'con_max_admit_order_to_consult_order_other_hrs',
#  'con_max_admit_order_to_consult_order_pharmacy_hrs',
#  'con_max_admit_order_to_consult_order_plastic_surgery_hrs',
#  'con_max_admit_order_to_consult_order_surgery_hrs',
#  'con_max_admit_order_to_consult_order_hospitalist_service_hrs',
#  'con_max_admit_order_to_consult_order_internal_medicine_hrs',
#  'con_max_admit_order_to_consult_order_neuro_oncology_hrs',
#  'con_max_admit_order_to_consult_order_neurosurgery_hrs',
#  'con_max_admit_order_to_consult_order_ophthalmology_hrs',
#  'con_max_admit_order_to_consult_order_physical_medicine_and_rehabilitation_hrs',
#  'con_max_admit_order_to_consult_order_addiction_medicine_hrs',
#  'con_max_admit_order_to_consult_order_otolaryngology_ent_hrs',
#  'con_max_admit_order_to_consult_order_icu_sdu_hrs',
#  'con_max_admit_order_to_consult_order_trauma_hrs',
#  'con_max_admit_order_to_consult_order_cardiothoracic_surgery_hrs',
#  'con_max_admit_order_to_consult_order_rheumatology_hrs',
#  'con_max_admit_order_to_consult_order_sw_hrs',
#  'con_max_admit_order_to_consult_order_colon_and_rectal_quintile',
#  'con_max_admit_order_to_consult_order_lab_medicine_quintile',
#  'con_max_admit_order_to_consult_order_picc_quintile',
#  'con_max_admit_order_to_consult_order_radiation_oncology_quintile',
#  'con_max_admit_order_to_consult_order_hepatology_quintile',
#  'con_max_admit_order_to_consult_order_other_quintile',
#  'con_max_admit_order_to_consult_order_pharmacy_quintile',
#  'con_max_admit_order_to_consult_order_plastic_surgery_quintile',
#  'con_max_admit_order_to_consult_order_surgery_quintile',
#  'con_max_admit_order_to_consult_order_hospitalist_service_quintile',
#  'con_max_admit_order_to_consult_order_internal_medicine_quintile',
#  'con_max_admit_order_to_consult_order_neuro_oncology_quintile',
#  'con_max_admit_order_to_consult_order_neurosurgery_quintile',
#  'con_max_admit_order_to_consult_order_ophthalmology_quintile',
#  'con_max_admit_order_to_consult_order_physical_medicine_and_rehabilitation_quintile',
#  'con_max_admit_order_to_consult_order_addiction_medicine_quintile',
#  'con_max_admit_order_to_consult_order_otolaryngology_ent_quintile',
#  'con_max_admit_order_to_consult_order_icu_sdu_quintile',
#  'con_max_admit_order_to_consult_order_trauma_quintile',
#  'con_max_admit_order_to_consult_order_cardiothoracic_surgery_quintile',
#  'con_max_admit_order_to_consult_order_rheumatology_quintile',
#  'con_max_admit_order_to_consult_order_sw_quintile',
#  'con_max_admit_order_to_consult_completion_colon_and_rectal_hrs',
#  'con_max_admit_order_to_consult_completion_lab_medicine_hrs',
#  'con_max_admit_order_to_consult_completion_picc_hrs',
#  'con_max_admit_order_to_consult_completion_radiation_oncology_hrs',
#  'con_max_admit_order_to_consult_completion_pharmacy_hrs',
#  'con_max_admit_order_to_consult_completion_internal_medicine_hrs',
#  'con_max_admit_order_to_consult_completion_neuro_oncology_hrs',
#  'con_max_admit_order_to_consult_completion_ophthalmology_hrs',
#  'con_max_admit_order_to_consult_completion_trauma_hrs',
#  'con_max_admit_order_to_consult_completion_cardiothoracic_surgery_hrs',
#  'con_max_admit_order_to_consult_completion_rheumatology_hrs',
#  'con_max_admit_order_to_consult_completion_sw_hrs',
#  'con_max_admit_order_to_consult_completion_colon_and_rectal_quintile',
#  'con_max_admit_order_to_consult_completion_lab_medicine_quintile',
#  'con_max_admit_order_to_consult_completion_picc_quintile',
#  'con_max_admit_order_to_consult_completion_radiation_oncology_quintile',
#  'con_max_admit_order_to_consult_completion_pharmacy_quintile',
#  'con_max_admit_order_to_consult_completion_internal_medicine_quintile',
#  'con_max_admit_order_to_consult_completion_neuro_oncology_quintile',
#  'con_max_admit_order_to_consult_completion_ophthalmology_quintile',
#  'con_max_admit_order_to_consult_completion_trauma_quintile',
#  'con_max_admit_order_to_consult_completion_cardiothoracic_surgery_quintile',
#  'con_max_admit_order_to_consult_completion_rheumatology_quintile',
#  'con_max_admit_order_to_consult_completion_sw_quintile',
#  'con_avg_admit_order_to_consult_order_colon_and_rectal_hrs',
#  'con_avg_admit_order_to_consult_order_lab_medicine_hrs',
#  'con_avg_admit_order_to_consult_order_picc_hrs',
#  'con_avg_admit_order_to_consult_order_radiation_oncology_hrs',
#  'con_avg_admit_order_to_consult_order_hepatology_hrs',
#  'con_avg_admit_order_to_consult_order_other_hrs',
#  'con_avg_admit_order_to_consult_order_pharmacy_hrs',
#  'con_avg_admit_order_to_consult_order_plastic_surgery_hrs',
#  'con_avg_admit_order_to_consult_order_surgery_hrs',
#  'con_avg_admit_order_to_consult_order_hospitalist_service_hrs',
#  'con_avg_admit_order_to_consult_order_internal_medicine_hrs',
#  'con_avg_admit_order_to_consult_order_neuro_oncology_hrs',
#  'con_avg_admit_order_to_consult_order_neurosurgery_hrs',
#  'con_avg_admit_order_to_consult_order_ophthalmology_hrs',
#  'con_avg_admit_order_to_consult_order_physical_medicine_and_rehabilitation_hrs',
#  'con_avg_admit_order_to_consult_order_addiction_medicine_hrs',
#  'con_avg_admit_order_to_consult_order_otolaryngology_ent_hrs',
#  'con_avg_admit_order_to_consult_order_icu_sdu_hrs',
#  'con_avg_admit_order_to_consult_order_trauma_hrs',
#  'con_avg_admit_order_to_consult_order_cardiothoracic_surgery_hrs',
#  'con_avg_admit_order_to_consult_order_rheumatology_hrs',
#  'con_avg_admit_order_to_consult_order_sw_hrs',
#  'con_avg_admit_order_to_consult_order_colon_and_rectal_quintile',
#  'con_avg_admit_order_to_consult_order_lab_medicine_quintile',
#  'con_avg_admit_order_to_consult_order_picc_quintile',
#  'con_avg_admit_order_to_consult_order_radiation_oncology_quintile',
#  'con_avg_admit_order_to_consult_order_hepatology_quintile',
#  'con_avg_admit_order_to_consult_order_other_quintile',
#  'con_avg_admit_order_to_consult_order_pharmacy_quintile',
#  'con_avg_admit_order_to_consult_order_plastic_surgery_quintile',
#  'con_avg_admit_order_to_consult_order_surgery_quintile',
#  'con_avg_admit_order_to_consult_order_hospitalist_service_quintile',
#  'con_avg_admit_order_to_consult_order_internal_medicine_quintile',
#  'con_avg_admit_order_to_consult_order_neuro_oncology_quintile',
#  'con_avg_admit_order_to_consult_order_neurosurgery_quintile',
#  'con_avg_admit_order_to_consult_order_ophthalmology_quintile',
#  'con_avg_admit_order_to_consult_order_physical_medicine_and_rehabilitation_quintile',
#  'con_avg_admit_order_to_consult_order_addiction_medicine_quintile',
#  'con_avg_admit_order_to_consult_order_otolaryngology_ent_quintile',
#  'con_avg_admit_order_to_consult_order_icu_sdu_quintile',
#  'con_avg_admit_order_to_consult_order_trauma_quintile',
#  'con_avg_admit_order_to_consult_order_cardiothoracic_surgery_quintile',
#  'con_avg_admit_order_to_consult_order_rheumatology_quintile',
#  'con_avg_admit_order_to_consult_order_sw_quintile',
#  'con_avg_admit_order_to_consult_completion_colon_and_rectal_hrs',
#  'con_avg_admit_order_to_consult_completion_lab_medicine_hrs',
#  'con_avg_admit_order_to_consult_completion_picc_hrs',
#  'con_avg_admit_order_to_consult_completion_radiation_oncology_hrs',
#  'con_avg_admit_order_to_consult_completion_pharmacy_hrs',
#  'con_avg_admit_order_to_consult_completion_internal_medicine_hrs',
#  'con_avg_admit_order_to_consult_completion_neuro_oncology_hrs',
#  'con_avg_admit_order_to_consult_completion_ophthalmology_hrs',
#  'con_avg_admit_order_to_consult_completion_trauma_hrs',
#  'con_avg_admit_order_to_consult_completion_cardiothoracic_surgery_hrs',
#  'con_avg_admit_order_to_consult_completion_rheumatology_hrs',
#  'con_avg_admit_order_to_consult_completion_sw_hrs',
#  'con_avg_admit_order_to_consult_completion_colon_and_rectal_quintile',
#  'con_avg_admit_order_to_consult_completion_lab_medicine_quintile',
#  'con_avg_admit_order_to_consult_completion_picc_quintile',
#  'con_avg_admit_order_to_consult_completion_radiation_oncology_quintile',
#  'con_avg_admit_order_to_consult_completion_pharmacy_quintile',
#  'con_avg_admit_order_to_consult_completion_internal_medicine_quintile',
#  'con_avg_admit_order_to_consult_completion_neuro_oncology_quintile',
#  'con_avg_admit_order_to_consult_completion_ophthalmology_quintile',
#  'con_avg_admit_order_to_consult_completion_trauma_quintile',
#  'con_avg_admit_order_to_consult_completion_cardiothoracic_surgery_quintile',
#  'con_avg_admit_order_to_consult_completion_rheumatology_quintile',
#  'con_avg_admit_order_to_consult_completion_sw_quintile']

# %%
def miss_var_summary(df):
    miss_df = df.isna().sum().reset_index()
    miss_df.columns = ['variable', 'n_missing']
    miss_df['pct_missing'] = (miss_df['n_missing'] / len(df)) * 100
    miss_df = miss_df[miss_df['n_missing'] > 0]  # Optional: filter out columns with no missing
    miss_df = miss_df.sort_values(by='pct_missing', ascending=False).reset_index(drop=True)
    return miss_df

# %%
View(miss_var_summary(df_filt))
# Out:
#                                                                                     variable  n_missing  pct_missing
# 0                                                              summary_sw_consult_order_time      12771   100.000000
# 1                                           con_max_admit_order_to_consult_order_sw_quintile      12771   100.000000
# 2                                              con_avg_admit_order_to_consult_order_picc_hrs      12771   100.000000
# 3                                                       con_avg_consult_order_to_sign_sw_hrs      12771   100.000000
# 4                                      con_max_admit_order_to_consult_completion_sw_quintile      12771   100.000000
# 5                                  con_avg_admit_order_to_consult_order_colon_and_rectal_hrs      12771   100.000000
# 6                             con_max_admit_order_to_consult_order_colon_and_rectal_quintile      12771   100.000000
# 7                                                con_max_admit_order_to_consult_order_sw_hrs      12771   100.000000
# 8                                                 con_avg_consult_note_to_sign_picc_quintile      12771   100.000000
# 9                                                con_max_consult_order_to_sign_picc_quintile      12771   100.000000
# 10                                                     con_avg_consult_note_to_sign_picc_hrs      12771   100.000000
# 11                                                    con_avg_consult_order_to_sign_picc_hrs      12771   100.000000
# 12                                          con_avg_admit_order_to_consult_completion_sw_hrs      12771   100.000000
# 13                                        con_avg_admit_order_to_consult_order_picc_quintile      12771   100.000000
# 14                                   con_avg_admit_order_to_consult_completion_picc_quintile      12771   100.000000
# 15                                                    con_max_consult_order_to_sign_picc_hrs      12771   100.000000
# 16                                          con_avg_admit_order_to_consult_order_sw_quintile      12771   100.000000
# 17                                                 con_avg_consult_order_to_sign_sw_quintile      12771   100.000000
# 18                                                con_max_consult_note_to_sign_picc_quintile      12771   100.000000
# 19                                                 con_max_consult_order_to_sign_sw_quintile      12771   100.000000
# 20                                          con_max_admit_order_to_consult_completion_sw_hrs      12771   100.000000
# 21                                                     con_max_consult_note_to_sign_picc_hrs      12771   100.000000
# 22                                               con_avg_consult_order_to_sign_picc_quintile      12771   100.000000
# 23                            con_avg_admit_order_to_consult_order_colon_and_rectal_quintile      12771   100.000000
# 24                                                       con_avg_consult_note_to_sign_sw_hrs      12771   100.000000
# 25                                                       con_max_consult_note_to_sign_sw_hrs      12771   100.000000
# 26                                        con_avg_admit_order_to_consult_completion_picc_hrs      12771   100.000000
# 27                                                      con_max_consult_order_to_sign_sw_hrs      12771   100.000000
# 28                                               con_avg_admit_order_to_consult_order_sw_hrs      12771   100.000000
# 29                                   con_max_admit_order_to_consult_completion_picc_quintile      12771   100.000000
# 30                                                  con_avg_consult_note_to_sign_sw_quintile      12771   100.000000
# 31                                        con_max_admit_order_to_consult_completion_picc_hrs      12771   100.000000
# 32                                 con_max_admit_order_to_consult_order_colon_and_rectal_hrs      12771   100.000000
# 33                                                  con_max_consult_note_to_sign_sw_quintile      12771   100.000000
# 34                                     con_avg_admit_order_to_consult_completion_sw_quintile      12771   100.000000
# 35                                                              summary_sw_consult_order_day      12771   100.000000
# 36                                             con_max_admit_order_to_consult_order_picc_hrs      12771   100.000000
# 37                                        con_max_admit_order_to_consult_order_picc_quintile      12771   100.000000
# 38                          con_max_admit_order_to_consult_order_addiction_medicine_quintile      12770    99.992170
# 39                               con_max_admit_order_to_consult_order_addiction_medicine_hrs      12770    99.992170
# 40                                           con_avg_consult_order_to_sign_pharmacy_quintile      12770    99.992170
# 41                               con_avg_admit_order_to_consult_completion_pharmacy_quintile      12770    99.992170
# 42                                            con_max_consult_note_to_sign_pharmacy_quintile      12770    99.992170
# 43                                           con_max_consult_order_to_sign_pharmacy_quintile      12770    99.992170
# 44                                                con_max_consult_order_to_sign_pharmacy_hrs      12770    99.992170
# 45                          con_avg_admit_order_to_consult_order_addiction_medicine_quintile      12770    99.992170
# 46                                                 con_avg_consult_note_to_sign_pharmacy_hrs      12770    99.992170
# 47                               con_max_admit_order_to_consult_completion_pharmacy_quintile      12770    99.992170
# 48                                                 con_max_consult_note_to_sign_pharmacy_hrs      12770    99.992170
# 49                               con_avg_admit_order_to_consult_order_addiction_medicine_hrs      12770    99.992170
# 50                                            con_avg_consult_note_to_sign_pharmacy_quintile      12770    99.992170
# 51                                    con_max_admit_order_to_consult_completion_pharmacy_hrs      12770    99.992170
# 52                                                con_avg_consult_order_to_sign_pharmacy_hrs      12770    99.992170
# 53                                    con_avg_admit_order_to_consult_completion_pharmacy_hrs      12770    99.992170
# 54                                con_avg_admit_order_to_consult_order_lab_medicine_quintile      12767    99.968679
# 55                                     con_max_admit_order_to_consult_order_lab_medicine_hrs      12767    99.968679
# 56                                con_max_admit_order_to_consult_order_lab_medicine_quintile      12767    99.968679
# 57                                     con_avg_admit_order_to_consult_order_lab_medicine_hrs      12767    99.968679
# 58                                     con_avg_admit_order_to_consult_order_icu_sdu_quintile      12759    99.906037
# 59                                     con_max_admit_order_to_consult_order_icu_sdu_quintile      12759    99.906037
# 60                                          con_avg_admit_order_to_consult_order_icu_sdu_hrs      12759    99.906037
# 61                                          con_max_admit_order_to_consult_order_icu_sdu_hrs      12759    99.906037
# 62                              con_avg_admit_order_to_consult_order_hospitalist_service_hrs      12755    99.874716
# 63                         con_max_admit_order_to_consult_order_hospitalist_service_quintile      12755    99.874716
# 64                         con_avg_admit_order_to_consult_order_hospitalist_service_quintile      12755    99.874716
# 65                              con_max_admit_order_to_consult_order_hospitalist_service_hrs      12755    99.874716
# 66                                           con_avg_admit_order_to_consult_order_trauma_hrs      12750    99.835565
# 67                                      con_avg_admit_order_to_consult_order_trauma_quintile      12750    99.835565
# 68                                           con_max_admit_order_to_consult_order_trauma_hrs      12750    99.835565
# 69                                      con_max_admit_order_to_consult_order_trauma_quintile      12750    99.835565
# 70                                  con_max_admit_order_to_consult_order_hepatology_quintile      12738    99.741602
# 71                           con_max_admit_order_to_consult_order_internal_medicine_quintile      12738    99.741602
# 72                                con_avg_admit_order_to_consult_order_internal_medicine_hrs      12738    99.741602
# 73                                       con_max_admit_order_to_consult_order_hepatology_hrs      12738    99.741602
# 74                                       con_avg_admit_order_to_consult_order_hepatology_hrs      12738    99.741602
# 75                                con_max_admit_order_to_consult_order_internal_medicine_hrs      12738    99.741602
# 76                           con_avg_admit_order_to_consult_order_internal_medicine_quintile      12738    99.741602
# 77                                  con_avg_admit_order_to_consult_order_hepatology_quintile      12738    99.741602
# 78                              con_max_admit_order_to_consult_order_neuro_oncology_quintile      12722    99.616318
# 79                                   con_avg_admit_order_to_consult_order_neuro_oncology_hrs      12722    99.616318
# 80                              con_avg_admit_order_to_consult_order_neuro_oncology_quintile      12722    99.616318
# 81                                   con_max_admit_order_to_consult_order_neuro_oncology_hrs      12722    99.616318
# 82                                          con_avg_admit_order_to_consult_order_surgery_hrs      12720    99.600658
# 83                                     con_max_admit_order_to_consult_order_surgery_quintile      12720    99.600658
# 84                                     con_avg_admit_order_to_consult_order_surgery_quintile      12720    99.600658
# 85                                          con_max_admit_order_to_consult_order_surgery_hrs      12720    99.600658
# 86                       con_max_admit_order_to_consult_completion_colon_and_rectal_quintile      12711    99.530186
# 87                            con_avg_admit_order_to_consult_completion_colon_and_rectal_hrs      12711    99.530186
# 88                            con_max_admit_order_to_consult_completion_colon_and_rectal_hrs      12711    99.530186
# 89                       con_avg_admit_order_to_consult_completion_colon_and_rectal_quintile      12711    99.530186
# 90                               con_max_admit_order_to_consult_order_radiation_oncology_hrs      12710    99.522355
# 91                          con_avg_admit_order_to_consult_order_radiation_oncology_quintile      12710    99.522355
# 92                               con_avg_admit_order_to_consult_order_radiation_oncology_hrs      12710    99.522355
# 93                          con_max_admit_order_to_consult_order_radiation_oncology_quintile      12710    99.522355
# 94                                         con_avg_consult_note_to_sign_colon_and_rectal_hrs      12708    99.506695
# 95                                        con_avg_consult_order_to_sign_colon_and_rectal_hrs      12708    99.506695
# 96                                         con_max_consult_note_to_sign_colon_and_rectal_hrs      12708    99.506695
# 97                                        con_max_consult_order_to_sign_colon_and_rectal_hrs      12708    99.506695
# 98                                    con_avg_consult_note_to_sign_colon_and_rectal_quintile      12708    99.506695
# 99                                    con_max_consult_note_to_sign_colon_and_rectal_quintile      12708    99.506695
# 100                                  con_avg_consult_order_to_sign_colon_and_rectal_quintile      12708    99.506695
# 101                                  con_max_consult_order_to_sign_colon_and_rectal_quintile      12708    99.506695
# 102                     con_avg_admit_order_to_consult_order_cardiothoracic_surgery_quintile      12704    99.475374
# 103                          con_max_admit_order_to_consult_order_cardiothoracic_surgery_hrs      12704    99.475374
# 104                     con_max_admit_order_to_consult_order_cardiothoracic_surgery_quintile      12704    99.475374
# 105                          con_avg_admit_order_to_consult_order_cardiothoracic_surgery_hrs      12704    99.475374
# 106                              con_avg_admit_order_to_consult_order_ophthalmology_quintile      12696    99.412732
# 107                                   con_avg_admit_order_to_consult_order_ophthalmology_hrs      12696    99.412732
# 108                                   con_max_admit_order_to_consult_order_ophthalmology_hrs      12696    99.412732
# 109                              con_max_admit_order_to_consult_order_ophthalmology_quintile      12696    99.412732
# 110                                    con_avg_admit_order_to_consult_order_neurosurgery_hrs      12694    99.397071
# 111                                    con_max_admit_order_to_consult_order_neurosurgery_hrs      12694    99.397071
# 112                               con_max_admit_order_to_consult_order_neurosurgery_quintile      12694    99.397071
# 113                               con_avg_admit_order_to_consult_order_neurosurgery_quintile      12694    99.397071
# 114                             con_avg_admit_order_to_consult_completion_neuro_oncology_hrs      12692    99.381411
# 115                                     con_max_admit_order_to_consult_completion_trauma_hrs      12692    99.381411
# 116                        con_avg_admit_order_to_consult_completion_neuro_oncology_quintile      12692    99.381411
# 117                             con_max_admit_order_to_consult_completion_neuro_oncology_hrs      12692    99.381411
# 118                                con_max_admit_order_to_consult_completion_trauma_quintile      12692    99.381411
# 119                        con_max_admit_order_to_consult_completion_neuro_oncology_quintile      12692    99.381411
# 120                                     con_avg_admit_order_to_consult_completion_trauma_hrs      12692    99.381411
# 121                                con_avg_admit_order_to_consult_completion_trauma_quintile      12692    99.381411
# 122                          con_max_admit_order_to_consult_completion_lab_medicine_quintile      12688    99.350090
# 123                               con_avg_admit_order_to_consult_completion_lab_medicine_hrs      12688    99.350090
# 124                               con_max_admit_order_to_consult_completion_lab_medicine_hrs      12688    99.350090
# 125                          con_avg_admit_order_to_consult_completion_lab_medicine_quintile      12688    99.350090
# 126                         con_avg_admit_order_to_consult_completion_radiation_oncology_hrs      12682    99.303109
# 127                         con_max_admit_order_to_consult_completion_radiation_oncology_hrs      12682    99.303109
# 128                    con_max_admit_order_to_consult_completion_radiation_oncology_quintile      12682    99.303109
# 129                    con_avg_admit_order_to_consult_completion_radiation_oncology_quintile      12682    99.303109
# 130                                           con_avg_consult_order_to_sign_lab_medicine_hrs      12681    99.295278
# 131                                      con_max_consult_order_to_sign_lab_medicine_quintile      12681    99.295278
# 132                                           con_max_consult_order_to_sign_lab_medicine_hrs      12681    99.295278
# 133                                            con_max_consult_note_to_sign_lab_medicine_hrs      12681    99.295278
# 134                                            con_avg_consult_note_to_sign_lab_medicine_hrs      12681    99.295278
# 135                                      con_avg_consult_order_to_sign_lab_medicine_quintile      12681    99.295278
# 136                                       con_avg_consult_note_to_sign_lab_medicine_quintile      12681    99.295278
# 137                                       con_max_consult_note_to_sign_lab_medicine_quintile      12681    99.295278
# 138                                             con_avg_consult_note_to_sign_trauma_quintile      12680    99.287448
# 139                                            con_avg_consult_order_to_sign_trauma_quintile      12680    99.287448
# 140                                                 con_avg_consult_order_to_sign_trauma_hrs      12680    99.287448
# 141                                                  con_avg_consult_note_to_sign_trauma_hrs      12680    99.287448
# 142                                                  con_max_consult_note_to_sign_trauma_hrs      12680    99.287448
# 143                                             con_max_consult_note_to_sign_trauma_quintile      12680    99.287448
# 144                                            con_max_consult_order_to_sign_trauma_quintile      12680    99.287448
# 145                                                 con_max_consult_order_to_sign_trauma_hrs      12680    99.287448
# 146                              con_avg_admit_order_to_consult_order_otolaryngology_ent_hrs      12676    99.256127
# 147                         con_max_admit_order_to_consult_order_otolaryngology_ent_quintile      12676    99.256127
# 148                              con_max_admit_order_to_consult_order_otolaryngology_ent_hrs      12676    99.256127
# 149                         con_avg_admit_order_to_consult_order_otolaryngology_ent_quintile      12676    99.256127
# 150                         con_max_admit_order_to_consult_completion_ophthalmology_quintile      12674    99.240467
# 151                              con_avg_admit_order_to_consult_completion_ophthalmology_hrs      12674    99.240467
# 152                         con_avg_admit_order_to_consult_completion_ophthalmology_quintile      12674    99.240467
# 153                              con_max_admit_order_to_consult_completion_ophthalmology_hrs      12674    99.240467
# 154                                 con_avg_consult_note_to_sign_radiation_oncology_quintile      12670    99.209146
# 155                                      con_max_consult_note_to_sign_radiation_oncology_hrs      12670    99.209146
# 156                                con_max_consult_order_to_sign_radiation_oncology_quintile      12670    99.209146
# 157                                     con_max_consult_order_to_sign_radiation_oncology_hrs      12670    99.209146
# 158                                     con_avg_consult_order_to_sign_radiation_oncology_hrs      12670    99.209146
# 159                                con_avg_consult_order_to_sign_radiation_oncology_quintile      12670    99.209146
# 160                                 con_max_consult_note_to_sign_radiation_oncology_quintile      12670    99.209146
# 161                                      con_avg_consult_note_to_sign_radiation_oncology_hrs      12670    99.209146
# 162                               con_max_admit_order_to_consult_order_rheumatology_quintile      12668    99.193485
# 163                               con_avg_admit_order_to_consult_order_rheumatology_quintile      12668    99.193485
# 164                                    con_avg_admit_order_to_consult_order_rheumatology_hrs      12668    99.193485
# 165                                    con_max_admit_order_to_consult_order_rheumatology_hrs      12668    99.193485
# 166                                        con_avg_admit_order_to_consult_order_pharmacy_hrs      12667    99.185655
# 167                                   con_max_admit_order_to_consult_order_pharmacy_quintile      12667    99.185655
# 168                                        con_max_admit_order_to_consult_order_pharmacy_hrs      12667    99.185655
# 169                                   con_avg_admit_order_to_consult_order_pharmacy_quintile      12667    99.185655
# 170                                         con_max_consult_order_to_sign_neuro_oncology_hrs      12664    99.162164
# 171                                    con_max_consult_order_to_sign_neuro_oncology_quintile      12664    99.162164
# 172                                          con_avg_consult_note_to_sign_neuro_oncology_hrs      12664    99.162164
# 173                                          con_max_consult_note_to_sign_neuro_oncology_hrs      12664    99.162164
# 174                                    con_avg_consult_order_to_sign_neuro_oncology_quintile      12664    99.162164
# 175                                     con_max_consult_note_to_sign_neuro_oncology_quintile      12664    99.162164
# 176                                     con_avg_consult_note_to_sign_neuro_oncology_quintile      12664    99.162164
# 177                                         con_avg_consult_order_to_sign_neuro_oncology_hrs      12664    99.162164
# 178                               con_avg_admit_order_to_consult_completion_rheumatology_hrs      12660    99.130843
# 179                          con_avg_admit_order_to_consult_completion_rheumatology_quintile      12660    99.130843
# 180                con_avg_admit_order_to_consult_completion_cardiothoracic_surgery_quintile      12660    99.130843
# 181                          con_max_admit_order_to_consult_completion_rheumatology_quintile      12660    99.130843
# 182                con_max_admit_order_to_consult_completion_cardiothoracic_surgery_quintile      12660    99.130843
# 183                     con_avg_admit_order_to_consult_completion_cardiothoracic_surgery_hrs      12660    99.130843
# 184                               con_max_admit_order_to_consult_completion_rheumatology_hrs      12660    99.130843
# 185                     con_max_admit_order_to_consult_completion_cardiothoracic_surgery_hrs      12660    99.130843
# 186                                          con_max_consult_order_to_sign_ophthalmology_hrs      12658    99.115183
# 187                                      con_max_consult_note_to_sign_ophthalmology_quintile      12658    99.115183
# 188                                           con_avg_consult_note_to_sign_ophthalmology_hrs      12658    99.115183
# 189                                          con_avg_consult_order_to_sign_ophthalmology_hrs      12658    99.115183
# 190                                           con_max_consult_note_to_sign_ophthalmology_hrs      12658    99.115183
# 191                                      con_avg_consult_note_to_sign_ophthalmology_quintile      12658    99.115183
# 192                                     con_max_consult_order_to_sign_ophthalmology_quintile      12658    99.115183
# 193                                     con_avg_consult_order_to_sign_ophthalmology_quintile      12658    99.115183
# 194                          con_avg_admit_order_to_consult_completion_internal_medicine_hrs      12657    99.107353
# 195                     con_avg_admit_order_to_consult_completion_internal_medicine_quintile      12657    99.107353
# 196                     con_max_admit_order_to_consult_completion_internal_medicine_quintile      12657    99.107353
# 197                          con_max_admit_order_to_consult_completion_internal_medicine_hrs      12657    99.107353
# 198                                 con_max_admit_order_to_consult_order_plastic_surgery_hrs      12656    99.099522
# 199                                 con_avg_admit_order_to_consult_order_plastic_surgery_hrs      12656    99.099522
# 200                            con_max_admit_order_to_consult_order_plastic_surgery_quintile      12656    99.099522
# 201                            con_avg_admit_order_to_consult_order_plastic_surgery_quintile      12656    99.099522
# 202                                       con_avg_consult_note_to_sign_rheumatology_quintile      12647    99.029050
# 203                                      con_avg_consult_order_to_sign_internal_medicine_hrs      12647    99.029050
# 204                                            con_max_consult_note_to_sign_rheumatology_hrs      12647    99.029050
# 205                                  con_avg_consult_note_to_sign_internal_medicine_quintile      12647    99.029050
# 206                                           con_max_consult_order_to_sign_rheumatology_hrs      12647    99.029050
# 207                                      con_max_consult_order_to_sign_rheumatology_quintile      12647    99.029050
# 208                                      con_max_consult_order_to_sign_internal_medicine_hrs      12647    99.029050
# 209                                       con_max_consult_note_to_sign_internal_medicine_hrs      12647    99.029050
# 210                                  con_max_consult_note_to_sign_internal_medicine_quintile      12647    99.029050
# 211                                       con_max_consult_note_to_sign_rheumatology_quintile      12647    99.029050
# 212                                       con_avg_consult_note_to_sign_internal_medicine_hrs      12647    99.029050
# 213                                            con_avg_consult_note_to_sign_rheumatology_hrs      12647    99.029050
# 214                                 con_max_consult_order_to_sign_internal_medicine_quintile      12647    99.029050
# 215                                      con_avg_consult_order_to_sign_rheumatology_quintile      12647    99.029050
# 216                                 con_avg_consult_order_to_sign_internal_medicine_quintile      12647    99.029050
# 217                                           con_avg_consult_order_to_sign_rheumatology_hrs      12647    99.029050
# 218                                           con_avg_admit_order_to_consult_order_other_hrs      12645    99.013390
# 219       con_avg_admit_order_to_consult_order_physical_medicine_and_rehabilitation_quintile      12645    99.013390
# 220            con_max_admit_order_to_consult_order_physical_medicine_and_rehabilitation_hrs      12645    99.013390
# 221                                           con_max_admit_order_to_consult_order_other_hrs      12645    99.013390
# 222            con_avg_admit_order_to_consult_order_physical_medicine_and_rehabilitation_hrs      12645    99.013390
# 223                                      con_max_admit_order_to_consult_order_other_quintile      12645    99.013390
# 224       con_max_admit_order_to_consult_order_physical_medicine_and_rehabilitation_quintile      12645    99.013390
# 225                                      con_avg_admit_order_to_consult_order_other_quintile      12645    99.013390
# 226       con_avg_admit_order_to_consult_completion_physical_medicine_and_rehabilitation_hrs      12643    98.997729
# 227       con_max_admit_order_to_consult_completion_physical_medicine_and_rehabilitation_hrs      12643    98.997729
# 228  con_avg_admit_order_to_consult_completion_physical_medicine_and_rehabilitation_quintile      12643    98.997729
# 229  con_max_admit_order_to_consult_completion_physical_medicine_and_rehabilitation_quintile      12643    98.997729
# 230                                      con_avg_admit_order_to_consult_order_geriatrics_hrs      12642    98.989899
# 231                                 con_avg_admit_order_to_consult_order_geriatrics_quintile      12642    98.989899
# 232                                 con_max_admit_order_to_consult_order_geriatrics_quintile      12642    98.989899
# 233                                      con_max_admit_order_to_consult_order_geriatrics_hrs      12642    98.989899
# 234                                  con_max_consult_note_to_sign_cardiothoracic_surgery_hrs      12633    98.919427
# 235                             con_avg_consult_note_to_sign_cardiothoracic_surgery_quintile      12633    98.919427
# 236                                 con_max_consult_order_to_sign_cardiothoracic_surgery_hrs      12633    98.919427
# 237                                  con_avg_consult_note_to_sign_cardiothoracic_surgery_hrs      12633    98.919427
# 238                             con_max_consult_note_to_sign_cardiothoracic_surgery_quintile      12633    98.919427
# 239                                 con_avg_consult_order_to_sign_cardiothoracic_surgery_hrs      12633    98.919427
# 240                            con_avg_consult_order_to_sign_cardiothoracic_surgery_quintile      12633    98.919427
# 241                            con_max_consult_order_to_sign_cardiothoracic_surgery_quintile      12633    98.919427
# 242                                 con_avg_admit_order_to_consult_completion_hepatology_hrs      12628    98.880276
# 243                            con_max_admit_order_to_consult_completion_hepatology_quintile      12628    98.880276
# 244                            con_avg_admit_order_to_consult_completion_hepatology_quintile      12628    98.880276
# 245                                 con_max_admit_order_to_consult_completion_hepatology_hrs      12628    98.880276
# 246                    con_max_admit_order_to_consult_completion_otolaryngology_ent_quintile      12617    98.794143
# 247                         con_max_admit_order_to_consult_completion_otolaryngology_ent_hrs      12617    98.794143
# 248                         con_avg_admit_order_to_consult_completion_otolaryngology_ent_hrs      12617    98.794143
# 249                    con_avg_admit_order_to_consult_completion_otolaryngology_ent_quintile      12617    98.794143
# 250                                con_max_admit_order_to_consult_order_orthopedics_quintile      12615    98.778482
# 251                                 con_max_admit_order_to_consult_order_psychiatry_quintile      12615    98.778482
# 252                                     con_avg_admit_order_to_consult_order_orthopedics_hrs      12615    98.778482
# 253                                con_avg_admit_order_to_consult_order_orthopedics_quintile      12615    98.778482
# 254                                      con_max_admit_order_to_consult_order_psychiatry_hrs      12615    98.778482
# 255                                      con_avg_admit_order_to_consult_order_psychiatry_hrs      12615    98.778482
# 256                                     con_max_admit_order_to_consult_order_orthopedics_hrs      12615    98.778482
# 257                                 con_avg_admit_order_to_consult_order_psychiatry_quintile      12615    98.778482
# 258              con_max_consult_order_to_sign_physical_medicine_and_rehabilitation_quintile      12611    98.747162
# 259               con_avg_consult_note_to_sign_physical_medicine_and_rehabilitation_quintile      12611    98.747162
# 260                   con_avg_consult_order_to_sign_physical_medicine_and_rehabilitation_hrs      12611    98.747162
# 261               con_max_consult_note_to_sign_physical_medicine_and_rehabilitation_quintile      12611    98.747162
# 262                   con_max_consult_order_to_sign_physical_medicine_and_rehabilitation_hrs      12611    98.747162
# 263                    con_avg_consult_note_to_sign_physical_medicine_and_rehabilitation_hrs      12611    98.747162
# 264              con_avg_consult_order_to_sign_physical_medicine_and_rehabilitation_quintile      12611    98.747162
# 265                    con_max_consult_note_to_sign_physical_medicine_and_rehabilitation_hrs      12611    98.747162
# 266                                 con_max_admit_order_to_consult_order_palliative_quintile      12605    98.700180
# 267                                 con_avg_admit_order_to_consult_order_palliative_quintile      12605    98.700180
# 268                                      con_max_admit_order_to_consult_order_palliative_hrs      12605    98.700180
# 269                                      con_avg_admit_order_to_consult_order_palliative_hrs      12605    98.700180
# 270                                                             summary_pt_consult_order_day      12603    98.684520
# 271                                                            summary_pt_consult_order_time      12603    98.684520
# 272                                     con_avg_consult_order_to_sign_otolaryngology_ent_hrs      12601    98.668859
# 273                                 con_max_consult_note_to_sign_otolaryngology_ent_quintile      12601    98.668859
# 274                                con_max_consult_order_to_sign_otolaryngology_ent_quintile      12601    98.668859
# 275                                     con_max_consult_order_to_sign_otolaryngology_ent_hrs      12601    98.668859
# 276                                con_avg_consult_order_to_sign_otolaryngology_ent_quintile      12601    98.668859
# 277                                 con_avg_consult_note_to_sign_otolaryngology_ent_quintile      12601    98.668859
# 278                                      con_max_consult_note_to_sign_otolaryngology_ent_hrs      12601    98.668859
# 279                                      con_avg_consult_note_to_sign_otolaryngology_ent_hrs      12601    98.668859
# 280                                             con_avg_consult_order_to_sign_hepatology_hrs      12599    98.653199
# 281                                         con_max_consult_note_to_sign_hepatology_quintile      12599    98.653199
# 282                                         con_avg_consult_note_to_sign_hepatology_quintile      12599    98.653199
# 283                                        con_avg_consult_order_to_sign_hepatology_quintile      12599    98.653199
# 284                                              con_avg_consult_note_to_sign_hepatology_hrs      12599    98.653199
# 285                                        con_max_consult_order_to_sign_hepatology_quintile      12599    98.653199
# 286                                             con_max_consult_order_to_sign_hepatology_hrs      12599    98.653199
# 287                                              con_max_consult_note_to_sign_hepatology_hrs      12599    98.653199
# 288                         con_max_admit_order_to_consult_completion_addiction_medicine_hrs      12583    98.527915
# 289                    con_avg_admit_order_to_consult_completion_addiction_medicine_quintile      12583    98.527915
# 290                    con_max_admit_order_to_consult_completion_addiction_medicine_quintile      12583    98.527915
# 291                         con_avg_admit_order_to_consult_completion_addiction_medicine_hrs      12583    98.527915
# 292                                      con_avg_consult_note_to_sign_addiction_medicine_hrs      12577    98.480933
# 293                                      con_max_consult_note_to_sign_addiction_medicine_hrs      12577    98.480933
# 294                                con_max_consult_order_to_sign_addiction_medicine_quintile      12577    98.480933
# 295                                 con_max_consult_note_to_sign_addiction_medicine_quintile      12577    98.480933
# 296                                     con_avg_consult_order_to_sign_addiction_medicine_hrs      12577    98.480933
# 297                                     con_max_consult_order_to_sign_addiction_medicine_hrs      12577    98.480933
# 298                                con_avg_consult_order_to_sign_addiction_medicine_quintile      12577    98.480933
# 299                                 con_avg_consult_note_to_sign_addiction_medicine_quintile      12577    98.480933
# 300                                con_avg_admit_order_to_consult_order_vascular_surgery_hrs      12576    98.473103
# 301                           con_max_admit_order_to_consult_order_vascular_surgery_quintile      12576    98.473103
# 302                           con_avg_admit_order_to_consult_order_vascular_surgery_quintile      12576    98.473103
# 303                                con_max_admit_order_to_consult_order_vascular_surgery_hrs      12576    98.473103
# 304                                        con_max_admit_order_to_consult_order_oncology_hrs      12574    98.457443
# 305                                   con_max_admit_order_to_consult_order_oncology_quintile      12574    98.457443
# 306                                   con_avg_admit_order_to_consult_order_oncology_quintile      12574    98.457443
# 307                                        con_max_admit_order_to_consult_order_diabetes_hrs      12574    98.457443
# 308                                   con_max_admit_order_to_consult_order_diabetes_quintile      12574    98.457443
# 309                                        con_avg_admit_order_to_consult_order_diabetes_hrs      12574    98.457443
# 310                                   con_avg_admit_order_to_consult_order_diabetes_quintile      12574    98.457443
# 311                                        con_avg_admit_order_to_consult_order_oncology_hrs      12574    98.457443
# 312                                     con_avg_admit_order_to_consult_order_dermatology_hrs      12572    98.441782
# 313                                con_avg_admit_order_to_consult_order_dermatology_quintile      12572    98.441782
# 314                                     con_max_admit_order_to_consult_order_dermatology_hrs      12572    98.441782
# 315                                con_max_admit_order_to_consult_order_dermatology_quintile      12572    98.441782
# 316                       con_avg_admit_order_to_consult_completion_plastic_surgery_quintile      12562    98.363480
# 317                            con_max_admit_order_to_consult_completion_plastic_surgery_hrs      12562    98.363480
# 318                            con_avg_admit_order_to_consult_completion_plastic_surgery_hrs      12562    98.363480
# 319                       con_max_admit_order_to_consult_completion_plastic_surgery_quintile      12562    98.363480
# 320                                   con_avg_admit_order_to_consult_order_podiatry_quintile      12558    98.332159
# 321                                        con_avg_admit_order_to_consult_order_podiatry_hrs      12558    98.332159
# 322                                   con_max_admit_order_to_consult_order_podiatry_quintile      12558    98.332159
# 323                                        con_max_admit_order_to_consult_order_podiatry_hrs      12558    98.332159
# 324                                con_max_admit_order_to_consult_completion_dermatology_hrs      12557    98.324329
# 325                           con_avg_admit_order_to_consult_completion_dermatology_quintile      12557    98.324329
# 326                           con_max_admit_order_to_consult_completion_dermatology_quintile      12557    98.324329
# 327                                con_avg_admit_order_to_consult_completion_dermatology_hrs      12557    98.324329
# 328                                   con_max_consult_order_to_sign_plastic_surgery_quintile      12553    98.293008
# 329                                         con_max_consult_note_to_sign_plastic_surgery_hrs      12553    98.293008
# 330                                        con_avg_consult_order_to_sign_plastic_surgery_hrs      12553    98.293008
# 331                                    con_max_consult_note_to_sign_plastic_surgery_quintile      12553    98.293008
# 332                                         con_avg_consult_note_to_sign_plastic_surgery_hrs      12553    98.293008
# 333                                   con_avg_consult_order_to_sign_plastic_surgery_quintile      12553    98.293008
# 334                                    con_avg_consult_note_to_sign_plastic_surgery_quintile      12553    98.293008
# 335                                        con_max_consult_order_to_sign_plastic_surgery_hrs      12553    98.293008
# 336                                             con_avg_consult_note_to_sign_dermatology_hrs      12539    98.183384
# 337                                            con_max_consult_order_to_sign_dermatology_hrs      12539    98.183384
# 338                                            con_avg_consult_order_to_sign_dermatology_hrs      12539    98.183384
# 339                                       con_max_consult_order_to_sign_dermatology_quintile      12539    98.183384
# 340                                       con_avg_consult_order_to_sign_dermatology_quintile      12539    98.183384
# 341                                        con_avg_consult_note_to_sign_dermatology_quintile      12539    98.183384
# 342                                             con_max_consult_note_to_sign_dermatology_hrs      12539    98.183384
# 343                                        con_max_consult_note_to_sign_dermatology_quintile      12539    98.183384
# 344                           con_max_admit_order_to_consult_completion_vascular_surgery_hrs      12527    98.089421
# 345                      con_avg_admit_order_to_consult_completion_vascular_surgery_quintile      12527    98.089421
# 346                           con_avg_admit_order_to_consult_completion_vascular_surgery_hrs      12527    98.089421
# 347                      con_max_admit_order_to_consult_completion_vascular_surgery_quintile      12527    98.089421
# 348                                         con_max_admit_order_to_consult_order_urology_hrs      12525    98.073761
# 349                                    con_max_admit_order_to_consult_order_urology_quintile      12525    98.073761
# 350                                    con_avg_admit_order_to_consult_order_urology_quintile      12525    98.073761
# 351                                         con_avg_admit_order_to_consult_order_urology_hrs      12525    98.073761
# 352                                   con_avg_consult_note_to_sign_vascular_surgery_quintile      12510    97.956307
# 353                                       con_avg_consult_order_to_sign_vascular_surgery_hrs      12510    97.956307
# 354                                  con_avg_consult_order_to_sign_vascular_surgery_quintile      12510    97.956307
# 355                                   con_max_consult_note_to_sign_vascular_surgery_quintile      12510    97.956307
# 356                                       con_max_consult_order_to_sign_vascular_surgery_hrs      12510    97.956307
# 357                                  con_max_consult_order_to_sign_vascular_surgery_quintile      12510    97.956307
# 358                                        con_max_consult_note_to_sign_vascular_surgery_hrs      12510    97.956307
# 359                                        con_avg_consult_note_to_sign_vascular_surgery_hrs      12510    97.956307
# 360                                      con_avg_admit_order_to_consult_order_hematology_hrs      12501    97.885835
# 361                                      con_max_admit_order_to_consult_order_hematology_hrs      12501    97.885835
# 362                                 con_avg_admit_order_to_consult_order_hematology_quintile      12501    97.885835
# 363                                 con_max_admit_order_to_consult_order_hematology_quintile      12501    97.885835
# 364                                  con_max_admit_order_to_consult_order_neurology_quintile      12467    97.619607
# 365                                  con_avg_admit_order_to_consult_order_neurology_quintile      12467    97.619607
# 366                                       con_max_admit_order_to_consult_order_neurology_hrs      12467    97.619607
# 367                                       con_avg_admit_order_to_consult_order_neurology_hrs      12467    97.619607
# 368                                 con_avg_admit_order_to_consult_completion_geriatrics_hrs      12457    97.541305
# 369                            con_max_admit_order_to_consult_completion_geriatrics_quintile      12457    97.541305
# 370                                 con_max_admit_order_to_consult_completion_geriatrics_hrs      12457    97.541305
# 371                            con_avg_admit_order_to_consult_completion_geriatrics_quintile      12457    97.541305
# 372                                   con_max_admit_order_to_consult_completion_podiatry_hrs      12453    97.509984
# 373                              con_avg_admit_order_to_consult_completion_podiatry_quintile      12453    97.509984
# 374                              con_max_admit_order_to_consult_completion_podiatry_quintile      12453    97.509984
# 375                                   con_avg_admit_order_to_consult_completion_podiatry_hrs      12453    97.509984
# 376                                          con_avg_consult_order_to_sign_podiatry_quintile      12440    97.408190
# 377                                               con_avg_consult_order_to_sign_podiatry_hrs      12440    97.408190
# 378                                                con_max_consult_note_to_sign_podiatry_hrs      12440    97.408190
# 379                                               con_max_consult_order_to_sign_podiatry_hrs      12440    97.408190
# 380                                                con_avg_consult_note_to_sign_podiatry_hrs      12440    97.408190
# 381                                           con_max_consult_note_to_sign_podiatry_quintile      12440    97.408190
# 382                                           con_avg_consult_note_to_sign_podiatry_quintile      12440    97.408190
# 383                                          con_max_consult_order_to_sign_podiatry_quintile      12440    97.408190
# 384                                         con_avg_consult_note_to_sign_geriatrics_quintile      12424    97.282907
# 385                                             con_max_consult_order_to_sign_geriatrics_hrs      12424    97.282907
# 386                                              con_max_consult_note_to_sign_geriatrics_hrs      12424    97.282907
# 387                                             con_avg_consult_order_to_sign_geriatrics_hrs      12424    97.282907
# 388                                        con_avg_consult_order_to_sign_geriatrics_quintile      12424    97.282907
# 389                                        con_max_consult_order_to_sign_geriatrics_quintile      12424    97.282907
# 390                                         con_max_consult_note_to_sign_geriatrics_quintile      12424    97.282907
# 391                                              con_avg_consult_note_to_sign_geriatrics_hrs      12424    97.282907
# 392                                    con_max_admit_order_to_consult_completion_icu_sdu_hrs      12414    97.204604
# 393                                    con_avg_admit_order_to_consult_completion_icu_sdu_hrs      12414    97.204604
# 394                               con_max_admit_order_to_consult_completion_icu_sdu_quintile      12414    97.204604
# 395                               con_avg_admit_order_to_consult_completion_icu_sdu_quintile      12414    97.204604
# 396                                   con_max_admit_order_to_consult_completion_diabetes_hrs      12401    97.102811
# 397                              con_max_admit_order_to_consult_completion_diabetes_quintile      12401    97.102811
# 398                              con_avg_admit_order_to_consult_completion_diabetes_quintile      12401    97.102811
# 399                                   con_avg_admit_order_to_consult_completion_diabetes_hrs      12401    97.102811
# 400                          con_avg_admit_order_to_consult_completion_neurosurgery_quintile      12380    96.938376
# 401                               con_avg_admit_order_to_consult_completion_neurosurgery_hrs      12380    96.938376
# 402                          con_max_admit_order_to_consult_completion_neurosurgery_quintile      12380    96.938376
# 403                               con_max_admit_order_to_consult_completion_neurosurgery_hrs      12380    96.938376
# 404                                                con_avg_consult_order_to_sign_icu_sdu_hrs      12379    96.930546
# 405                                                 con_max_consult_note_to_sign_icu_sdu_hrs      12379    96.930546
# 406                                                con_max_consult_order_to_sign_icu_sdu_hrs      12379    96.930546
# 407                                            con_max_consult_note_to_sign_icu_sdu_quintile      12379    96.930546
# 408                                            con_avg_consult_note_to_sign_icu_sdu_quintile      12379    96.930546
# ...
# 716                                                       con_max_consult_note_creation_time       3707    29.026701
# 717                                                        con_max_consult_note_creation_day       3707    29.026701
# 718                                                           con_max_date_note_signed_time2       3707    29.026701
# 719                                                            con_max_date_note_signed_day2       3707    29.026701
# 720                            con_max_consult_order_to_sign_is_signer_community_provider_yn       3707    29.026701
# 721                                 con_max_consult_order_to_sign_is_signer_nemg_provider_yn       3707    29.026701
# 722                                                con_max_consult_note_to_sign_any_quintile       3707    29.026701
# 723                                                con_avg_consult_note_to_sign_any_quintile       3707    29.026701
# 724                                                     con_avg_consult_note_to_sign_any_hrs       3707    29.026701
# 725                                               con_max_consult_order_to_sign_any_quintile       3707    29.026701
# 726                                               con_avg_consult_order_to_sign_any_quintile       3707    29.026701
# 727                                                     con_max_consult_note_to_sign_any_hrs       3707    29.026701
# 728                                                            con_max_date_note_signed_day1       3707    29.026701
# 729                                                    con_avg_consult_order_to_sign_any_hrs       3707    29.026701
# 730                                                    con_max_consult_order_to_sign_any_hrs       3707    29.026701
# 731                                  con_max_consult_note_to_sign_is_signer_nemg_provider_yn       3707    29.026701
# 732                                    con_max_consult_note_to_sign_is_signer_ym_provider_yn       3707    29.026701
# 733                                                       con_max_consult_note_to_sign_which       3707    29.026701
# 734                                                             con_signer_ym_provider_count       3707    29.026701
# 735                                                           con_signer_nemg_provider_count       3707    29.026701
# 736                                                      con_signer_community_provider_count       3707    29.026701
# 737                                             img_max_admit_order_to_imaging_order_any_hrs       2978    23.318456
# 738                                             img_avg_admit_order_to_imaging_order_any_hrs       2978    23.318456
# 739                                        img_avg_admit_order_to_imaging_order_any_quintile       2978    23.318456
# 740                                        img_max_admit_order_to_imaging_order_any_quintile       2978    23.318456
# 741                                                               con_unique_services_which2       2954    23.130530
# 742                                                                con_unique_services_which       2954    23.130530
# 743                                                             con_service_cardiology_count       2954    23.130530
# 744                                                     con_service_addiction_medicine_count       2954    23.130530
# 745                                                                con_service_surgery_count       2954    23.130530
# 746                                                                     con_service_sw_count       2954    23.130530
# 747                                                                 con_service_trauma_count       2954    23.130530
# 748                                                               con_service_diabetes_count       2954    23.130530
# 749                                                       con_service_gastroenterology_count       2954    23.130530
# 750                                                             con_service_geriatrics_count       2954    23.130530
# 751                                                             con_service_hematology_count       2954    23.130530
# 752                                                             con_service_hepatology_count       2954    23.130530
# 753                                                                con_service_urology_count       2954    23.130530
# 754                                                       con_service_vascular_surgery_count       2954    23.130530
# 755                                                                   con_service_picc_count       2954    23.130530
# 756                                                        con_service_plastic_surgery_count       2954    23.130530
# 757                                                               con_service_podiatry_count       2954    23.130530
# 758                                                    con_service_hospitalist_service_count       2954    23.130530
# 759                                                                con_service_icu_sdu_count       2954    23.130530
# 760                                                     con_service_infectious_disease_count       2954    23.130530
# 761                                                      con_service_internal_medicine_count       2954    23.130530
# 762                                                           con_service_lab_medicine_count       2954    23.130530
# 763                                                             con_service_nephrology_count       2954    23.130530
# 764                                                         con_service_neuro_oncology_count       2954    23.130530
# 765                                                              con_service_neurology_count       2954    23.130530
# 766                                                             con_service_psychiatry_count       2954    23.130530
# 767                                                            con_service_pulmonology_count       2954    23.130530
# 768                                                     con_service_radiation_oncology_count       2954    23.130530
# 769                                                              con_service_radiology_count       2954    23.130530
# 770                                                           con_service_neurosurgery_count       2954    23.130530
# 771                                                             con_service_palliative_count       2954    23.130530
# 772                                                               con_service_pharmacy_count       2954    23.130530
# 773                                   con_service_physical_medicine_and_rehabilitation_count       2954    23.130530
# 774                                                 con_service_cardiothoracic_surgery_count       2954    23.130530
# 775                                                       con_service_colon_and_rectal_count       2954    23.130530
# 776                                                            con_service_dermatology_count       2954    23.130530
# 777                                                           con_service_rheumatology_count       2954    23.130530
# 778                                                               con_service_oncology_count       2954    23.130530
# 779                                                          con_service_ophthalmology_count       2954    23.130530
# 780                                                            con_service_orthopedics_count       2954    23.130530
# 781                                                                  con_service_other_count       2954    23.130530
# 782                                                     con_service_otolaryngology_ent_count       2954    23.130530
# 783                                         img_max_admit_order_to_imaging_read_any_quintile       2901    22.715527
# 784                                         img_avg_admit_order_to_imaging_read_any_quintile       2901    22.715527
# 785                                              img_max_admit_order_to_imaging_read_any_hrs       2901    22.715527
# 786                                              img_avg_admit_order_to_imaging_read_any_hrs       2901    22.715527
# 787                                                           rfd_last_mrnb_to_discharge_hrs       2558    20.029755
# 788                                                         rfd_last_mrnb_effective_end_time       2558    20.029755
# 789                                                                rfd_first_mrnb_start_time       2558    20.029755
# 790                                                                 rfd_first_mrnb_start_day       2558    20.029755
# 791                                                          rfd_first_mrnb_to_discharge_hrs       2558    20.029755
# 792                                                          rfd_last_mrnb_effective_end_day       2558    20.029755
# 793                                                            img_avg_order_to_read_any_hrs       2380    18.635972
# 794                                                                            img_count_any       2380    18.635972
# 795                                                       img_max_order_to_read_any_quintile       2380    18.635972
# 796                                                 img_max_order_to_completion_any_quintile       2380    18.635972
# 797                                                       img_avg_order_to_read_any_quintile       2380    18.635972
# 798                                                 img_avg_order_to_completion_any_quintile       2380    18.635972
# 799                                                                             img_count_ct       2380    18.635972
# 800                                                                             img_count_mr       2380    18.635972
# 801                                                                             img_count_us       2380    18.635972
# 802                                                      img_max_order_to_completion_any_hrs       2380    18.635972
# 803                                                            img_max_order_to_read_any_hrs       2380    18.635972
# 804                                                      img_avg_order_to_completion_any_hrs       2380    18.635972
# 805                                                        thro_admit_order_to_first_bed_hrs       1221     9.560724
# 806                                                             thro_last_bed_to_ed_dept_hrs       1220     9.552893
# 807                                                             thro_first_bed_assigned_time       1220     9.552893
# 808                                                              thro_first_bed_assigned_day       1220     9.552893
# 809                                                              thro_last_bed_assigned_time       1220     9.552893
# 810                                                               thro_last_bed_assigned_day       1220     9.552893
# 811                                                           rfd_first_nmr_to_discharge_hrs       1036     8.112129
# 812                                                           rfd_last_nmr_effective_end_day       1036     8.112129
# 813                                                                 rfd_first_nmr_start_time       1036     8.112129
# 814                                                            rfd_last_nmr_to_discharge_hrs       1036     8.112129
# 815                                                          rfd_last_nmr_effective_end_time       1036     8.112129
# 816                                                                  rfd_first_nmr_start_day       1036     8.112129
# 817                                                             thro_door_to_admit_order_hrs        703     5.504659
# 818                                                          thro_admit_order_to_ed_dept_hrs        703     5.504659
# 819                                                              thro_admit_or_obs_order_day        703     5.504659
# 820                                                             thro_admit_or_obs_order_time        703     5.504659
# 821                                                                         thro_boarding_yn        703     5.504659
# 822                                                                          ed_arrival_date        673     5.269752
# 823                                                                    thro_ed_departure_day        673     5.269752
# 824                                                                   thro_ed_departure_time        673     5.269752
# 825                                                                     thro_ed_arrival_time        673     5.269752
# 826                                                                      thro_ed_arrival_day        673     5.269752
# 827                                                                          ed_arrival_time        673     5.269752
# 828                                                                    census_daily_ed_count        673     5.269752
# 829                                                                          ed_arrival_hour        673     5.269752
# 830                                                                   summary_first_edd_time        555     4.345783
# 831                                                                 summary_last_edd_doc_day        555     4.345783
# 832                                                                    summary_first_edd_day        555     4.345783
# 833                                                        summary_last_edd_to_discharge_hrs        555     4.345783
# 834                                                    summary_last_edd_doc_to_discharge_hrs        555     4.345783
# 835                                                                summary_last_edd_doc_time        555     4.345783
# 836                                                                summary_first_edd_doc_day        555     4.345783
# 837                                                                     summary_last_edd_day        555     4.345783
# 838                                                                    summary_last_edd_time        555     4.345783
# 839                                                   summary_first_edd_doc_to_discharge_hrs        555     4.345783
# 840                                                               summary_first_edd_doc_time        555     4.345783
# 841                                                       summary_first_edd_to_discharge_hrs        555     4.345783
# 842                                                                 summary_first_rfd_status        393     3.077284
# 843                                                        summary_last_rfd_to_discharge_hrs        393     3.077284
# 844                                                                    summary_first_rfd_day        393     3.077284
# 845                                                                  summary_last_rfd_status        393     3.077284
# 846                                                                     summary_last_rfd_day        393     3.077284
# 847                                                                    summary_last_rfd_time        393     3.077284
# 848                                                       summary_first_rfd_to_discharge_hrs        393     3.077284
# 849                                                                   summary_first_rfd_time        393     3.077284
# 850                                                                   viz_primary_payer_name        254     1.988881
# 851                                                                             viz_language          2     0.015660
